# %%
import re
import random as rd

# %%
# IOI Dataset

NAMES = [
    "Michael",
    "Christopher",
    "Jessica",
    "Matthew",
    "Ashley",
    "Jennifer",
    "Joshua",
    "Amanda",
    "Daniel",
    "David",
    "James",
    "Robert",
    "John",
    "Joseph",
    "Andrew",
    "Ryan",
    "Brandon",
    "Jason",
    "Justin",
    "Sarah",
    "William",
    "Jonathan",
    "Stephanie",
    "Brian",
    "Nicole",
    "Nicholas",
    "Anthony",
    "Heather",
    "Eric",
    "Elizabeth",
    "Adam",
    "Megan",
    "Melissa",
    "Kevin",
    "Steven",
    "Thomas",
    "Timothy",
    "Christina",
    "Kyle",
    "Rachel",
    "Laura",
    "Lauren",
    "Amber",
    "Brittany",
    "Danielle",
    "Richard",
    "Kimberly",
    "Jeffrey",
    "Amy",
    "Crystal",
    "Michelle",
    "Tiffany",
    "Jeremy",
    "Benjamin",
    "Mark",
    "Emily",
    "Aaron",
    "Charles",
    "Rebecca",
    "Jacob",
    "Stephen",
    "Patrick",
    "Sean",
    "Erin",
    "Jamie",
    "Kelly",
    "Samantha",
    "Nathan",
    "Sara",
    "Dustin",
    "Paul",
    "Angela",
    "Tyler",
    "Scott",
    "Katherine",
    "Andrea",
    "Gregory",
    "Erica",
    "Mary",
    "Travis",
    "Lisa",
    "Kenneth",
    "Bryan",
    "Lindsey",
    "Kristen",
    "Jose",
    "Alexander",
    "Jesse",
    "Katie",
    "Lindsay",
    "Shannon",
    "Vanessa",
    "Courtney",
    "Christine",
    "Alicia",
    "Cody",
    "Allison",
    "Bradley",
    "Samuel",
]

ABC_TEMPLATES = [
    "Then, [A], [B] and [C] went to the [PLACE]. [B] and [C] gave a [OBJECT] to [A]",
    "Afterwards [A], [B] and [C] went to the [PLACE]. [B] and [C] gave a [OBJECT] to [A]",
    "When [A], [B] and [C] arrived at the [PLACE], [B] and [C] gave a [OBJECT] to [A]",
    "Friends [A], [B] and [C] went to the [PLACE]. [B] and [C] gave a [OBJECT] to [A]",
]

BAC_TEMPLATES = [
    template.replace("[B]", "[A]", 1).replace("[A]", "[B]", 1)
    for template in ABC_TEMPLATES
]

BABA_TEMPLATES = [
    "Then, [B] and [A] went to the [PLACE]. [B] gave a [OBJECT] to [A]",
    "Then, [B] and [A] had a lot of fun at the [PLACE]. [B] gave a [OBJECT] to [A]",
    "Then, [B] and [A] were working at the [PLACE]. [B] decided to give a [OBJECT] to [A]",
    "Then, [B] and [A] were thinking about going to the [PLACE]. [B] wanted to give a [OBJECT] to [A]",
    "Then, [B] and [A] had a long argument, and afterwards [B] said to [A]",
    "After [B] and [A] went to the [PLACE], [B] gave a [OBJECT] to [A]",
    "When [B] and [A] got a [OBJECT] at the [PLACE], [B] decided to give it to [A]",
    "When [B] and [A] got a [OBJECT] at the [PLACE], [B] decided to give the [OBJECT] to [A]",
    "While [B] and [A] were working at the [PLACE], [B] gave a [OBJECT] to [A]",
    "While [B] and [A] were commuting to the [PLACE], [B] gave a [OBJECT] to [A]",
    "After the lunch, [B] and [A] went to the [PLACE]. [B] gave a [OBJECT] to [A]",
    "Afterwards, [B] and [A] went to the [PLACE]. [B] gave a [OBJECT] to [A]",
    "Then, [B] and [A] had a long argument. Afterwards [B] said to [A]",
    "The [PLACE] [B] and [A] went to had a [OBJECT]. [B] gave it to [A]",
    "Friends [B] and [A] found a [OBJECT] at the [PLACE]. [B] gave it to [A]",
]

BABA_LONG_TEMPLATES = [
    "Then in the morning, [B] and [A] went to the [PLACE]. [B] gave a [OBJECT] to [A]",
    "Then in the morning, [B] and [A] had a lot of fun at the [PLACE]. [B] gave a [OBJECT] to [A]",
    "Then in the morning, [B] and [A] were working at the [PLACE]. [B] decided to give a [OBJECT] to [A]",
    "Then in the morning, [B] and [A] were thinking about going to the [PLACE]. [B] wanted to give a [OBJECT] to [A]",
    "Then in the morning, [B] and [A] had a long argument, and afterwards [B] said to [A]",
    "After taking a long break [B] and [A] went to the [PLACE], [B] gave a [OBJECT] to [A]",
    "When soon afterwards [B] and [A] got a [OBJECT] at the [PLACE], [B] decided to give it to [A]",
    "When soon afterwards [B] and [A] got a [OBJECT] at the [PLACE], [B] decided to give the [OBJECT] to [A]",
    "While spending time together [B] and [A] were working at the [PLACE], [B] gave a [OBJECT] to [A]",
    "While spending time together [B] and [A] were commuting to the [PLACE], [B] gave a [OBJECT] to [A]",
    "After the lunch in the afternoon, [B] and [A] went to the [PLACE]. [B] gave a [OBJECT] to [A]",
    "Afterwards, while spending time together [B] and [A] went to the [PLACE]. [B] gave a [OBJECT] to [A]",
    "Then in the morning afterwards, [B] and [A] had a long argument. Afterwards [B] said to [A]",
    "The local big [PLACE] [B] and [A] went to had a [OBJECT]. [B] gave it to [A]",
    "Friends separated at birth [B] and [A] found a [OBJECT] at the [PLACE]. [B] gave it to [A]",
]

BABA_LATE_IOS = [
    "Then, [B] and [A] went to the [PLACE]. [B] gave a [OBJECT] to [A]",
    "Then, [B] and [A] had a lot of fun at the [PLACE]. [B] gave a [OBJECT] to [A]",
    "Then, [B] and [A] were working at the [PLACE]. [B] decided to give a [OBJECT] to [A]",
    "Then, [B] and [A] were thinking about going to the [PLACE]. [B] wanted to give a [OBJECT] to [A]",
    "Then, [B] and [A] had a long argument and after that [B] said to [A]",
    "After the lunch, [B] and [A] went to the [PLACE]. [B] gave a [OBJECT] to [A]",
    "Afterwards, [B] and [A] went to the [PLACE]. [B] gave a [OBJECT] to [A]",
    "Then, [B] and [A] had a long argument. Afterwards [B] said to [A]",
]

BABA_EARLY_IOS = [
    "Then [B] and [A] went to the [PLACE], and [B] gave a [OBJECT] to [A]",
    "Then [B] and [A] had a lot of fun at the [PLACE], and [B] gave a [OBJECT] to [A]",
    "Then [B] and [A] were working at the [PLACE], and [B] decided to give a [OBJECT] to [A]",
    "Then [B] and [A] were thinking about going to the [PLACE], and [B] wanted to give a [OBJECT] to [A]",
    "Then [B] and [A] had a long argument, and after that [B] said to [A]",
    "After the lunch [B] and [A] went to the [PLACE], and [B] gave a [OBJECT] to [A]",
    "Afterwards [B] and [A] went to the [PLACE], and [B] gave a [OBJECT] to [A]",
    "Then [B] and [A] had a long argument, and afterwards [B] said to [A]",
]

TEMPLATES_VARIED_MIDDLE = [
    "",
]

# no end of texts, GPT-2 small wasn't trained this way (ask Arthur)
# warnings.warn("Adding end of text prefixes!")
# for TEMPLATES in [BABA_TEMPLATES, BABA_EARLY_IOS, BABA_LATE_IOS]:
#     for i in range(len(TEMPLATES)):
#         TEMPLATES[i] = "<|endoftext|>" + TEMPLATES[i]

ABBA_TEMPLATES = BABA_TEMPLATES[:]
ABBA_LATE_IOS = BABA_LATE_IOS[:]
ABBA_EARLY_IOS = BABA_EARLY_IOS[:]

# %%
VERBS = [" tried", " said", " decided", " wanted", " gave"]
PLACES = [
    "store",
    "garden",
    "restaurant",
    "school",
    "hospital",
    "office",
    "house",
    "station",
]
OBJECTS = [
    "ring",
    "kiss",
    "bone",
    "basketball",
    "computer",
    "necklace",
    "drink",
    "snack",
]

ANIMALS = [
    "dog",
    "cat",
    "snake",
    "elephant",
    "beetle",
    "hippo",
    "giraffe",
    "tiger",
    "husky",
    "lion",
    "panther",
    "whale",
    "dolphin",
    "beaver",
    "rabbit",
    "fox",
    "lamb",
    "ferret",
]

# %%
for TEMPLATES in [ABBA_TEMPLATES, ABBA_LATE_IOS, ABBA_EARLY_IOS]:
    for i in range(len(TEMPLATES)):
        first_clause = True
        for j in range(1, len(TEMPLATES[i]) - 1):
            if TEMPLATES[i][j - 1 : j + 2] == "[B]" and first_clause:
                TEMPLATES[i] = TEMPLATES[i][:j] + "A" + TEMPLATES[i][j + 1 :]
            elif TEMPLATES[i][j - 1 : j + 2] == "[A]" and first_clause:
                first_clause = False
                TEMPLATES[i] = TEMPLATES[i][:j] + "B" + TEMPLATES[i][j + 1 :]


def multiple_replace(dict, text):
    # from: https://stackoverflow.com/questions/15175142/how-can-i-do-multiple-substitutions-using-regex
    # Create a regular expression from the dictionary keys
    regex = re.compile("(%s)" % "|".join(map(re.escape, dict.keys())))

    # For each match, look-up corresponding value in dictionary
    return regex.sub(lambda mo: dict[mo.string[mo.start() : mo.end()]], text)


def iter_sample_fast(iterable, samplesize):
    results = []
    # Fill in the first samplesize elements:
    try:
        for _ in range(samplesize):
            results.append(next(iterable))
    except StopIteration:
        raise ValueError("Sample larger than population.")
    rd.shuffle(results)  # Randomize their positions

    return results


NOUNS_DICT = NOUNS_DICT = {"[PLACE]": PLACES, "[OBJECT]": OBJECTS}


def gen_prompt_uniform(
    templates, names, nouns_dict, N, symmetric, prefixes=None, abc=False
):
    nb_gen = 0
    ioi_prompts = []
    while nb_gen < N:
        temp = rd.choice(templates)
        temp_id = templates.index(temp)
        name_1 = ""
        name_2 = ""
        name_3 = ""
        while len(set([name_1, name_2, name_3])) < 3:
            name_1 = rd.choice(names)
            name_2 = rd.choice(names)
            name_3 = rd.choice(names)

        nouns = {}
        ioi_prompt = {}
        for k in nouns_dict:
            nouns[k] = rd.choice(nouns_dict[k])
            ioi_prompt[k] = nouns[k]
        prompt = temp
        for k in nouns_dict:
            prompt = prompt.replace(k, nouns[k])

        if prefixes is not None:
            L = rd.randint(30, 40)
            pref = ".".join(rd.choice(prefixes).split(".")[:L])
            pref += "<|endoftext|>"
        else:
            pref = ""

        prompt1 = prompt.replace("[A]", name_1)
        prompt1 = prompt1.replace("[B]", name_2)
        if abc:
            prompt1 = prompt1.replace("[C]", name_3)
        prompt1 = pref + prompt1
        ioi_prompt["text"] = prompt1
        ioi_prompt["IO"] = name_1
        ioi_prompt["S"] = name_2
        ioi_prompt["TEMPLATE_IDX"] = temp_id
        ioi_prompts.append(ioi_prompt)
        if abc:
            ioi_prompts[-1]["C"] = name_3

        nb_gen += 1

        if symmetric and nb_gen < N:
            prompt2 = prompt.replace("[A]", name_2)
            prompt2 = prompt2.replace("[B]", name_1)
            prompt2 = pref + prompt2
            ioi_prompts.append(
                {"text": prompt2, "IO": name_2, "S": name_1, "TEMPLATE_IDX": temp_id}
            )
            nb_gen += 1
    return ioi_prompts

# %%
# Make sentences with each template for train and test
ioi_prompts = gen_prompt_uniform(
    BABA_TEMPLATES + ABBA_TEMPLATES, NAMES, NOUNS_DICT, 10000, True, abc=True
)

BABA_TEMPLATES + ABBA_TEMPLATES
# Out:
# ['Then, [B] and [A] went to the [PLACE]. [B] gave a [OBJECT] to [A]',
#  'Then, [B] and [A] had a lot of fun at the [PLACE]. [B] gave a [OBJECT] to [A]',
#  'Then, [B] and [A] were working at the [PLACE]. [B] decided to give a [OBJECT] to [A]',
#  'Then, [B] and [A] were thinking about going to the [PLACE]. [B] wanted to give a [OBJECT] to [A]',
#  'Then, [B] and [A] had a long argument, and afterwards [B] said to [A]',
#  'After [B] and [A] went to the [PLACE], [B] gave a [OBJECT] to [A]',
#  'When [B] and [A] got a [OBJECT] at the [PLACE], [B] decided to give it to [A]',
#  'When [B] and [A] got a [OBJECT] at the [PLACE], [B] decided to give the [OBJECT] to [A]',
#  'While [B] and [A] were working at the [PLACE], [B] gave a [OBJECT] to [A]',
#  'While [B] and [A] were commuting to the [PLACE], [B] gave a [OBJECT] to [A]',
#  'After the lunch, [B] and [A] went to the [PLACE]. [B] gave a [OBJECT] to [A]',
#  'Afterwards, [B] and [A] went to the [PLACE]. [B] gave a [OBJECT] to [A]',
#  'Then, [B] and [A] had a long argument. Afterwards [B] said to [A]',
#  'The [PLACE] [B] and [A] went to had a [OBJECT]. [B] gave it to [A]',
#  'Friends [B] and [A] found a [OBJECT] at the [PLACE]. [B] gave it to [A]',
#  'Then, [A] and [B] went to the [PLACE]. [B] gave a [OBJECT] to [A]',
#  'Then, [A] and [B] had a lot of fun at the [PLACE]. [B] gave a [OBJECT] to [A]',
#  'Then, [A] and [B] were working at the [PLACE]. [B] decided to give a [OBJECT] to [A]',
#  'Then, [A] and [B] were thinking about going to the [PLACE]. [B] wanted to give a [OBJECT] to [A]',
#  'Then, [A] and [B] had a long argument, and afterwards [B] said to [A]',
#  'After [A] and [B] went to the [PLACE], [B] gave a [OBJECT] to [A]',
#  'When [A] and [B] got a [OBJECT] at the [PLACE], [B] decided to give it to [A]',
#  'When [A] and [B] got a [OBJECT] at the [PLACE], [B] decided to give the [OBJECT] to [A]',
#  'While [A] and [B] were working at the [PLACE], [B] gave a [OBJECT] to [A]',
#  'While [A] and [B] were commuting to the [PLACE], [B] gave a [OBJECT] to [A]',
#  'After the lunch, [A] and [B] went to the [PLACE]. [B] gave a [OBJECT] to [A]',
#  'Afterwards, [A] and [B] went to the [PLACE]. [B] gave a [OBJECT] to [A]',
#  'Then, [A] and [B] had a long argument. Afterwards [B] said to [A]',
#  'The [PLACE] [A] and [B] went to had a [OBJECT]. [B] gave it to [A]',
#  'Friends [A] and [B] found a [OBJECT] at the [PLACE]. [B] gave it to [A]']

# %%
# replace the first occurence of B in BABA and ABBA with C
non_ioi_templates = []
for template in BABA_TEMPLATES + ABBA_TEMPLATES:
    non_ioi_templates.append(template.replace("[B]", "[C]", 1))

non_ioi_templates
ioi_prompts_abc = gen_prompt_uniform(
    non_ioi_templates, NAMES, NOUNS_DICT, 10000, True, abc=True
)

# %%
ioi_prompts
# Out:
# [{'[PLACE]': 'station',
#   '[OBJECT]': 'necklace',
#   'text': 'While Courtney and Andrew were commuting to the station, Andrew gave a necklace to Courtney',
#   'IO': 'Courtney',
#   'S': 'Andrew',
#   'TEMPLATE_IDX': 24,
#   'C': 'Angela'},
#  {'text': 'While Andrew and Courtney were commuting to the station, Courtney gave a necklace to Andrew',
#   'IO': 'Andrew',
#   'S': 'Courtney',
#   'TEMPLATE_IDX': 24},
#  {'[PLACE]': 'restaurant',
#   '[OBJECT]': 'basketball',
#   'text': 'Afterwards, Amanda and Katherine went to the restaurant. Katherine gave a basketball to Amanda',
#   'IO': 'Amanda',
#   'S': 'Katherine',
#   'TEMPLATE_IDX': 26,
#   'C': 'Rebecca'},
#  {'text': 'Afterwards, Katherine and Amanda went to the restaurant. Amanda gave a basketball to Katherine',
#   'IO': 'Katherine',
#   'S': 'Amanda',
#   'TEMPLATE_IDX': 26},
#  {'[PLACE]': 'office',
#   '[OBJECT]': 'drink',
#   'text': 'Then, Lindsay and Matthew were working at the office. Lindsay decided to give a drink to Matthew',
#   'IO': 'Matthew',
#   'S': 'Lindsay',
#   'TEMPLATE_IDX': 2,
#   'C': 'Kevin'},
#  {'text': 'Then, Matthew and Lindsay were working at the office. Matthew decided to give a drink to Lindsay',
#   'IO': 'Lindsay',
#   'S': 'Matthew',
#   'TEMPLATE_IDX': 2},
#  {'[PLACE]': 'office',
#   '[OBJECT]': 'kiss',
#   'text': 'The office Allison and Tyler went to had a kiss. Allison gave it to Tyler',
#   'IO': 'Tyler',
#   'S': 'Allison',
#   'TEMPLATE_IDX': 13,
#   'C': 'Samuel'},
#  {'text': 'The office Tyler and Allison went to had a kiss. Tyler gave it to Allison',
#   'IO': 'Allison',
#   'S': 'Tyler',
#   'TEMPLATE_IDX': 13},
#  {'[PLACE]': 'office',
#   '[OBJECT]': 'bone',
#   'text': 'Afterwards, Erica and Jonathan went to the office. Jonathan gave a bone to Erica',
#   'IO': 'Erica',
#   'S': 'Jonathan',
#   'TEMPLATE_IDX': 26,
#   'C': 'Ashley'},
#  {'text': 'Afterwards, Jonathan and Erica went to the office. Erica gave a bone to Jonathan',
#   'IO': 'Jonathan',
#   'S': 'Erica',
#   'TEMPLATE_IDX': 26},
#  {'[PLACE]': 'store',
#   '[OBJECT]': 'basketball',
#   'text': 'Afterwards, Jonathan and Kenneth went to the store. Kenneth gave a basketball to Jonathan',
#   'IO': 'Jonathan',
#   'S': 'Kenneth',
#   'TEMPLATE_IDX': 26,
#   'C': 'Alicia'},
#  {'text': 'Afterwards, Kenneth and Jonathan went to the store. Jonathan gave a basketball to Kenneth',
#   'IO': 'Kenneth',
#   'S': 'Jonathan',
#   'TEMPLATE_IDX': 26},
#  {'[PLACE]': 'store',
#   '[OBJECT]': 'basketball',
#   'text': 'Afterwards, Amber and Eric went to the store. Amber gave a basketball to Eric',
#   'IO': 'Eric',
#   'S': 'Amber',
#   'TEMPLATE_IDX': 11,
#   'C': 'Sean'},
#  {'text': 'Afterwards, Eric and Amber went to the store. Eric gave a basketball to Amber',
#   'IO': 'Amber',
#   'S': 'Eric',
#   'TEMPLATE_IDX': 11},
#  {'[PLACE]': 'house',
#   '[OBJECT]': 'basketball',
#   'text': 'Afterwards, Jonathan and Angela went to the house. Jonathan gave a basketball to Angela',
#   'IO': 'Angela',
#   'S': 'Jonathan',
#   'TEMPLATE_IDX': 11,
#   'C': 'Tyler'},
#  {'text': 'Afterwards, Angela and Jonathan went to the house. Angela gave a basketball to Jonathan',
#   'IO': 'Jonathan',
#   'S': 'Angela',
#   'TEMPLATE_IDX': 11},
#  {'[PLACE]': 'garden',
#   '[OBJECT]': 'kiss',
#   'text': 'While Michelle and Sean were commuting to the garden, Michelle gave a kiss to Sean',
#   'IO': 'Sean',
#   'S': 'Michelle',
#   'TEMPLATE_IDX': 9,
#   'C': 'Katherine'},
#  {'text': 'While Sean and Michelle were commuting to the garden, Sean gave a kiss to Michelle',
#   'IO': 'Michelle',
#   'S': 'Sean',
#   'TEMPLATE_IDX': 9},
#  {'[PLACE]': 'house',
#   '[OBJECT]': 'bone',
#   'text': 'Friends Benjamin and Jeffrey found a bone at the house. Benjamin gave it to Jeffrey',
#   'IO': 'Jeffrey',
#   'S': 'Benjamin',
#   'TEMPLATE_IDX': 14,
#   'C': 'Heather'},
#  {'text': 'Friends Jeffrey and Benjamin found a bone at the house. Jeffrey gave it to Benjamin',
#   'IO': 'Benjamin',
#   'S': 'Jeffrey',
#   'TEMPLATE_IDX': 14},
#  {'[PLACE]': 'house',
#   '[OBJECT]': 'basketball',
#   'text': 'Then, Alexander and Christine were thinking about going to the house. Christine wanted to give a basketball to Alexander',
#   'IO': 'Alexander',
#   'S': 'Christine',
#   'TEMPLATE_IDX': 18,
#   'C': 'Heather'},
#  {'text': 'Then, Christine and Alexander were thinking about going to the house. Alexander wanted to give a basketball to Christine',
#   'IO': 'Christine',
#   'S': 'Alexander',
#   'TEMPLATE_IDX': 18},
#  {'[PLACE]': 'office',
#   '[OBJECT]': 'drink',
#   'text': 'Friends Benjamin and Angela found a drink at the office. Angela gave it to Benjamin',
#   'IO': 'Benjamin',
#   'S': 'Angela',
#   'TEMPLATE_IDX': 29,
#   'C': 'Gregory'},
#  {'text': 'Friends Angela and Benjamin found a drink at the office. Benjamin gave it to Angela',
#   'IO': 'Angela',
#   'S': 'Benjamin',
#   'TEMPLATE_IDX': 29},
#  {'[PLACE]': 'hospital',
#   '[OBJECT]': 'ring',
#   'text': 'Then, Benjamin and Jonathan went to the hospital. Jonathan gave a ring to Benjamin',
#   'IO': 'Benjamin',
#   'S': 'Jonathan',
#   'TEMPLATE_IDX': 15,
#   'C': 'Travis'},
#  {'text': 'Then, Jonathan and Benjamin went to the hospital. Benjamin gave a ring to Jonathan',
#   'IO': 'Jonathan',
#   'S': 'Benjamin',
#   'TEMPLATE_IDX': 15},
#  {'[PLACE]': 'station',
#   '[OBJECT]': 'computer',
#   'text': 'Then, Daniel and Charles went to the station. Daniel gave a computer to Charles',
#   'IO': 'Charles',
#   'S': 'Daniel',
#   'TEMPLATE_IDX': 0,
#   'C': 'Alicia'},
#  {'text': 'Then, Charles and Daniel went to the station. Charles gave a computer to Daniel',
#   'IO': 'Daniel',
#   'S': 'Charles',
#   'TEMPLATE_IDX': 0},
#  {'[PLACE]': 'restaurant',
#   '[OBJECT]': 'necklace',
#   'text': 'While Angela and Amanda were working at the restaurant, Amanda gave a necklace to Angela',
#   'IO': 'Angela',
#   'S': 'Amanda',
#   'TEMPLATE_IDX': 23,
#   'C': 'Rebecca'},
#  {'text': 'While Amanda and Angela were working at the restaurant, Angela gave a necklace to Amanda',
#   'IO': 'Amanda',
#   'S': 'Angela',
#   'TEMPLATE_IDX': 23},
#  {'[PLACE]': 'station',
#   '[OBJECT]': 'ring',
#   'text': 'After Brian and Erica went to the station, Erica gave a ring to Brian',
#   'IO': 'Brian',
#   'S': 'Erica',
#   'TEMPLATE_IDX': 20,
#   'C': 'Travis'},
#  {'text': 'After Erica and Brian went to the station, Brian gave a ring to Erica',
#   'IO': 'Erica',
#   'S': 'Brian',
#   'TEMPLATE_IDX': 20},
#  {'[PLACE]': 'restaurant',
#   '[OBJECT]': 'bone',
#   'text': 'While Alexander and Tiffany were commuting to the restaurant, Alexander gave a bone to Tiffany',
#   'IO': 'Tiffany',
#   'S': 'Alexander',
#   'TEMPLATE_IDX': 9,
#   'C': 'Jason'},
#  {'text': 'While Tiffany and Alexander were commuting to the restaurant, Tiffany gave a bone to Alexander',
#   'IO': 'Alexander',
#   'S': 'Tiffany',
#   'TEMPLATE_IDX': 9},
#  {'[PLACE]': 'store',
#   '[OBJECT]': 'basketball',
#   'text': 'Then, Brittany and Dustin had a long argument. Afterwards Brittany said to Dustin',
#   'IO': 'Dustin',
#   'S': 'Brittany',
#   'TEMPLATE_IDX': 12,
#   'C': 'Robert'},
#  {'text': 'Then, Dustin and Brittany had a long argument. Afterwards Dustin said to Brittany',
#   'IO': 'Brittany',
#   'S': 'Dustin',
#   'TEMPLATE_IDX': 12},
#  {'[PLACE]': 'store',
#   '[OBJECT]': 'kiss',
#   'text': 'Friends Lindsey and Jose found a kiss at the store. Jose gave it to Lindsey',
#   'IO': 'Lindsey',
#   'S': 'Jose',
#   'TEMPLATE_IDX': 29,
#   'C': 'Kelly'},
#  {'text': 'Friends Jose and Lindsey found a kiss at the store. Lindsey gave it to Jose',
#   'IO': 'Jose',
#   'S': 'Lindsey',
#   'TEMPLATE_IDX': 29},
#  {'[PLACE]': 'garden',
#   '[OBJECT]': 'computer',
#   'text': 'After Bryan and Emily went to the garden, Bryan gave a computer to Emily',
#   'IO': 'Emily',
#   'S': 'Bryan',
#   'TEMPLATE_IDX': 5,
#   'C': 'Christine'},
#  {'text': 'After Emily and Bryan went to the garden, Emily gave a computer to Bryan',
#   'IO': 'Bryan',
#   'S': 'Emily',
#   'TEMPLATE_IDX': 5},
#  {'[PLACE]': 'restaurant',
#   '[OBJECT]': 'computer',
#   'text': 'After the lunch, Steven and Amy went to the restaurant. Steven gave a computer to Amy',
#   'IO': 'Amy',
#   'S': 'Steven',
#   'TEMPLATE_IDX': 10,
#   'C': 'Kenneth'},
#  {'text': 'After the lunch, Amy and Steven went to the restaurant. Amy gave a computer to Steven',
#   'IO': 'Steven',
#   'S': 'Amy',
#   'TEMPLATE_IDX': 10},
#  {'[PLACE]': 'school',
#   '[OBJECT]': 'kiss',
#   'text': 'The school Shannon and Alicia went to had a kiss. Alicia gave it to Shannon',
#   'IO': 'Shannon',
#   'S': 'Alicia',
#   'TEMPLATE_IDX': 28,
#   'C': 'Daniel'},
#  {'text': 'The school Alicia and Shannon went to had a kiss. Shannon gave it to Alicia',
#   'IO': 'Alicia',
#   'S': 'Shannon',
#   'TEMPLATE_IDX': 28},
#  {'[PLACE]': 'office',
#   '[OBJECT]': 'bone',
#   'text': 'When Kyle and Brandon got a bone at the office, Kyle decided to give the bone to Brandon',
#   'IO': 'Brandon',
#   'S': 'Kyle',
#   'TEMPLATE_IDX': 7,
#   'C': 'Kelly'},
#  {'text': 'When Brandon and Kyle got a bone at the office, Brandon decided to give the bone to Kyle',
#   'IO': 'Kyle',
#   'S': 'Brandon',
#   'TEMPLATE_IDX': 7},
#  {'[PLACE]': 'garden',
#   '[OBJECT]': 'drink',
#   'text': 'Then, Jeffrey and Jeremy were working at the garden. Jeffrey decided to give a drink to Jeremy',
#   'IO': 'Jeremy',
#   'S': 'Jeffrey',
#   'TEMPLATE_IDX': 2,
#   'C': 'Laura'},
#  {'text': 'Then, Jeremy and Jeffrey were working at the garden. Jeremy decided to give a drink to Jeffrey',
#   'IO': 'Jeffrey',
#   'S': 'Jeremy',
#   'TEMPLATE_IDX': 2},
#  {'[PLACE]': 'restaurant',
#   '[OBJECT]': 'necklace',
#   'text': 'Then, Brittany and Ashley went to the restaurant. Brittany gave a necklace to Ashley',
#   'IO': 'Ashley',
#   'S': 'Brittany',
#   'TEMPLATE_IDX': 0,
#   'C': 'Patrick'},
#  {'text': 'Then, Ashley and Brittany went to the restaurant. Ashley gave a necklace to Brittany',
#   'IO': 'Brittany',
#   'S': 'Ashley',
#   'TEMPLATE_IDX': 0},
#  {'[PLACE]': 'hospital',
#   '[OBJECT]': 'ring',
#   'text': 'Then, Joseph and Charles had a lot of fun at the hospital. Joseph gave a ring to Charles',
#   'IO': 'Charles',
#   'S': 'Joseph',
#   'TEMPLATE_IDX': 1,
#   'C': 'Lisa'},
#  {'text': 'Then, Charles and Joseph had a lot of fun at the hospital. Charles gave a ring to Joseph',
#   'IO': 'Joseph',
#   'S': 'Charles',
#   'TEMPLATE_IDX': 1},
#  {'[PLACE]': 'store',
#   '[OBJECT]': 'snack',
#   'text': 'After Brittany and Brian went to the store, Brittany gave a snack to Brian',
#   'IO': 'Brian',
#   'S': 'Brittany',
#   'TEMPLATE_IDX': 5,
#   'C': 'Bradley'},
#  {'text': 'After Brian and Brittany went to the store, Brian gave a snack to Brittany',
#   'IO': 'Brittany',
#   'S': 'Brian',
#   'TEMPLATE_IDX': 5},
#  {'[PLACE]': 'hospital',
#   '[OBJECT]': 'bone',
#   'text': 'Friends Richard and Samantha found a bone at the hospital. Richard gave it to Samantha',
#   'IO': 'Samantha',
#   'S': 'Richard',
#   'TEMPLATE_IDX': 14,
#   'C': 'Michael'},
#  {'text': 'Friends Samantha and Richard found a bone at the hospital. Samantha gave it to Richard',
#   'IO': 'Richard',
#   'S': 'Samantha',
#   'TEMPLATE_IDX': 14},
#  {'[PLACE]': 'garden',
#   '[OBJECT]': 'computer',
#   'text': 'While Andrew and Scott were working at the garden, Scott gave a computer to Andrew',
#   'IO': 'Andrew',
#   'S': 'Scott',
#   'TEMPLATE_IDX': 23,
#   'C': 'Dustin'},
#  {'text': 'While Scott and Andrew were working at the garden, Andrew gave a computer to Scott',
#   'IO': 'Scott',
#   'S': 'Andrew',
#   'TEMPLATE_IDX': 23},
#  {'[PLACE]': 'garden',
#   '[OBJECT]': 'basketball',
#   'text': 'When Andrew and Laura got a basketball at the garden, Laura decided to give the basketball to Andrew',
#   'IO': 'Andrew',
#   'S': 'Laura',
#   'TEMPLATE_IDX': 22,
#   'C': 'Kelly'},
#  {'text': 'When Laura and Andrew got a basketball at the garden, Andrew decided to give the basketball to Laura',
#   'IO': 'Laura',
#   'S': 'Andrew',
#   'TEMPLATE_IDX': 22},
#  {'[PLACE]': 'restaurant',
#   '[OBJECT]': 'bone',
#   'text': 'Afterwards, Courtney and James went to the restaurant. Courtney gave a bone to James',
#   'IO': 'James',
#   'S': 'Courtney',
#   'TEMPLATE_IDX': 11,
#   'C': 'Amber'},
#  {'text': 'Afterwards, James and Courtney went to the restaurant. James gave a bone to Courtney',
#   'IO': 'Courtney',
#   'S': 'James',
#   'TEMPLATE_IDX': 11},
#  {'[PLACE]': 'store',
#   '[OBJECT]': 'snack',
#   'text': 'Then, Kyle and Paul had a lot of fun at the store. Kyle gave a snack to Paul',
#   'IO': 'Paul',
#   'S': 'Kyle',
#   'TEMPLATE_IDX': 1,
#   'C': 'Justin'},
#  {'text': 'Then, Paul and Kyle had a lot of fun at the store. Paul gave a snack to Kyle',
#   'IO': 'Kyle',
#   'S': 'Paul',
#   'TEMPLATE_IDX': 1},
#  {'[PLACE]': 'store',
#   '[OBJECT]': 'computer',
#   'text': 'When Shannon and Robert got a computer at the store, Shannon decided to give it to Robert',
#   'IO': 'Robert',
#   'S': 'Shannon',
#   'TEMPLATE_IDX': 6,
#   'C': 'Lisa'},
#  {'text': 'When Robert and Shannon got a computer at the store, Robert decided to give it to Shannon',
#   'IO': 'Shannon',
#   'S': 'Robert',
#   'TEMPLATE_IDX': 6},
#  {'[PLACE]': 'office',
#   '[OBJECT]': 'snack',
#   'text': 'When Heather and Jennifer got a snack at the office, Heather decided to give it to Jennifer',
#   'IO': 'Jennifer',
#   'S': 'Heather',
#   'TEMPLATE_IDX': 6,
#   'C': 'Jacob'},
#  {'text': 'When Jennifer and Heather got a snack at the office, Jennifer decided to give it to Heather',
#   'IO': 'Heather',
#   'S': 'Jennifer',
#   'TEMPLATE_IDX': 6},
#  {'[PLACE]': 'garden',
#   '[OBJECT]': 'basketball',
#   'text': 'Then, Ryan and Kenneth were thinking about going to the garden. Kenneth wanted to give a basketball to Ryan',
#   'IO': 'Ryan',
#   'S': 'Kenneth',
#   'TEMPLATE_IDX': 18,
#   'C': 'Stephanie'},
#  {'text': 'Then, Kenneth and Ryan were thinking about going to the garden. Ryan wanted to give a basketball to Kenneth',
#   'IO': 'Kenneth',
#   'S': 'Ryan',
#   'TEMPLATE_IDX': 18},
#  {'[PLACE]': 'store',
#   '[OBJECT]': 'computer',
#   'text': 'Then, Steven and Sarah were thinking about going to the store. Steven wanted to give a computer to Sarah',
#   'IO': 'Sarah',
#   'S': 'Steven',
#   'TEMPLATE_IDX': 3,
#   'C': 'Megan'},
#  {'text': 'Then, Sarah and Steven were thinking about going to the store. Sarah wanted to give a computer to Steven',
#   'IO': 'Steven',
#   'S': 'Sarah',
#   'TEMPLATE_IDX': 3},
#  {'[PLACE]': 'house',
#   '[OBJECT]': 'basketball',
#   'text': 'After the lunch, Christopher and Lauren went to the house. Christopher gave a basketball to Lauren',
#   'IO': 'Lauren',
#   'S': 'Christopher',
#   'TEMPLATE_IDX': 10,
#   'C': 'Sean'},
#  {'text': 'After the lunch, Lauren and Christopher went to the house. Lauren gave a basketball to Christopher',
#   'IO': 'Christopher',
#   'S': 'Lauren',
#   'TEMPLATE_IDX': 10},
#  {'[PLACE]': 'office',
#   '[OBJECT]': 'basketball',
#   'text': 'Then, Cody and Kevin were working at the office. Cody decided to give a basketball to Kevin',
#   'IO': 'Kevin',
#   'S': 'Cody',
#   'TEMPLATE_IDX': 2,
#   'C': 'Mark'},
#  {'text': 'Then, Kevin and Cody were working at the office. Kevin decided to give a basketball to Cody',
#   'IO': 'Cody',
#   'S': 'Kevin',
#   'TEMPLATE_IDX': 2},
#  {'[PLACE]': 'store',
#   '[OBJECT]': 'ring',
#   'text': 'The store Tiffany and Nicholas went to had a ring. Nicholas gave it to Tiffany',
#   'IO': 'Tiffany',
#   'S': 'Nicholas',
#   'TEMPLATE_IDX': 28,
#   'C': 'Stephen'},
#  {'text': 'The store Nicholas and Tiffany went to had a ring. Tiffany gave it to Nicholas',
#   'IO': 'Nicholas',
#   'S': 'Tiffany',
#   'TEMPLATE_IDX': 28},
#  {'[PLACE]': 'station',
#   '[OBJECT]': 'kiss',
#   'text': 'Afterwards, Christine and Erica went to the station. Erica gave a kiss to Christine',
#   'IO': 'Christine',
#   'S': 'Erica',
#   'TEMPLATE_IDX': 26,
#   'C': 'Gregory'},
#  {'text': 'Afterwards, Erica and Christine went to the station. Christine gave a kiss to Erica',
#   'IO': 'Erica',
#   'S': 'Christine',
#   'TEMPLATE_IDX': 26},
#  {'[PLACE]': 'restaurant',
#   '[OBJECT]': 'bone',
#   'text': 'The restaurant Jason and Lindsay went to had a bone. Lindsay gave it to Jason',
#   'IO': 'Jason',
#   'S': 'Lindsay',
#   'TEMPLATE_IDX': 28,
#   'C': 'Paul'},
#  {'text': 'The restaurant Lindsay and Jason went to had a bone. Jason gave it to Lindsay',
#   'IO': 'Lindsay',
#   'S': 'Jason',
#   'TEMPLATE_IDX': 28},
#  {'[PLACE]': 'house',
#   '[OBJECT]': 'necklace',
#   'text': 'Afterwards, Vanessa and Daniel went to the house. Vanessa gave a necklace to Daniel',
#   'IO': 'Daniel',
#   'S': 'Vanessa',
#   'TEMPLATE_IDX': 11,
#   'C': 'Jacob'},
#  {'text': 'Afterwards, Daniel and Vanessa went to the house. Daniel gave a necklace to Vanessa',
#   'IO': 'Vanessa',
#   'S': 'Daniel',
#   'TEMPLATE_IDX': 11},
#  {'[PLACE]': 'hospital',
#   '[OBJECT]': 'computer',
#   'text': 'When Megan and Kevin got a computer at the hospital, Kevin decided to give it to Megan',
#   'IO': 'Megan',
#   'S': 'Kevin',
#   'TEMPLATE_IDX': 21,
#   'C': 'Jessica'},
#  {'text': 'When Kevin and Megan got a computer at the hospital, Megan decided to give it to Kevin',
#   'IO': 'Kevin',
#   'S': 'Megan',
#   'TEMPLATE_IDX': 21},
#  {'[PLACE]': 'school',
#   '[OBJECT]': 'snack',
#   'text': 'While Christine and Sara were working at the school, Sara gave a snack to Christine',
#   'IO': 'Christine',
#   'S': 'Sara',
#   'TEMPLATE_IDX': 23,
#   'C': 'Jennifer'},
#  {'text': 'While Sara and Christine were working at the school, Christine gave a snack to Sara',
#   'IO': 'Sara',
#   'S': 'Christine',
#   'TEMPLATE_IDX': 23},
#  {'[PLACE]': 'restaurant',
#   '[OBJECT]': 'drink',
#   'text': 'While Christopher and James were commuting to the restaurant, James gave a drink to Christopher',
#   'IO': 'Christopher',
#   'S': 'James',
#   'TEMPLATE_IDX': 24,
#   'C': 'Dustin'},
#  {'text': 'While James and Christopher were commuting to the restaurant, Christopher gave a drink to James',
#   'IO': 'James',
#   'S': 'Christopher',
#   'TEMPLATE_IDX': 24},
#  {'[PLACE]': 'restaurant',
#   '[OBJECT]': 'computer',
#   'text': 'Afterwards, Rebecca and Jonathan went to the restaurant. Jonathan gave a computer to Rebecca',
#   'IO': 'Rebecca',
#   'S': 'Jonathan',
#   'TEMPLATE_IDX': 26,
#   'C': 'Samuel'},
#  {'text': 'Afterwards, Jonathan and Rebecca went to the restaurant. Rebecca gave a computer to Jonathan',
#   'IO': 'Jonathan',
#   'S': 'Rebecca',
#   'TEMPLATE_IDX': 26},
#  {'[PLACE]': 'garden',
#   '[OBJECT]': 'kiss',
#   'text': 'Then, Jennifer and Alexander had a long argument. Afterwards Alexander said to Jennifer',
#   'IO': 'Jennifer',
#   'S': 'Alexander',
#   'TEMPLATE_IDX': 27,
#   'C': 'Christina'},
#  {'text': 'Then, Alexander and Jennifer had a long argument. Afterwards Jennifer said to Alexander',
#   'IO': 'Alexander',
#   'S': 'Jennifer',
#   'TEMPLATE_IDX': 27},
#  {'[PLACE]': 'garden',
#   '[OBJECT]': 'drink',
#   'text': 'Then, Benjamin and Amber had a lot of fun at the garden. Benjamin gave a drink to Amber',
#   'IO': 'Amber',
#   'S': 'Benjamin',
#   'TEMPLATE_IDX': 1,
#   'C': 'Joseph'},
#  {'text': 'Then, Amber and Benjamin had a lot of fun at the garden. Amber gave a drink to Benjamin',
#   'IO': 'Benjamin',
#   'S': 'Amber',
#   'TEMPLATE_IDX': 1},
#  {'[PLACE]': 'school',
#   '[OBJECT]': 'bone',
#   'text': 'While Andrew and Jason were commuting to the school, Andrew gave a bone to Jason',
#   'IO': 'Jason',
#   'S': 'Andrew',
#   'TEMPLATE_IDX': 9,
#   'C': 'Michael'},
#  {'text': 'While Jason and Andrew were commuting to the school, Jason gave a bone to Andrew',
#   'IO': 'Andrew',
#   'S': 'Jason',
#   'TEMPLATE_IDX': 9},
#  {'[PLACE]': 'hospital',
#   '[OBJECT]': 'computer',
#   'text': 'Then, Samuel and Vanessa were thinking about going to the hospital. Vanessa wanted to give a computer to Samuel',
#   'IO': 'Samuel',
#   'S': 'Vanessa',
#   'TEMPLATE_IDX': 18,
#   'C': 'Kevin'},
#  {'text': 'Then, Vanessa and Samuel were thinking about going to the hospital. Samuel wanted to give a computer to Vanessa',
#   'IO': 'Vanessa',
#   'S': 'Samuel',
#   'TEMPLATE_IDX': 18},
#  {'[PLACE]': 'garden',
#   '[OBJECT]': 'kiss',
#   'text': 'Then, Robert and Jesse were thinking about going to the garden. Robert wanted to give a kiss to Jesse',
#   'IO': 'Jesse',
#   'S': 'Robert',
#   'TEMPLATE_IDX': 3,
#   'C': 'Travis'},
#  {'text': 'Then, Jesse and Robert were thinking about going to the garden. Jesse wanted to give a kiss to Robert',
#   'IO': 'Robert',
#   'S': 'Jesse',
#   'TEMPLATE_IDX': 3},
#  {'[PLACE]': 'school',
#   '[OBJECT]': 'computer',
#   'text': 'Afterwards, Gregory and Kelly went to the school. Gregory gave a computer to Kelly',
#   'IO': 'Kelly',
#   'S': 'Gregory',
#   'TEMPLATE_IDX': 11,
#   'C': 'Crystal'},
#  {'text': 'Afterwards, Kelly and Gregory went to the school. Kelly gave a computer to Gregory',
#   'IO': 'Gregory',
#   'S': 'Kelly',
#   'TEMPLATE_IDX': 11},
#  {'[PLACE]': 'house',
#   '[OBJECT]': 'snack',
#   'text': 'When Richard and Michael got a snack at the house, Michael decided to give the snack to Richard',
#   'IO': 'Richard',
#   'S': 'Michael',
#   'TEMPLATE_IDX': 22,
#   'C': 'Andrew'},
#  {'text': 'When Michael and Richard got a snack at the house, Richard decided to give the snack to Michael',
#   'IO': 'Michael',
#   'S': 'Richard',
#   'TEMPLATE_IDX': 22},
#  {'[PLACE]': 'house',
#   '[OBJECT]': 'ring',
#   'text': 'Then, Amber and Nathan were working at the house. Amber decided to give a ring to Nathan',
#   'IO': 'Nathan',
#   'S': 'Amber',
#   'TEMPLATE_IDX': 2,
#   'C': 'Lindsey'},
#  {'text': 'Then, Nathan and Amber were working at the house. Nathan decided to give a ring to Amber',
#   'IO': 'Amber',
#   'S': 'Nathan',
#   'TEMPLATE_IDX': 2},
#  {'[PLACE]': 'school',
#   '[OBJECT]': 'necklace',
#   'text': 'Then, Cody and Danielle were thinking about going to the school. Danielle wanted to give a necklace to Cody',
#   'IO': 'Cody',
#   'S': 'Danielle',
#   'TEMPLATE_IDX': 18,
#   'C': 'Daniel'},
#  {'text': 'Then, Danielle and Cody were thinking about going to the school. Cody wanted to give a necklace to Danielle',
#   'IO': 'Danielle',
#   'S': 'Cody',
#   'TEMPLATE_IDX': 18},
#  {'[PLACE]': 'store',
#   '[OBJECT]': 'drink',
#   'text': 'The store Andrew and Nicholas went to had a drink. Nicholas gave it to Andrew',
#   'IO': 'Andrew',
#   'S': 'Nicholas',
#   'TEMPLATE_IDX': 28,
#   'C': 'Kimberly'},
#  {'text': 'The store Nicholas and Andrew went to had a drink. Andrew gave it to Nicholas',
#   'IO': 'Nicholas',
#   'S': 'Andrew',
#   'TEMPLATE_IDX': 28},
#  {'[PLACE]': 'hospital',
#   '[OBJECT]': 'snack',
#   'text': 'While Christopher and Kenneth were commuting to the hospital, Christopher gave a snack to Kenneth',
#   'IO': 'Kenneth',
#   'S': 'Christopher',
#   'TEMPLATE_IDX': 9,
#   'C': 'Tyler'},
#  {'text': 'While Kenneth and Christopher were commuting to the hospital, Kenneth gave a snack to Christopher',
#   'IO': 'Christopher',
#   'S': 'Kenneth',
#   'TEMPLATE_IDX': 9},
#  {'[PLACE]': 'school',
#   '[OBJECT]': 'drink',
#   'text': 'After Jesse and Joseph went to the school, Joseph gave a drink to Jesse',
#   'IO': 'Jesse',
#   'S': 'Joseph',
#   'TEMPLATE_IDX': 20,
#   'C': 'Amy'},
#  {'text': 'After Joseph and Jesse went to the school, Jesse gave a drink to Joseph',
#   'IO': 'Joseph',
#   'S': 'Jesse',
#   'TEMPLATE_IDX': 20},
#  {'[PLACE]': 'store',
#   '[OBJECT]': 'snack',
#   'text': 'Then, Bradley and Erica had a long argument, and afterwards Erica said to Bradley',
#   'IO': 'Bradley',
#   'S': 'Erica',
#   'TEMPLATE_IDX': 19,
#   'C': 'Kristen'},
#  {'text': 'Then, Erica and Bradley had a long argument, and afterwards Bradley said to Erica',
#   'IO': 'Erica',
#   'S': 'Bradley',
#   'TEMPLATE_IDX': 19},
#  {'[PLACE]': 'restaurant',
#   '[OBJECT]': 'drink',
#   'text': 'Then, Samuel and Jamie had a long argument, and afterwards Jamie said to Samuel',
#   'IO': 'Samuel',
#   'S': 'Jamie',
#   'TEMPLATE_IDX': 19,
#   'C': 'Stephanie'},
#  {'text': 'Then, Jamie and Samuel had a long argument, and afterwards Samuel said to Jamie',
#   'IO': 'Jamie',
#   'S': 'Samuel',
#   'TEMPLATE_IDX': 19},
#  {'[PLACE]': 'hospital',
#   '[OBJECT]': 'snack',
#   'text': 'Then, Robert and Anthony were thinking about going to the hospital. Anthony wanted to give a snack to Robert',
#   'IO': 'Robert',
#   'S': 'Anthony',
#   'TEMPLATE_IDX': 18,
#   'C': 'Amy'},
#  {'text': 'Then, Anthony and Robert were thinking about going to the hospital. Robert wanted to give a snack to Anthony',
#   'IO': 'Anthony',
#   'S': 'Robert',
#   'TEMPLATE_IDX': 18},
#  {'[PLACE]': 'store',
#   '[OBJECT]': 'computer',
#   'text': 'Then, Jose and David had a long argument. Afterwards David said to Jose',
#   'IO': 'Jose',
#   'S': 'David',
#   'TEMPLATE_IDX': 27,
#   'C': 'Shannon'},
#  {'text': 'Then, David and Jose had a long argument. Afterwards Jose said to David',
#   'IO': 'David',
#   'S': 'Jose',
#   'TEMPLATE_IDX': 27},
#  {'[PLACE]': 'school',
#   '[OBJECT]': 'snack',
#   'text': 'Then, Laura and Tiffany were thinking about going to the school. Laura wanted to give a snack to Tiffany',
#   'IO': 'Tiffany',
#   'S': 'Laura',
#   'TEMPLATE_IDX': 3,
#   'C': 'Amy'},
#  {'text': 'Then, Tiffany and Laura were thinking about going to the school. Tiffany wanted to give a snack to Laura',
#   'IO': 'Laura',
#   'S': 'Tiffany',
#   'TEMPLATE_IDX': 3},
#  {'[PLACE]': 'garden',
#   '[OBJECT]': 'drink',
#   'text': 'After the lunch, Crystal and James went to the garden. James gave a drink to Crystal',
#   'IO': 'Crystal',
#   'S': 'James',
#   'TEMPLATE_IDX': 25,
#   'C': 'Kelly'},
#  {'text': 'After the lunch, James and Crystal went to the garden. Crystal gave a drink to James',
#   'IO': 'James',
#   'S': 'Crystal',
#   'TEMPLATE_IDX': 25},
#  {'[PLACE]': 'restaurant',
#   '[OBJECT]': 'computer',
#   'text': 'Then, Lisa and Richard were working at the restaurant. Lisa decided to give a computer to Richard',
#   'IO': 'Richard',
#   'S': 'Lisa',
#   'TEMPLATE_IDX': 2,
#   'C': 'Christina'},
#  {'text': 'Then, Richard and Lisa were working at the restaurant. Richard decided to give a computer to Lisa',
#   'IO': 'Lisa',
#   'S': 'Richard',
#   'TEMPLATE_IDX': 2},
#  {'[PLACE]': 'garden',
#   '[OBJECT]': 'necklace',
#   'text': 'While Kyle and Brandon were commuting to the garden, Brandon gave a necklace to Kyle',
#   'IO': 'Kyle',
#   'S': 'Brandon',
#   'TEMPLATE_IDX': 24,
#   'C': 'Melissa'},
#  {'text': 'While Brandon and Kyle were commuting to the garden, Kyle gave a necklace to Brandon',
#   'IO': 'Brandon',
#   'S': 'Kyle',
#   'TEMPLATE_IDX': 24},
#  {'[PLACE]': 'store',
#   '[OBJECT]': 'kiss',
#   'text': 'The store Mary and Jason went to had a kiss. Mary gave it to Jason',
#   'IO': 'Jason',
#   'S': 'Mary',
#   'TEMPLATE_IDX': 13,
#   'C': 'Nicole'},
#  {'text': 'The store Jason and Mary went to had a kiss. Jason gave it to Mary',
#   'IO': 'Mary',
#   'S': 'Jason',
#   'TEMPLATE_IDX': 13},
#  {'[PLACE]': 'store',
#   '[OBJECT]': 'drink',
#   'text': 'After the lunch, Tyler and Travis went to the store. Travis gave a drink to Tyler',
#   'IO': 'Tyler',
#   'S': 'Travis',
#   'TEMPLATE_IDX': 25,
#   'C': 'Brian'},
#  {'text': 'After the lunch, Travis and Tyler went to the store. Tyler gave a drink to Travis',
#   'IO': 'Travis',
#   'S': 'Tyler',
#   'TEMPLATE_IDX': 25},
#  {'[PLACE]': 'school',
#   '[OBJECT]': 'necklace',
#   'text': 'Then, William and Steven had a lot of fun at the school. Steven gave a necklace to William',
#   'IO': 'William',
#   'S': 'Steven',
#   'TEMPLATE_IDX': 16,
#   'C': 'Andrew'},
#  {'text': 'Then, Steven and William had a lot of fun at the school. William gave a necklace to Steven',
#   'IO': 'Steven',
#   'S': 'William',
#   'TEMPLATE_IDX': 16},
#  {'[PLACE]': 'restaurant',
#   '[OBJECT]': 'bone',
#   'text': 'Then, Joshua and Travis went to the restaurant. Travis gave a bone to Joshua',
#   'IO': 'Joshua',
#   'S': 'Travis',
#   'TEMPLATE_IDX': 15,
#   'C': 'Lindsey'},
#  {'text': 'Then, Travis and Joshua went to the restaurant. Joshua gave a bone to Travis',
#   'IO': 'Travis',
#   'S': 'Joshua',
#   'TEMPLATE_IDX': 15},
#  {'[PLACE]': 'store',
#   '[OBJECT]': 'basketball',
#   'text': 'Then, Kyle and Eric had a long argument, and afterwards Eric said to Kyle',
#   'IO': 'Kyle',
#   'S': 'Eric',
#   'TEMPLATE_IDX': 19,
#   'C': 'Nicole'},
#  {'text': 'Then, Eric and Kyle had a long argument, and afterwards Kyle said to Eric',
#   'IO': 'Eric',
#   'S': 'Kyle',
#   'TEMPLATE_IDX': 19},
#  {'[PLACE]': 'office',
#   '[OBJECT]': 'ring',
#   'text': 'Then, Patrick and Jose were thinking about going to the office. Patrick wanted to give a ring to Jose',
#   'IO': 'Jose',
#   'S': 'Patrick',
#   'TEMPLATE_IDX': 3,
#   'C': 'Samantha'},
#  {'text': 'Then, Jose and Patrick were thinking about going to the office. Jose wanted to give a ring to Patrick',
#   'IO': 'Patrick',
#   'S': 'Jose',
#   'TEMPLATE_IDX': 3},
#  {'[PLACE]': 'station',
#   '[OBJECT]': 'kiss',
#   'text': 'When Katie and Kristen got a kiss at the station, Katie decided to give the kiss to Kristen',
#   'IO': 'Kristen',
#   'S': 'Katie',
#   'TEMPLATE_IDX': 7,
#   'C': 'James'},
#  {'text': 'When Kristen and Katie got a kiss at the station, Kristen decided to give the kiss to Katie',
#   'IO': 'Katie',
#   'S': 'Kristen',
#   'TEMPLATE_IDX': 7},
#  {'[PLACE]': 'hospital',
#   '[OBJECT]': 'kiss',
#   'text': 'Then, Erica and Elizabeth were working at the hospital. Elizabeth decided to give a kiss to Erica',
#   'IO': 'Erica',
#   'S': 'Elizabeth',
#   'TEMPLATE_IDX': 17,
#   'C': 'Bradley'},
#  {'text': 'Then, Elizabeth and Erica were working at the hospital. Erica decided to give a kiss to Elizabeth',
#   'IO': 'Elizabeth',
#   'S': 'Erica',
#   'TEMPLATE_IDX': 17},
#  {'[PLACE]': 'garden',
#   '[OBJECT]': 'basketball',
#   'text': 'Then, Christina and Nathan had a lot of fun at the garden. Christina gave a basketball to Nathan',
#   'IO': 'Nathan',
#   'S': 'Christina',
#   'TEMPLATE_IDX': 1,
#   'C': 'Anthony'},
#  {'text': 'Then, Nathan and Christina had a lot of fun at the garden. Nathan gave a basketball to Christina',
#   'IO': 'Christina',
#   'S': 'Nathan',
#   'TEMPLATE_IDX': 1},
#  {'[PLACE]': 'station',
#   '[OBJECT]': 'drink',
#   'text': 'When Tyler and Richard got a drink at the station, Tyler decided to give the drink to Richard',
#   'IO': 'Richard',
#   'S': 'Tyler',
#   'TEMPLATE_IDX': 7,
#   'C': 'Benjamin'},
#  {'text': 'When Richard and Tyler got a drink at the station, Richard decided to give the drink to Tyler',
#   'IO': 'Tyler',
#   'S': 'Richard',
#   'TEMPLATE_IDX': 7},
#  {'[PLACE]': 'station',
#   '[OBJECT]': 'kiss',
#   'text': 'While Amber and Erin were commuting to the station, Amber gave a kiss to Erin',
#   'IO': 'Erin',
#   'S': 'Amber',
#   'TEMPLATE_IDX': 9,
#   'C': 'Patrick'},
#  {'text': 'While Erin and Amber were commuting to the station, Erin gave a kiss to Amber',
#   'IO': 'Amber',
#   'S': 'Erin',
#   'TEMPLATE_IDX': 9},
#  {'[PLACE]': 'house',
#   '[OBJECT]': 'ring',
#   'text': 'Then, Jamie and Kelly were thinking about going to the house. Kelly wanted to give a ring to Jamie',
#   'IO': 'Jamie',
#   'S': 'Kelly',
#   'TEMPLATE_IDX': 18,
#   'C': 'Stephen'},
#  {'text': 'Then, Kelly and Jamie were thinking about going to the house. Jamie wanted to give a ring to Kelly',
#   'IO': 'Kelly',
#   'S': 'Jamie',
#   'TEMPLATE_IDX': 18},
#  {'[PLACE]': 'restaurant',
#   '[OBJECT]': 'computer',
#   'text': 'Then, Erin and Samantha had a long argument, and afterwards Samantha said to Erin',
#   'IO': 'Erin',
#   'S': 'Samantha',
#   'TEMPLATE_IDX': 19,
#   'C': 'Adam'},
#  {'text': 'Then, Samantha and Erin had a long argument, and afterwards Erin said to Samantha',
#   'IO': 'Samantha',
#   'S': 'Erin',
#   'TEMPLATE_IDX': 19},
#  {'[PLACE]': 'station',
#   '[OBJECT]': 'basketball',
#   'text': 'The station Amanda and Michael went to had a basketball. Amanda gave it to Michael',
#   'IO': 'Michael',
#   'S': 'Amanda',
#   'TEMPLATE_IDX': 13,
#   'C': 'Timothy'},
#  {'text': 'The station Michael and Amanda went to had a basketball. Michael gave it to Amanda',
#   'IO': 'Amanda',
#   'S': 'Michael',
#   'TEMPLATE_IDX': 13},
#  {'[PLACE]': 'garden',
#   '[OBJECT]': 'ring',
#   'text': 'The garden Daniel and Kimberly went to had a ring. Daniel gave it to Kimberly',
#   'IO': 'Kimberly',
#   'S': 'Daniel',
#   'TEMPLATE_IDX': 13,
#   'C': 'Lindsey'},
#  {'text': 'The garden Kimberly and Daniel went to had a ring. Kimberly gave it to Daniel',
#   'IO': 'Daniel',
#   'S': 'Kimberly',
#   'TEMPLATE_IDX': 13},
#  {'[PLACE]': 'restaurant',
#   '[OBJECT]': 'snack',
#   'text': 'After Emily and Ryan went to the restaurant, Ryan gave a snack to Emily',
#   'IO': 'Emily',
#   'S': 'Ryan',
#   'TEMPLATE_IDX': 20,
#   'C': 'David'},
#  {'text': 'After Ryan and Emily went to the restaurant, Emily gave a snack to Ryan',
#   'IO': 'Ryan',
#   'S': 'Emily',
#   'TEMPLATE_IDX': 20},
#  {'[PLACE]': 'garden',
#   '[OBJECT]': 'snack',
#   'text': 'When Tiffany and Sara got a snack at the garden, Tiffany decided to give the snack to Sara',
#   'IO': 'Sara',
#   'S': 'Tiffany',
#   'TEMPLATE_IDX': 7,
#   'C': 'Daniel'},
#  {'text': 'When Sara and Tiffany got a snack at the garden, Sara decided to give the snack to Tiffany',
#   'IO': 'Tiffany',
#   'S': 'Sara',
#   'TEMPLATE_IDX': 7},
#  {'[PLACE]': 'store',
#   '[OBJECT]': 'snack',
#   'text': 'The store William and Lindsay went to had a snack. Lindsay gave it to William',
#   'IO': 'William',
#   'S': 'Lindsay',
#   'TEMPLATE_IDX': 28,
#   'C': 'Scott'},
#  {'text': 'The store Lindsay and William went to had a snack. William gave it to Lindsay',
#   'IO': 'Lindsay',
#   'S': 'William',
#   'TEMPLATE_IDX': 28},
#  {'[PLACE]': 'house',
#   '[OBJECT]': 'ring',
#   'text': 'While Rachel and Robert were commuting to the house, Rachel gave a ring to Robert',
#   'IO': 'Robert',
#   'S': 'Rachel',
#   'TEMPLATE_IDX': 9,
#   'C': 'Lauren'},
#  {'text': 'While Robert and Rachel were commuting to the house, Robert gave a ring to Rachel',
#   'IO': 'Rachel',
#   'S': 'Robert',
#   'TEMPLATE_IDX': 9},
#  {'[PLACE]': 'office',
#   '[OBJECT]': 'basketball',
#   'text': 'When Katie and Amy got a basketball at the office, Amy decided to give it to Katie',
#   'IO': 'Katie',
#   'S': 'Amy',
#   'TEMPLATE_IDX': 21,
#   'C': 'Crystal'},
#  {'text': 'When Amy and Katie got a basketball at the office, Katie decided to give it to Amy',
#   'IO': 'Amy',
#   'S': 'Katie',
#   'TEMPLATE_IDX': 21},
#  {'[PLACE]': 'house',
#   '[OBJECT]': 'computer',
#   'text': 'Then, Joseph and Ashley had a long argument. Afterwards Ashley said to Joseph',
#   'IO': 'Joseph',
#   'S': 'Ashley',
#   'TEMPLATE_IDX': 27,
#   'C': 'Aaron'},
#  {'text': 'Then, Ashley and Joseph had a long argument. Afterwards Joseph said to Ashley',
#   'IO': 'Ashley',
#   'S': 'Joseph',
#   'TEMPLATE_IDX': 27},
#  {'[PLACE]': 'garden',
#   '[OBJECT]': 'basketball',
#   'text': 'Then, Jose and Matthew were thinking about going to the garden. Matthew wanted to give a basketball to Jose',
#   'IO': 'Jose',
#   'S': 'Matthew',
#   'TEMPLATE_IDX': 18,
#   'C': 'Alicia'},
#  {'text': 'Then, Matthew and Jose were thinking about going to the garden. Jose wanted to give a basketball to Matthew',
#   'IO': 'Matthew',
#   'S': 'Jose',
#   'TEMPLATE_IDX': 18},
#  {'[PLACE]': 'restaurant',
#   '[OBJECT]': 'necklace',
#   'text': 'Then, Sara and Patrick were working at the restaurant. Sara decided to give a necklace to Patrick',
#   'IO': 'Patrick',
#   'S': 'Sara',
#   'TEMPLATE_IDX': 2,
#   'C': 'Tyler'},
#  {'text': 'Then, Patrick and Sara were working at the restaurant. Patrick decided to give a necklace to Sara',
#   'IO': 'Sara',
#   'S': 'Patrick',
#   'TEMPLATE_IDX': 2},
#  {'[PLACE]': 'restaurant',
#   '[OBJECT]': 'computer',
#   'text': 'After Crystal and Charles went to the restaurant, Charles gave a computer to Crystal',
#   'IO': 'Crystal',
#   'S': 'Charles',
#   'TEMPLATE_IDX': 20,
#   'C': 'Christina'},
#  {'text': 'After Charles and Crystal went to the restaurant, Crystal gave a computer to Charles',
#   'IO': 'Charles',
#   'S': 'Crystal',
#   'TEMPLATE_IDX': 20},
#  {'[PLACE]': 'house',
#   '[OBJECT]': 'computer',
#   'text': 'Then, Lisa and Danielle were working at the house. Danielle decided to give a computer to Lisa',
#   'IO': 'Lisa',
#   'S': 'Danielle',
#   'TEMPLATE_IDX': 17,
#   'C': 'Travis'},
#  {'text': 'Then, Danielle and Lisa were working at the house. Lisa decided to give a computer to Danielle',
#   'IO': 'Danielle',
#   'S': 'Lisa',
#   'TEMPLATE_IDX': 17},
#  {'[PLACE]': 'restaurant',
#   '[OBJECT]': 'basketball',
#   'text': 'Afterwards, Angela and Jamie went to the restaurant. Angela gave a basketball to Jamie',
#   'IO': 'Jamie',
#   'S': 'Angela',
#   'TEMPLATE_IDX': 11,
#   'C': 'Andrew'},
#  {'text': 'Afterwards, Jamie and Angela went to the restaurant. Jamie gave a basketball to Angela',
#   'IO': 'Angela',
#   'S': 'Jamie',
#   'TEMPLATE_IDX': 11},
#  {'[PLACE]': 'restaurant',
#   '[OBJECT]': 'kiss',
#   'text': 'After the lunch, Paul and Ryan went to the restaurant. Paul gave a kiss to Ryan',
#   'IO': 'Ryan',
#   'S': 'Paul',
#   'TEMPLATE_IDX': 10,
#   'C': 'Katie'},
#  {'text': 'After the lunch, Ryan and Paul went to the restaurant. Ryan gave a kiss to Paul',
#   'IO': 'Paul',
#   'S': 'Ryan',
#   'TEMPLATE_IDX': 10},
#  {'[PLACE]': 'hospital',
#   '[OBJECT]': 'basketball',
#   'text': 'Then, Angela and Mary had a lot of fun at the hospital. Mary gave a basketball to Angela',
#   'IO': 'Angela',
#   'S': 'Mary',
#   'TEMPLATE_IDX': 16,
#   'C': 'Jason'},
#  {'text': 'Then, Mary and Angela had a lot of fun at the hospital. Angela gave a basketball to Mary',
#   'IO': 'Mary',
#   'S': 'Angela',
#   'TEMPLATE_IDX': 16},
#  {'[PLACE]': 'restaurant',
#   '[OBJECT]': 'bone',
#   'text': 'Then, Tiffany and Scott had a long argument, and afterwards Scott said to Tiffany',
#   'IO': 'Tiffany',
#   'S': 'Scott',
#   'TEMPLATE_IDX': 19,
#   'C': 'Joseph'},
#  {'text': 'Then, Scott and Tiffany had a long argument, and afterwards Tiffany said to Scott',
#   'IO': 'Scott',
#   'S': 'Tiffany',
#   'TEMPLATE_IDX': 19},
#  {'[PLACE]': 'store',
#   '[OBJECT]': 'necklace',
#   'text': 'When Andrew and James got a necklace at the store, Andrew decided to give the necklace to James',
#   'IO': 'James',
#   'S': 'Andrew',
#   'TEMPLATE_IDX': 7,
#   'C': 'Courtney'},
#  {'text': 'When James and Andrew got a necklace at the store, James decided to give the necklace to Andrew',
#   'IO': 'Andrew',
#   'S': 'James',
#   'TEMPLATE_IDX': 7},
#  {'[PLACE]': 'house',
#   '[OBJECT]': 'basketball',
#   'text': 'Then, Samuel and Cody were working at the house. Cody decided to give a basketball to Samuel',
#   'IO': 'Samuel',
#   'S': 'Cody',
#   'TEMPLATE_IDX': 17,
#   'C': 'John'},
#  {'text': 'Then, Cody and Samuel were working at the house. Samuel decided to give a basketball to Cody',
#   'IO': 'Cody',
#   'S': 'Samuel',
#   'TEMPLATE_IDX': 17},
#  {'[PLACE]': 'school',
#   '[OBJECT]': 'kiss',
#   'text': 'While Justin and Sean were working at the school, Justin gave a kiss to Sean',
#   'IO': 'Sean',
#   'S': 'Justin',
#   'TEMPLATE_IDX': 8,
#   'C': 'Tiffany'},
#  {'text': 'While Sean and Justin were working at the school, Sean gave a kiss to Justin',
#   'IO': 'Justin',
#   'S': 'Sean',
#   'TEMPLATE_IDX': 8},
#  {'[PLACE]': 'office',
#   '[OBJECT]': 'ring',
#   'text': 'Then, Bryan and Jessica had a long argument, and afterwards Bryan said to Jessica',
#   'IO': 'Jessica',
#   'S': 'Bryan',
#   'TEMPLATE_IDX': 4,
#   'C': 'Amy'},
#  {'text': 'Then, Jessica and Bryan had a long argument, and afterwards Jessica said to Bryan',
#   'IO': 'Bryan',
#   'S': 'Jessica',
#   'TEMPLATE_IDX': 4},
#  {'[PLACE]': 'restaurant',
#   '[OBJECT]': 'bone',
#   'text': 'Then, Christine and Mark had a long argument. Afterwards Mark said to Christine',
#   'IO': 'Christine',
#   'S': 'Mark',
#   'TEMPLATE_IDX': 27,
#   'C': 'Laura'},
#  {'text': 'Then, Mark and Christine had a long argument. Afterwards Christine said to Mark',
#   'IO': 'Mark',
#   'S': 'Christine',
#   'TEMPLATE_IDX': 27},
#  {'[PLACE]': 'office',
#   '[OBJECT]': 'computer',
#   'text': 'Afterwards, Alicia and Steven went to the office. Alicia gave a computer to Steven',
#   'IO': 'Steven',
#   'S': 'Alicia',
#   'TEMPLATE_IDX': 11,
#   'C': 'Katherine'},
#  {'text': 'Afterwards, Steven and Alicia went to the office. Steven gave a computer to Alicia',
#   'IO': 'Alicia',
#   'S': 'Steven',
#   'TEMPLATE_IDX': 11},
#  {'[PLACE]': 'restaurant',
#   '[OBJECT]': 'computer',
#   'text': 'Then, Bradley and Bryan had a long argument. Afterwards Bradley said to Bryan',
#   'IO': 'Bryan',
#   'S': 'Bradley',
#   'TEMPLATE_IDX': 12,
#   'C': 'Matthew'},
#  {'text': 'Then, Bryan and Bradley had a long argument. Afterwards Bryan said to Bradley',
#   'IO': 'Bradley',
#   'S': 'Bryan',
#   'TEMPLATE_IDX': 12},
#  {'[PLACE]': 'store',
#   '[OBJECT]': 'snack',
#   'text': 'When Benjamin and Brandon got a snack at the store, Brandon decided to give it to Benjamin',
#   'IO': 'Benjamin',
#   'S': 'Brandon',
#   'TEMPLATE_IDX': 21,
#   'C': 'Amy'},
#  {'text': 'When Brandon and Benjamin got a snack at the store, Benjamin decided to give it to Brandon',
#   'IO': 'Brandon',
#   'S': 'Benjamin',
#   'TEMPLATE_IDX': 21},
#  {'[PLACE]': 'house',
#   '[OBJECT]': 'drink',
#   'text': 'The house Patrick and Sean went to had a drink. Sean gave it to Patrick',
#   'IO': 'Patrick',
#   'S': 'Sean',
#   'TEMPLATE_IDX': 28,
#   'C': 'Thomas'},
#  {'text': 'The house Sean and Patrick went to had a drink. Patrick gave it to Sean',
#   'IO': 'Sean',
#   'S': 'Patrick',
#   'TEMPLATE_IDX': 28},
#  {'[PLACE]': 'hospital',
#   '[OBJECT]': 'kiss',
#   'text': 'After the lunch, Richard and Adam went to the hospital. Richard gave a kiss to Adam',
#   'IO': 'Adam',
#   'S': 'Richard',
#   'TEMPLATE_IDX': 10,
#   'C': 'Rachel'},
#  {'text': 'After the lunch, Adam and Richard went to the hospital. Adam gave a kiss to Richard',
#   'IO': 'Richard',
#   'S': 'Adam',
#   'TEMPLATE_IDX': 10},
#  {'[PLACE]': 'garden',
#   '[OBJECT]': 'ring',
#   'text': 'After Rebecca and Jonathan went to the garden, Rebecca gave a ring to Jonathan',
#   'IO': 'Jonathan',
#   'S': 'Rebecca',
#   'TEMPLATE_IDX': 5,
#   'C': 'Dustin'},
#  {'text': 'After Jonathan and Rebecca went to the garden, Jonathan gave a ring to Rebecca',
#   'IO': 'Rebecca',
#   'S': 'Jonathan',
#   'TEMPLATE_IDX': 5},
#  {'[PLACE]': 'hospital',
#   '[OBJECT]': 'basketball',
#   'text': 'Afterwards, Shannon and Tyler went to the hospital. Shannon gave a basketball to Tyler',
#   'IO': 'Tyler',
#   'S': 'Shannon',
#   'TEMPLATE_IDX': 11,
#   'C': 'Brandon'},
#  {'text': 'Afterwards, Tyler and Shannon went to the hospital. Tyler gave a basketball to Shannon',
#   'IO': 'Shannon',
#   'S': 'Tyler',
#   'TEMPLATE_IDX': 11},
#  {'[PLACE]': 'house',
#   '[OBJECT]': 'kiss',
#   'text': 'Then, Stephanie and Jose had a lot of fun at the house. Stephanie gave a kiss to Jose',
#   'IO': 'Jose',
#   'S': 'Stephanie',
#   'TEMPLATE_IDX': 1,
#   'C': 'Kenneth'},
#  {'text': 'Then, Jose and Stephanie had a lot of fun at the house. Jose gave a kiss to Stephanie',
#   'IO': 'Stephanie',
#   'S': 'Jose',
#   'TEMPLATE_IDX': 1},
#  {'[PLACE]': 'house',
#   '[OBJECT]': 'computer',
#   'text': 'After Mary and Travis went to the house, Travis gave a computer to Mary',
#   'IO': 'Mary',
#   'S': 'Travis',
#   'TEMPLATE_IDX': 20,
#   'C': 'Kyle'},
#  {'text': 'After Travis and Mary went to the house, Mary gave a computer to Travis',
#   'IO': 'Travis',
#   'S': 'Mary',
#   'TEMPLATE_IDX': 20},
#  {'[PLACE]': 'office',
#   '[OBJECT]': 'basketball',
#   'text': 'After Courtney and Alicia went to the office, Courtney gave a basketball to Alicia',
#   'IO': 'Alicia',
#   'S': 'Courtney',
#   'TEMPLATE_IDX': 5,
#   'C': 'Christopher'},
#  {'text': 'After Alicia and Courtney went to the office, Alicia gave a basketball to Courtney',
#   'IO': 'Courtney',
#   'S': 'Alicia',
#   'TEMPLATE_IDX': 5},
#  {'[PLACE]': 'office',
#   '[OBJECT]': 'necklace',
#   'text': 'Then, Kimberly and Andrea went to the office. Kimberly gave a necklace to Andrea',
#   'IO': 'Andrea',
#   'S': 'Kimberly',
#   'TEMPLATE_IDX': 0,
#   'C': 'Kristen'},
#  {'text': 'Then, Andrea and Kimberly went to the office. Andrea gave a necklace to Kimberly',
#   'IO': 'Kimberly',
#   'S': 'Andrea',
#   'TEMPLATE_IDX': 0},
#  {'[PLACE]': 'hospital',
#   '[OBJECT]': 'computer',
#   'text': 'After Angela and Sean went to the hospital, Sean gave a computer to Angela',
#   'IO': 'Angela',
#   'S': 'Sean',
#   'TEMPLATE_IDX': 20,
#   'C': 'Katherine'},
#  {'text': 'After Sean and Angela went to the hospital, Angela gave a computer to Sean',
#   'IO': 'Sean',
#   'S': 'Angela',
#   'TEMPLATE_IDX': 20},
#  {'[PLACE]': 'restaurant',
#   '[OBJECT]': 'ring',
#   'text': 'Then, Bradley and Amber had a long argument. Afterwards Amber said to Bradley',
#   'IO': 'Bradley',
#   'S': 'Amber',
#   'TEMPLATE_IDX': 27,
#   'C': 'Justin'},
#  {'text': 'Then, Amber and Bradley had a long argument. Afterwards Bradley said to Amber',
#   'IO': 'Amber',
#   'S': 'Bradley',
#   'TEMPLATE_IDX': 27},
#  {'[PLACE]': 'house',
#   '[OBJECT]': 'bone',
#   'text': 'Friends Vanessa and David found a bone at the house. Vanessa gave it to David',
#   'IO': 'David',
#   'S': 'Vanessa',
#   'TEMPLATE_IDX': 14,
#   'C': 'Gregory'},
#  {'text': 'Friends David and Vanessa found a bone at the house. David gave it to Vanessa',
#   'IO': 'Vanessa',
#   'S': 'David',
#   'TEMPLATE_IDX': 14},
#  {'[PLACE]': 'school',
#   '[OBJECT]': 'necklace',
#   'text': 'When Bradley and Lisa got a necklace at the school, Bradley decided to give it to Lisa',
#   'IO': 'Lisa',
#   'S': 'Bradley',
#   'TEMPLATE_IDX': 6,
#   'C': 'Nicholas'},
#  {'text': 'When Lisa and Bradley got a necklace at the school, Lisa decided to give it to Bradley',
#   'IO': 'Bradley',
#   'S': 'Lisa',
#   'TEMPLATE_IDX': 6},
#  {'[PLACE]': 'station',
#   '[OBJECT]': 'basketball',
#   'text': 'Friends Eric and James found a basketball at the station. Eric gave it to James',
#   'IO': 'James',
#   'S': 'Eric',
#   'TEMPLATE_IDX': 14,
#   'C': 'Crystal'},
#  {'text': 'Friends James and Eric found a basketball at the station. James gave it to Eric',
#   'IO': 'Eric',
#   'S': 'James',
#   'TEMPLATE_IDX': 14},
#  {'[PLACE]': 'hospital',
#   '[OBJECT]': 'basketball',
#   'text': 'While Sara and Tiffany were commuting to the hospital, Sara gave a basketball to Tiffany',
#   'IO': 'Tiffany',
#   'S': 'Sara',
#   'TEMPLATE_IDX': 9,
#   'C': 'Kyle'},
#  {'text': 'While Tiffany and Sara were commuting to the hospital, Tiffany gave a basketball to Sara',
#   'IO': 'Sara',
#   'S': 'Tiffany',
#   'TEMPLATE_IDX': 9},
#  {'[PLACE]': 'garden',
#   '[OBJECT]': 'kiss',
#   'text': 'Then, Rebecca and Christopher had a lot of fun at the garden. Christopher gave a kiss to Rebecca',
#   'IO': 'Rebecca',
#   'S': 'Christopher',
#   'TEMPLATE_IDX': 16,
#   'C': 'Mary'},
#  {'text': 'Then, Christopher and Rebecca had a lot of fun at the garden. Rebecca gave a kiss to Christopher',
#   'IO': 'Christopher',
#   'S': 'Rebecca',
#   'TEMPLATE_IDX': 16},
#  {'[PLACE]': 'garden',
#   '[OBJECT]': 'bone',
#   'text': 'Then, Samantha and Rebecca had a lot of fun at the garden. Rebecca gave a bone to Samantha',
#   'IO': 'Samantha',
#   'S': 'Rebecca',
#   'TEMPLATE_IDX': 16,
#   'C': 'Lindsay'},
#  {'text': 'Then, Rebecca and Samantha had a lot of fun at the garden. Samantha gave a bone to Rebecca',
#   'IO': 'Rebecca',
#   'S': 'Samantha',
#   'TEMPLATE_IDX': 16},
#  {'[PLACE]': 'hospital',
#   '[OBJECT]': 'kiss',
#   'text': 'Then, Alicia and Kyle were thinking about going to the hospital. Kyle wanted to give a kiss to Alicia',
#   'IO': 'Alicia',
#   'S': 'Kyle',
#   'TEMPLATE_IDX': 18,
#   'C': 'Kelly'},
#  {'text': 'Then, Kyle and Alicia were thinking about going to the hospital. Alicia wanted to give a kiss to Kyle',
#   'IO': 'Kyle',
#   'S': 'Alicia',
#   'TEMPLATE_IDX': 18},
#  {'[PLACE]': 'restaurant',
#   '[OBJECT]': 'drink',
#   'text': 'Then, Shannon and Gregory were thinking about going to the restaurant. Shannon wanted to give a drink to Gregory',
#   'IO': 'Gregory',
#   'S': 'Shannon',
#   'TEMPLATE_IDX': 3,
#   'C': 'Elizabeth'},
#  {'text': 'Then, Gregory and Shannon were thinking about going to the restaurant. Gregory wanted to give a drink to Shannon',
#   'IO': 'Shannon',
#   'S': 'Gregory',
#   'TEMPLATE_IDX': 3},
#  {'[PLACE]': 'garden',
#   '[OBJECT]': 'necklace',
#   'text': 'When Richard and Timothy got a necklace at the garden, Richard decided to give the necklace to Timothy',
#   'IO': 'Timothy',
#   'S': 'Richard',
#   'TEMPLATE_IDX': 7,
#   'C': 'Sarah'},
#  {'text': 'When Timothy and Richard got a necklace at the garden, Timothy decided to give the necklace to Richard',
#   'IO': 'Richard',
#   'S': 'Timothy',
#   'TEMPLATE_IDX': 7},
#  {'[PLACE]': 'garden',
#   '[OBJECT]': 'basketball',
#   'text': 'The garden John and Vanessa went to had a basketball. John gave it to Vanessa',
#   'IO': 'Vanessa',
#   'S': 'John',
#   'TEMPLATE_IDX': 13,
#   'C': 'Nathan'},
#  {'text': 'The garden Vanessa and John went to had a basketball. Vanessa gave it to John',
#   'IO': 'John',
#   'S': 'Vanessa',
#   'TEMPLATE_IDX': 13},
#  {'[PLACE]': 'school',
#   '[OBJECT]': 'snack',
#   'text': 'Then, Michael and Daniel had a long argument, and afterwards Michael said to Daniel',
#   'IO': 'Daniel',
#   'S': 'Michael',
#   'TEMPLATE_IDX': 4,
#   'C': 'Eric'},
#  {'text': 'Then, Daniel and Michael had a long argument, and afterwards Daniel said to Michael',
#   'IO': 'Michael',
#   'S': 'Daniel',
#   'TEMPLATE_IDX': 4},
#  {'[PLACE]': 'office',
#   '[OBJECT]': 'drink',
#   'text': 'Then, Kelly and Jeffrey went to the office. Jeffrey gave a drink to Kelly',
#   'IO': 'Kelly',
#   'S': 'Jeffrey',
#   'TEMPLATE_IDX': 15,
#   'C': 'William'},
#  {'text': 'Then, Jeffrey and Kelly went to the office. Kelly gave a drink to Jeffrey',
#   'IO': 'Jeffrey',
#   'S': 'Kelly',
#   'TEMPLATE_IDX': 15},
#  {'[PLACE]': 'house',
#   '[OBJECT]': 'ring',
#   'text': 'When Lisa and Jonathan got a ring at the house, Jonathan decided to give it to Lisa',
#   'IO': 'Lisa',
#   'S': 'Jonathan',
#   'TEMPLATE_IDX': 21,
#   'C': 'Samuel'},
#  {'text': 'When Jonathan and Lisa got a ring at the house, Lisa decided to give it to Jonathan',
#   'IO': 'Jonathan',
# ...
#   'IO': 'Melissa',
#   'S': 'Stephanie',
#   'TEMPLATE_IDX': 28,
#   'C': 'Jeremy'},
#  {'text': 'The office Stephanie and Melissa went to had a computer. Melissa gave it to Stephanie',
#   'IO': 'Stephanie',
#   'S': 'Melissa',
#   'TEMPLATE_IDX': 28},
#  {'[PLACE]': 'school',
#   '[OBJECT]': 'necklace',
#   'text': 'Then, Amy and Thomas had a lot of fun at the school. Thomas gave a necklace to Amy',
#   'IO': 'Amy',
#   'S': 'Thomas',
#   'TEMPLATE_IDX': 16,
#   'C': 'Robert'},
#  {'text': 'Then, Thomas and Amy had a lot of fun at the school. Amy gave a necklace to Thomas',
#   'IO': 'Thomas',
#   'S': 'Amy',
#   'TEMPLATE_IDX': 16},
#  {'[PLACE]': 'hospital',
#   '[OBJECT]': 'necklace',
#   'text': 'After the lunch, Jamie and Danielle went to the hospital. Jamie gave a necklace to Danielle',
#   'IO': 'Danielle',
#   'S': 'Jamie',
#   'TEMPLATE_IDX': 10,
#   'C': 'Sean'},
#  {'text': 'After the lunch, Danielle and Jamie went to the hospital. Danielle gave a necklace to Jamie',
#   'IO': 'Jamie',
#   'S': 'Danielle',
#   'TEMPLATE_IDX': 10},
#  {'[PLACE]': 'office',
#   '[OBJECT]': 'kiss',
#   'text': 'The office Nicole and Sara went to had a kiss. Sara gave it to Nicole',
#   'IO': 'Nicole',
#   'S': 'Sara',
#   'TEMPLATE_IDX': 28,
#   'C': 'Jamie'},
#  {'text': 'The office Sara and Nicole went to had a kiss. Nicole gave it to Sara',
#   'IO': 'Sara',
#   'S': 'Nicole',
#   'TEMPLATE_IDX': 28},
#  {'[PLACE]': 'school',
#   '[OBJECT]': 'drink',
#   'text': 'After Erin and Lisa went to the school, Lisa gave a drink to Erin',
#   'IO': 'Erin',
#   'S': 'Lisa',
#   'TEMPLATE_IDX': 20,
#   'C': 'Jeffrey'},
#  {'text': 'After Lisa and Erin went to the school, Erin gave a drink to Lisa',
#   'IO': 'Lisa',
#   'S': 'Erin',
#   'TEMPLATE_IDX': 20},
#  {'[PLACE]': 'store',
#   '[OBJECT]': 'kiss',
#   'text': 'Then, Patrick and Lindsay were thinking about going to the store. Patrick wanted to give a kiss to Lindsay',
#   'IO': 'Lindsay',
#   'S': 'Patrick',
#   'TEMPLATE_IDX': 3,
#   'C': 'Tyler'},
#  {'text': 'Then, Lindsay and Patrick were thinking about going to the store. Lindsay wanted to give a kiss to Patrick',
#   'IO': 'Patrick',
#   'S': 'Lindsay',
#   'TEMPLATE_IDX': 3},
#  {'[PLACE]': 'house',
#   '[OBJECT]': 'necklace',
#   'text': 'After the lunch, Christopher and Sean went to the house. Christopher gave a necklace to Sean',
#   'IO': 'Sean',
#   'S': 'Christopher',
#   'TEMPLATE_IDX': 10,
#   'C': 'Ashley'},
#  {'text': 'After the lunch, Sean and Christopher went to the house. Sean gave a necklace to Christopher',
#   'IO': 'Christopher',
#   'S': 'Sean',
#   'TEMPLATE_IDX': 10},
#  {'[PLACE]': 'house',
#   '[OBJECT]': 'ring',
#   'text': 'While Elizabeth and Kimberly were working at the house, Elizabeth gave a ring to Kimberly',
#   'IO': 'Kimberly',
#   'S': 'Elizabeth',
#   'TEMPLATE_IDX': 8,
#   'C': 'Erica'},
#  {'text': 'While Kimberly and Elizabeth were working at the house, Kimberly gave a ring to Elizabeth',
#   'IO': 'Elizabeth',
#   'S': 'Kimberly',
#   'TEMPLATE_IDX': 8},
#  {'[PLACE]': 'restaurant',
#   '[OBJECT]': 'ring',
#   'text': 'After the lunch, Scott and Travis went to the restaurant. Scott gave a ring to Travis',
#   'IO': 'Travis',
#   'S': 'Scott',
#   'TEMPLATE_IDX': 10,
#   'C': 'Adam'},
#  {'text': 'After the lunch, Travis and Scott went to the restaurant. Travis gave a ring to Scott',
#   'IO': 'Scott',
#   'S': 'Travis',
#   'TEMPLATE_IDX': 10},
#  {'[PLACE]': 'station',
#   '[OBJECT]': 'drink',
#   'text': 'After the lunch, Dustin and Jessica went to the station. Dustin gave a drink to Jessica',
#   'IO': 'Jessica',
#   'S': 'Dustin',
#   'TEMPLATE_IDX': 10,
#   'C': 'Ashley'},
#  {'text': 'After the lunch, Jessica and Dustin went to the station. Jessica gave a drink to Dustin',
#   'IO': 'Dustin',
#   'S': 'Jessica',
#   'TEMPLATE_IDX': 10},
#  {'[PLACE]': 'garden',
#   '[OBJECT]': 'bone',
#   'text': 'While Paul and Adam were commuting to the garden, Adam gave a bone to Paul',
#   'IO': 'Paul',
#   'S': 'Adam',
#   'TEMPLATE_IDX': 24,
#   'C': 'Jeremy'},
#  {'text': 'While Adam and Paul were commuting to the garden, Paul gave a bone to Adam',
#   'IO': 'Adam',
#   'S': 'Paul',
#   'TEMPLATE_IDX': 24},
#  {'[PLACE]': 'store',
#   '[OBJECT]': 'ring',
#   'text': 'Then, Thomas and Ashley went to the store. Thomas gave a ring to Ashley',
#   'IO': 'Ashley',
#   'S': 'Thomas',
#   'TEMPLATE_IDX': 0,
#   'C': 'Jacob'},
#  {'text': 'Then, Ashley and Thomas went to the store. Ashley gave a ring to Thomas',
#   'IO': 'Thomas',
#   'S': 'Ashley',
#   'TEMPLATE_IDX': 0},
#  {'[PLACE]': 'store',
#   '[OBJECT]': 'kiss',
#   'text': 'Then, Benjamin and Lauren were working at the store. Lauren decided to give a kiss to Benjamin',
#   'IO': 'Benjamin',
#   'S': 'Lauren',
#   'TEMPLATE_IDX': 17,
#   'C': 'Courtney'},
#  {'text': 'Then, Lauren and Benjamin were working at the store. Benjamin decided to give a kiss to Lauren',
#   'IO': 'Lauren',
#   'S': 'Benjamin',
#   'TEMPLATE_IDX': 17},
#  {'[PLACE]': 'store',
#   '[OBJECT]': 'ring',
#   'text': 'Friends Emily and Bradley found a ring at the store. Bradley gave it to Emily',
#   'IO': 'Emily',
#   'S': 'Bradley',
#   'TEMPLATE_IDX': 29,
#   'C': 'Melissa'},
#  {'text': 'Friends Bradley and Emily found a ring at the store. Emily gave it to Bradley',
#   'IO': 'Bradley',
#   'S': 'Emily',
#   'TEMPLATE_IDX': 29},
#  {'[PLACE]': 'station',
#   '[OBJECT]': 'drink',
#   'text': 'After the lunch, William and Christopher went to the station. Christopher gave a drink to William',
#   'IO': 'William',
#   'S': 'Christopher',
#   'TEMPLATE_IDX': 25,
#   'C': 'Laura'},
#  {'text': 'After the lunch, Christopher and William went to the station. William gave a drink to Christopher',
#   'IO': 'Christopher',
#   'S': 'William',
#   'TEMPLATE_IDX': 25},
#  {'[PLACE]': 'house',
#   '[OBJECT]': 'snack',
#   'text': 'Then, Amber and Vanessa were thinking about going to the house. Amber wanted to give a snack to Vanessa',
#   'IO': 'Vanessa',
#   'S': 'Amber',
#   'TEMPLATE_IDX': 3,
#   'C': 'Samantha'},
#  {'text': 'Then, Vanessa and Amber were thinking about going to the house. Vanessa wanted to give a snack to Amber',
#   'IO': 'Amber',
#   'S': 'Vanessa',
#   'TEMPLATE_IDX': 3},
#  {'[PLACE]': 'garden',
#   '[OBJECT]': 'kiss',
#   'text': 'While Brandon and Angela were commuting to the garden, Angela gave a kiss to Brandon',
#   'IO': 'Brandon',
#   'S': 'Angela',
#   'TEMPLATE_IDX': 24,
#   'C': 'Kimberly'},
#  {'text': 'While Angela and Brandon were commuting to the garden, Brandon gave a kiss to Angela',
#   'IO': 'Angela',
#   'S': 'Brandon',
#   'TEMPLATE_IDX': 24},
#  {'[PLACE]': 'house',
#   '[OBJECT]': 'kiss',
#   'text': 'Then, Michael and John had a long argument, and afterwards Michael said to John',
#   'IO': 'John',
#   'S': 'Michael',
#   'TEMPLATE_IDX': 4,
#   'C': 'Steven'},
#  {'text': 'Then, John and Michael had a long argument, and afterwards John said to Michael',
#   'IO': 'Michael',
#   'S': 'John',
#   'TEMPLATE_IDX': 4},
#  {'[PLACE]': 'office',
#   '[OBJECT]': 'drink',
#   'text': 'While Shannon and Amber were working at the office, Amber gave a drink to Shannon',
#   'IO': 'Shannon',
#   'S': 'Amber',
#   'TEMPLATE_IDX': 23,
#   'C': 'Courtney'},
#  {'text': 'While Amber and Shannon were working at the office, Shannon gave a drink to Amber',
#   'IO': 'Amber',
#   'S': 'Shannon',
#   'TEMPLATE_IDX': 23},
#  {'[PLACE]': 'school',
#   '[OBJECT]': 'snack',
#   'text': 'Friends Gregory and Alicia found a snack at the school. Alicia gave it to Gregory',
#   'IO': 'Gregory',
#   'S': 'Alicia',
#   'TEMPLATE_IDX': 29,
#   'C': 'Angela'},
#  {'text': 'Friends Alicia and Gregory found a snack at the school. Gregory gave it to Alicia',
#   'IO': 'Alicia',
#   'S': 'Gregory',
#   'TEMPLATE_IDX': 29},
#  {'[PLACE]': 'office',
#   '[OBJECT]': 'ring',
#   'text': 'When Stephanie and Christine got a ring at the office, Christine decided to give the ring to Stephanie',
#   'IO': 'Stephanie',
#   'S': 'Christine',
#   'TEMPLATE_IDX': 22,
#   'C': 'Joseph'},
#  {'text': 'When Christine and Stephanie got a ring at the office, Stephanie decided to give the ring to Christine',
#   'IO': 'Christine',
#   'S': 'Stephanie',
#   'TEMPLATE_IDX': 22},
#  {'[PLACE]': 'office',
#   '[OBJECT]': 'necklace',
#   'text': 'Then, Jeremy and Eric were thinking about going to the office. Jeremy wanted to give a necklace to Eric',
#   'IO': 'Eric',
#   'S': 'Jeremy',
#   'TEMPLATE_IDX': 3,
#   'C': 'William'},
#  {'text': 'Then, Eric and Jeremy were thinking about going to the office. Eric wanted to give a necklace to Jeremy',
#   'IO': 'Jeremy',
#   'S': 'Eric',
#   'TEMPLATE_IDX': 3},
#  {'[PLACE]': 'office',
#   '[OBJECT]': 'bone',
#   'text': 'Then, Travis and Danielle had a long argument, and afterwards Travis said to Danielle',
#   'IO': 'Danielle',
#   'S': 'Travis',
#   'TEMPLATE_IDX': 4,
#   'C': 'Sean'},
#  {'text': 'Then, Danielle and Travis had a long argument, and afterwards Danielle said to Travis',
#   'IO': 'Travis',
#   'S': 'Danielle',
#   'TEMPLATE_IDX': 4},
#  {'[PLACE]': 'office',
#   '[OBJECT]': 'necklace',
#   'text': 'While Emily and Nathan were commuting to the office, Emily gave a necklace to Nathan',
#   'IO': 'Nathan',
#   'S': 'Emily',
#   'TEMPLATE_IDX': 9,
#   'C': 'Sara'},
#  {'text': 'While Nathan and Emily were commuting to the office, Nathan gave a necklace to Emily',
#   'IO': 'Emily',
#   'S': 'Nathan',
#   'TEMPLATE_IDX': 9},
#  {'[PLACE]': 'station',
#   '[OBJECT]': 'necklace',
#   'text': 'Afterwards, Charles and Lauren went to the station. Charles gave a necklace to Lauren',
#   'IO': 'Lauren',
#   'S': 'Charles',
#   'TEMPLATE_IDX': 11,
#   'C': 'Jesse'},
#  {'text': 'Afterwards, Lauren and Charles went to the station. Lauren gave a necklace to Charles',
#   'IO': 'Charles',
#   'S': 'Lauren',
#   'TEMPLATE_IDX': 11},
#  {'[PLACE]': 'garden',
#   '[OBJECT]': 'basketball',
#   'text': 'Then, Bryan and Aaron had a lot of fun at the garden. Aaron gave a basketball to Bryan',
#   'IO': 'Bryan',
#   'S': 'Aaron',
#   'TEMPLATE_IDX': 16,
#   'C': 'Benjamin'},
#  {'text': 'Then, Aaron and Bryan had a lot of fun at the garden. Bryan gave a basketball to Aaron',
#   'IO': 'Aaron',
#   'S': 'Bryan',
#   'TEMPLATE_IDX': 16},
#  {'[PLACE]': 'store',
#   '[OBJECT]': 'snack',
#   'text': 'When Brandon and Kimberly got a snack at the store, Brandon decided to give the snack to Kimberly',
#   'IO': 'Kimberly',
#   'S': 'Brandon',
#   'TEMPLATE_IDX': 7,
#   'C': 'Nicholas'},
#  {'text': 'When Kimberly and Brandon got a snack at the store, Kimberly decided to give the snack to Brandon',
#   'IO': 'Brandon',
#   'S': 'Kimberly',
#   'TEMPLATE_IDX': 7},
#  {'[PLACE]': 'restaurant',
#   '[OBJECT]': 'computer',
#   'text': 'Then, Kelly and Alexander were thinking about going to the restaurant. Alexander wanted to give a computer to Kelly',
#   'IO': 'Kelly',
#   'S': 'Alexander',
#   'TEMPLATE_IDX': 18,
#   'C': 'Jeremy'},
#  {'text': 'Then, Alexander and Kelly were thinking about going to the restaurant. Kelly wanted to give a computer to Alexander',
#   'IO': 'Alexander',
#   'S': 'Kelly',
#   'TEMPLATE_IDX': 18},
#  {'[PLACE]': 'house',
#   '[OBJECT]': 'drink',
#   'text': 'Afterwards, Nathan and Ashley went to the house. Ashley gave a drink to Nathan',
#   'IO': 'Nathan',
#   'S': 'Ashley',
#   'TEMPLATE_IDX': 26,
#   'C': 'Matthew'},
#  {'text': 'Afterwards, Ashley and Nathan went to the house. Nathan gave a drink to Ashley',
#   'IO': 'Ashley',
#   'S': 'Nathan',
#   'TEMPLATE_IDX': 26},
#  {'[PLACE]': 'office',
#   '[OBJECT]': 'bone',
#   'text': 'While Scott and Brittany were working at the office, Brittany gave a bone to Scott',
#   'IO': 'Scott',
#   'S': 'Brittany',
#   'TEMPLATE_IDX': 23,
#   'C': 'Nicole'},
#  {'text': 'While Brittany and Scott were working at the office, Scott gave a bone to Brittany',
#   'IO': 'Brittany',
#   'S': 'Scott',
#   'TEMPLATE_IDX': 23},
#  {'[PLACE]': 'school',
#   '[OBJECT]': 'kiss',
#   'text': 'After the lunch, Samantha and Melissa went to the school. Samantha gave a kiss to Melissa',
#   'IO': 'Melissa',
#   'S': 'Samantha',
#   'TEMPLATE_IDX': 10,
#   'C': 'Nicholas'},
#  {'text': 'After the lunch, Melissa and Samantha went to the school. Melissa gave a kiss to Samantha',
#   'IO': 'Samantha',
#   'S': 'Melissa',
#   'TEMPLATE_IDX': 10},
#  {'[PLACE]': 'hospital',
#   '[OBJECT]': 'basketball',
#   'text': 'When Laura and Jeremy got a basketball at the hospital, Laura decided to give the basketball to Jeremy',
#   'IO': 'Jeremy',
#   'S': 'Laura',
#   'TEMPLATE_IDX': 7,
#   'C': 'Rebecca'},
#  {'text': 'When Jeremy and Laura got a basketball at the hospital, Jeremy decided to give the basketball to Laura',
#   'IO': 'Laura',
#   'S': 'Jeremy',
#   'TEMPLATE_IDX': 7},
#  {'[PLACE]': 'office',
#   '[OBJECT]': 'snack',
#   'text': 'When Jose and Thomas got a snack at the office, Thomas decided to give the snack to Jose',
#   'IO': 'Jose',
#   'S': 'Thomas',
#   'TEMPLATE_IDX': 22,
#   'C': 'Crystal'},
#  {'text': 'When Thomas and Jose got a snack at the office, Jose decided to give the snack to Thomas',
#   'IO': 'Thomas',
#   'S': 'Jose',
#   'TEMPLATE_IDX': 22},
#  {'[PLACE]': 'garden',
#   '[OBJECT]': 'computer',
#   'text': 'Then, Jessica and John had a lot of fun at the garden. Jessica gave a computer to John',
#   'IO': 'John',
#   'S': 'Jessica',
#   'TEMPLATE_IDX': 1,
#   'C': 'Steven'},
#  {'text': 'Then, John and Jessica had a lot of fun at the garden. John gave a computer to Jessica',
#   'IO': 'Jessica',
#   'S': 'John',
#   'TEMPLATE_IDX': 1},
#  {'[PLACE]': 'office',
#   '[OBJECT]': 'basketball',
#   'text': 'When Daniel and Lauren got a basketball at the office, Daniel decided to give the basketball to Lauren',
#   'IO': 'Lauren',
#   'S': 'Daniel',
#   'TEMPLATE_IDX': 7,
#   'C': 'Amber'},
#  {'text': 'When Lauren and Daniel got a basketball at the office, Lauren decided to give the basketball to Daniel',
#   'IO': 'Daniel',
#   'S': 'Lauren',
#   'TEMPLATE_IDX': 7},
#  {'[PLACE]': 'house',
#   '[OBJECT]': 'necklace',
#   'text': 'Friends Patrick and Andrea found a necklace at the house. Andrea gave it to Patrick',
#   'IO': 'Patrick',
#   'S': 'Andrea',
#   'TEMPLATE_IDX': 29,
#   'C': 'Kelly'},
#  {'text': 'Friends Andrea and Patrick found a necklace at the house. Patrick gave it to Andrea',
#   'IO': 'Andrea',
#   'S': 'Patrick',
#   'TEMPLATE_IDX': 29},
#  {'[PLACE]': 'office',
#   '[OBJECT]': 'snack',
#   'text': 'Afterwards, Lindsey and Paul went to the office. Paul gave a snack to Lindsey',
#   'IO': 'Lindsey',
#   'S': 'Paul',
#   'TEMPLATE_IDX': 26,
#   'C': 'Kenneth'},
#  {'text': 'Afterwards, Paul and Lindsey went to the office. Lindsey gave a snack to Paul',
#   'IO': 'Paul',
#   'S': 'Lindsey',
#   'TEMPLATE_IDX': 26},
#  {'[PLACE]': 'hospital',
#   '[OBJECT]': 'kiss',
#   'text': 'Then, Cody and Melissa went to the hospital. Cody gave a kiss to Melissa',
#   'IO': 'Melissa',
#   'S': 'Cody',
#   'TEMPLATE_IDX': 0,
#   'C': 'Elizabeth'},
#  {'text': 'Then, Melissa and Cody went to the hospital. Melissa gave a kiss to Cody',
#   'IO': 'Cody',
#   'S': 'Melissa',
#   'TEMPLATE_IDX': 0},
#  {'[PLACE]': 'hospital',
#   '[OBJECT]': 'necklace',
#   'text': 'Then, Bradley and Paul had a lot of fun at the hospital. Bradley gave a necklace to Paul',
#   'IO': 'Paul',
#   'S': 'Bradley',
#   'TEMPLATE_IDX': 1,
#   'C': 'Scott'},
#  {'text': 'Then, Paul and Bradley had a lot of fun at the hospital. Paul gave a necklace to Bradley',
#   'IO': 'Bradley',
#   'S': 'Paul',
#   'TEMPLATE_IDX': 1},
#  {'[PLACE]': 'hospital',
#   '[OBJECT]': 'ring',
#   'text': 'Friends Nicholas and Kimberly found a ring at the hospital. Kimberly gave it to Nicholas',
#   'IO': 'Nicholas',
#   'S': 'Kimberly',
#   'TEMPLATE_IDX': 29,
#   'C': 'Bryan'},
#  {'text': 'Friends Kimberly and Nicholas found a ring at the hospital. Nicholas gave it to Kimberly',
#   'IO': 'Kimberly',
#   'S': 'Nicholas',
#   'TEMPLATE_IDX': 29},
#  {'[PLACE]': 'garden',
#   '[OBJECT]': 'kiss',
#   'text': 'Friends Brittany and Nicholas found a kiss at the garden. Nicholas gave it to Brittany',
#   'IO': 'Brittany',
#   'S': 'Nicholas',
#   'TEMPLATE_IDX': 29,
#   'C': 'Elizabeth'},
#  {'text': 'Friends Nicholas and Brittany found a kiss at the garden. Brittany gave it to Nicholas',
#   'IO': 'Nicholas',
#   'S': 'Brittany',
#   'TEMPLATE_IDX': 29},
#  {'[PLACE]': 'restaurant',
#   '[OBJECT]': 'kiss',
#   'text': 'Then, Daniel and Benjamin were thinking about going to the restaurant. Daniel wanted to give a kiss to Benjamin',
#   'IO': 'Benjamin',
#   'S': 'Daniel',
#   'TEMPLATE_IDX': 3,
#   'C': 'Vanessa'},
#  {'text': 'Then, Benjamin and Daniel were thinking about going to the restaurant. Benjamin wanted to give a kiss to Daniel',
#   'IO': 'Daniel',
#   'S': 'Benjamin',
#   'TEMPLATE_IDX': 3},
#  ...]

# %%
# extract all texts as sentences
ioi_sentences = [ioi_prompt["text"] for ioi_prompt in ioi_prompts]

# %%
ioi_sentences
# Out:
# ['After the lunch, Lindsey and Angela went to the hospital. Angela gave a ring to Lindsey',
#  'After the lunch, Angela and Lindsey went to the hospital. Lindsey gave a ring to Angela',
#  'After the lunch, James and Mark went to the hospital. James gave a snack to Mark',
#  'After the lunch, Mark and James went to the hospital. Mark gave a snack to James',
#  'While Elizabeth and William were commuting to the house, William gave a snack to Elizabeth',
#  'While William and Elizabeth were commuting to the house, Elizabeth gave a snack to William',
#  'When Stephanie and Laura got a kiss at the garden, Stephanie decided to give the kiss to Laura',
#  'When Laura and Stephanie got a kiss at the garden, Laura decided to give the kiss to Stephanie',
#  'Friends Patrick and Robert found a ring at the restaurant. Patrick gave it to Robert',
#  'Friends Robert and Patrick found a ring at the restaurant. Robert gave it to Patrick',
#  'Then, Tiffany and Bradley had a long argument, and afterwards Bradley said to Tiffany',
#  'Then, Bradley and Tiffany had a long argument, and afterwards Tiffany said to Bradley',
#  'Then, Robert and Eric had a long argument. Afterwards Eric said to Robert',
#  'Then, Eric and Robert had a long argument. Afterwards Robert said to Eric',
#  'After Cody and Crystal went to the office, Crystal gave a drink to Cody',
#  'After Crystal and Cody went to the office, Cody gave a drink to Crystal',
#  'Then, Adam and Allison were thinking about going to the house. Adam wanted to give a computer to Allison',
#  'Then, Allison and Adam were thinking about going to the house. Allison wanted to give a computer to Adam',
#  'Then, Courtney and Ashley had a long argument, and afterwards Ashley said to Courtney',
#  'Then, Ashley and Courtney had a long argument, and afterwards Courtney said to Ashley',
#  'Afterwards, Jesse and Brandon went to the restaurant. Brandon gave a bone to Jesse',
#  'Afterwards, Brandon and Jesse went to the restaurant. Jesse gave a bone to Brandon',
#  'Then, Kelly and Aaron were thinking about going to the office. Kelly wanted to give a snack to Aaron',
#  'Then, Aaron and Kelly were thinking about going to the office. Aaron wanted to give a snack to Kelly',
#  'Then, Matthew and Jonathan went to the restaurant. Matthew gave a kiss to Jonathan',
#  'Then, Jonathan and Matthew went to the restaurant. Jonathan gave a kiss to Matthew',
#  'Then, Joshua and Jonathan had a lot of fun at the house. Joshua gave a bone to Jonathan',
#  'Then, Jonathan and Joshua had a lot of fun at the house. Jonathan gave a bone to Joshua',
#  'Then, Rachel and Jennifer had a long argument, and afterwards Rachel said to Jennifer',
#  'Then, Jennifer and Rachel had a long argument, and afterwards Jennifer said to Rachel',
#  'While Kyle and Travis were commuting to the garden, Travis gave a computer to Kyle',
#  'While Travis and Kyle were commuting to the garden, Kyle gave a computer to Travis',
#  'Then, Samuel and Stephanie were thinking about going to the station. Samuel wanted to give a drink to Stephanie',
#  'Then, Stephanie and Samuel were thinking about going to the station. Stephanie wanted to give a drink to Samuel',
#  'Then, Rachel and David had a long argument, and afterwards Rachel said to David',
#  'Then, David and Rachel had a long argument, and afterwards David said to Rachel',
#  'While Brittany and Andrew were commuting to the restaurant, Brittany gave a computer to Andrew',
#  'While Andrew and Brittany were commuting to the restaurant, Andrew gave a computer to Brittany',
#  'Then, Ashley and Thomas went to the restaurant. Ashley gave a necklace to Thomas',
#  'Then, Thomas and Ashley went to the restaurant. Thomas gave a necklace to Ashley',
#  'Then, Kelly and Benjamin had a long argument, and afterwards Benjamin said to Kelly',
#  'Then, Benjamin and Kelly had a long argument, and afterwards Kelly said to Benjamin',
#  'Then, Eric and Lindsey had a lot of fun at the hospital. Lindsey gave a basketball to Eric',
#  'Then, Lindsey and Eric had a lot of fun at the hospital. Eric gave a basketball to Lindsey',
#  'After Daniel and Erica went to the school, Daniel gave a kiss to Erica',
#  'After Erica and Daniel went to the school, Erica gave a kiss to Daniel',
#  'Then, Elizabeth and Ashley were working at the station. Elizabeth decided to give a kiss to Ashley',
#  'Then, Ashley and Elizabeth were working at the station. Ashley decided to give a kiss to Elizabeth',
#  'After the lunch, Erin and Amanda went to the restaurant. Erin gave a snack to Amanda',
#  'After the lunch, Amanda and Erin went to the restaurant. Amanda gave a snack to Erin',
#  'Friends Alexander and Melissa found a kiss at the garden. Melissa gave it to Alexander',
#  'Friends Melissa and Alexander found a kiss at the garden. Alexander gave it to Melissa',
#  'While Andrew and Amber were working at the garden, Amber gave a bone to Andrew',
#  'While Amber and Andrew were working at the garden, Andrew gave a bone to Amber',
#  'After the lunch, Courtney and Andrew went to the restaurant. Andrew gave a computer to Courtney',
#  'After the lunch, Andrew and Courtney went to the restaurant. Courtney gave a computer to Andrew',
#  'Afterwards, Bradley and Jonathan went to the hospital. Bradley gave a basketball to Jonathan',
#  'Afterwards, Jonathan and Bradley went to the hospital. Jonathan gave a basketball to Bradley',
#  'Then, Sara and Samantha had a lot of fun at the hospital. Sara gave a ring to Samantha',
#  'Then, Samantha and Sara had a lot of fun at the hospital. Samantha gave a ring to Sara',
#  'Then, Allison and Megan had a long argument. Afterwards Megan said to Allison',
#  'Then, Megan and Allison had a long argument. Afterwards Allison said to Megan',
#  'Then, Amber and Jamie were working at the restaurant. Jamie decided to give a bone to Amber',
#  'Then, Jamie and Amber were working at the restaurant. Amber decided to give a bone to Jamie',
#  'While John and Jose were working at the hospital, Jose gave a snack to John',
#  'While Jose and John were working at the hospital, John gave a snack to Jose',
#  'Then, Melissa and Katherine had a long argument, and afterwards Katherine said to Melissa',
#  'Then, Katherine and Melissa had a long argument, and afterwards Melissa said to Katherine',
#  'After Rachel and Mark went to the restaurant, Rachel gave a kiss to Mark',
#  'After Mark and Rachel went to the restaurant, Mark gave a kiss to Rachel',
#  'Then, Michael and Patrick were thinking about going to the station. Michael wanted to give a basketball to Patrick',
#  'Then, Patrick and Michael were thinking about going to the station. Patrick wanted to give a basketball to Michael',
#  'When Jennifer and Benjamin got a necklace at the station, Jennifer decided to give it to Benjamin',
#  'When Benjamin and Jennifer got a necklace at the station, Benjamin decided to give it to Jennifer',
#  'Then, Kelly and Joshua had a long argument, and afterwards Kelly said to Joshua',
#  'Then, Joshua and Kelly had a long argument, and afterwards Joshua said to Kelly',
#  'Then, Matthew and David were thinking about going to the office. David wanted to give a computer to Matthew',
#  'Then, David and Matthew were thinking about going to the office. Matthew wanted to give a computer to David',
#  'Afterwards, Heather and Eric went to the restaurant. Heather gave a computer to Eric',
#  'Afterwards, Eric and Heather went to the restaurant. Eric gave a computer to Heather',
#  'When Erica and Adam got a necklace at the hospital, Adam decided to give the necklace to Erica',
#  'When Adam and Erica got a necklace at the hospital, Erica decided to give the necklace to Adam',
#  'While Jacob and Erin were working at the store, Erin gave a bone to Jacob',
#  'While Erin and Jacob were working at the store, Jacob gave a bone to Erin',
#  'Then, John and Amanda had a lot of fun at the office. John gave a drink to Amanda',
#  'Then, Amanda and John had a lot of fun at the office. Amanda gave a drink to John',
#  'When Lindsey and Katherine got a bone at the school, Katherine decided to give the bone to Lindsey',
#  'When Katherine and Lindsey got a bone at the school, Lindsey decided to give the bone to Katherine',
#  'Then, Megan and Andrew were thinking about going to the station. Andrew wanted to give a bone to Megan',
#  'Then, Andrew and Megan were thinking about going to the station. Megan wanted to give a bone to Andrew',
#  'When Elizabeth and Ryan got a drink at the store, Elizabeth decided to give the drink to Ryan',
#  'When Ryan and Elizabeth got a drink at the store, Ryan decided to give the drink to Elizabeth',
#  'After the lunch, Jeffrey and Lindsey went to the restaurant. Jeffrey gave a necklace to Lindsey',
#  'After the lunch, Lindsey and Jeffrey went to the restaurant. Lindsey gave a necklace to Jeffrey',
#  'Then, Nathan and Michael had a lot of fun at the hospital. Nathan gave a computer to Michael',
#  'Then, Michael and Nathan had a lot of fun at the hospital. Michael gave a computer to Nathan',
#  'When Crystal and Tiffany got a computer at the station, Tiffany decided to give the computer to Crystal',
#  'When Tiffany and Crystal got a computer at the station, Crystal decided to give the computer to Tiffany',
#  'The office Travis and Patrick went to had a bone. Patrick gave it to Travis',
#  'The office Patrick and Travis went to had a bone. Travis gave it to Patrick',
#  'While Vanessa and Brian were commuting to the office, Vanessa gave a computer to Brian',
#  'While Brian and Vanessa were commuting to the office, Brian gave a computer to Vanessa',
#  'Then, Richard and Christina were thinking about going to the station. Richard wanted to give a drink to Christina',
#  'Then, Christina and Richard were thinking about going to the station. Christina wanted to give a drink to Richard',
#  'Then, Jennifer and Elizabeth had a lot of fun at the hospital. Elizabeth gave a basketball to Jennifer',
#  'Then, Elizabeth and Jennifer had a lot of fun at the hospital. Jennifer gave a basketball to Elizabeth',
#  'Then, Jeremy and Jessica were thinking about going to the hospital. Jeremy wanted to give a drink to Jessica',
#  'Then, Jessica and Jeremy were thinking about going to the hospital. Jessica wanted to give a drink to Jeremy',
#  'After Paul and Jonathan went to the hospital, Jonathan gave a computer to Paul',
#  'After Jonathan and Paul went to the hospital, Paul gave a computer to Jonathan',
#  'Then, Samuel and Alicia had a lot of fun at the hospital. Samuel gave a necklace to Alicia',
#  'Then, Alicia and Samuel had a lot of fun at the hospital. Alicia gave a necklace to Samuel',
#  'After the lunch, Bradley and Lindsey went to the office. Bradley gave a drink to Lindsey',
#  'After the lunch, Lindsey and Bradley went to the office. Lindsey gave a drink to Bradley',
#  'Then, Heather and Alicia were thinking about going to the store. Alicia wanted to give a ring to Heather',
#  'Then, Alicia and Heather were thinking about going to the store. Heather wanted to give a ring to Alicia',
#  'The station Charles and Sarah went to had a snack. Charles gave it to Sarah',
#  'The station Sarah and Charles went to had a snack. Sarah gave it to Charles',
#  'When Jason and Nicole got a computer at the school, Nicole decided to give it to Jason',
#  'When Nicole and Jason got a computer at the school, Jason decided to give it to Nicole',
#  'While Michael and James were working at the garden, Michael gave a bone to James',
#  'While James and Michael were working at the garden, James gave a bone to Michael',
#  'Then, Jesse and Melissa had a lot of fun at the office. Jesse gave a drink to Melissa',
#  'Then, Melissa and Jesse had a lot of fun at the office. Melissa gave a drink to Jesse',
#  'Then, Bryan and Kimberly were working at the station. Kimberly decided to give a drink to Bryan',
#  'Then, Kimberly and Bryan were working at the station. Bryan decided to give a drink to Kimberly',
#  'When Robert and Amanda got a basketball at the house, Robert decided to give it to Amanda',
#  'When Amanda and Robert got a basketball at the house, Amanda decided to give it to Robert',
#  'Then, Robert and Gregory were working at the restaurant. Robert decided to give a snack to Gregory',
#  'Then, Gregory and Robert were working at the restaurant. Gregory decided to give a snack to Robert',
#  'Then, Anthony and Allison were thinking about going to the house. Anthony wanted to give a snack to Allison',
#  'Then, Allison and Anthony were thinking about going to the house. Allison wanted to give a snack to Anthony',
#  'Afterwards, Thomas and Kelly went to the store. Kelly gave a ring to Thomas',
#  'Afterwards, Kelly and Thomas went to the store. Thomas gave a ring to Kelly',
#  'Then, Rachel and Alexander had a long argument, and afterwards Alexander said to Rachel',
#  'Then, Alexander and Rachel had a long argument, and afterwards Rachel said to Alexander',
#  'Then, Brandon and Rachel were thinking about going to the hospital. Rachel wanted to give a drink to Brandon',
#  'Then, Rachel and Brandon were thinking about going to the hospital. Brandon wanted to give a drink to Rachel',
#  'Then, Megan and Jonathan were working at the house. Jonathan decided to give a snack to Megan',
#  'Then, Jonathan and Megan were working at the house. Megan decided to give a snack to Jonathan',
#  'While Robert and Stephanie were working at the restaurant, Stephanie gave a necklace to Robert',
#  'While Stephanie and Robert were working at the restaurant, Robert gave a necklace to Stephanie',
#  'The school Steven and Christopher went to had a kiss. Steven gave it to Christopher',
#  'The school Christopher and Steven went to had a kiss. Christopher gave it to Steven',
#  'Then, Gregory and Vanessa were thinking about going to the restaurant. Gregory wanted to give a necklace to Vanessa',
#  'Then, Vanessa and Gregory were thinking about going to the restaurant. Vanessa wanted to give a necklace to Gregory',
#  'Then, Crystal and Adam had a long argument. Afterwards Crystal said to Adam',
#  'Then, Adam and Crystal had a long argument. Afterwards Adam said to Crystal',
#  'Then, Christopher and Angela had a long argument, and afterwards Christopher said to Angela',
#  'Then, Angela and Christopher had a long argument, and afterwards Angela said to Christopher',
#  'Then, Erica and Alexander had a lot of fun at the restaurant. Alexander gave a computer to Erica',
#  'Then, Alexander and Erica had a lot of fun at the restaurant. Erica gave a computer to Alexander',
#  'Then, Angela and Michelle were thinking about going to the store. Angela wanted to give a computer to Michelle',
#  'Then, Michelle and Angela were thinking about going to the store. Michelle wanted to give a computer to Angela',
#  'Then, Sean and Matthew went to the office. Sean gave a kiss to Matthew',
#  'Then, Matthew and Sean went to the office. Matthew gave a kiss to Sean',
#  'After the lunch, Danielle and Lindsey went to the garden. Danielle gave a kiss to Lindsey',
#  'After the lunch, Lindsey and Danielle went to the garden. Lindsey gave a kiss to Danielle',
#  'Then, Samuel and Kenneth had a lot of fun at the house. Samuel gave a necklace to Kenneth',
#  'Then, Kenneth and Samuel had a lot of fun at the house. Kenneth gave a necklace to Samuel',
#  'The office Travis and Tiffany went to had a bone. Tiffany gave it to Travis',
#  'The office Tiffany and Travis went to had a bone. Travis gave it to Tiffany',
#  'Friends Nicole and Alicia found a bone at the restaurant. Nicole gave it to Alicia',
#  'Friends Alicia and Nicole found a bone at the restaurant. Alicia gave it to Nicole',
#  'When Danielle and Lisa got a snack at the house, Danielle decided to give the snack to Lisa',
#  'When Lisa and Danielle got a snack at the house, Lisa decided to give the snack to Danielle',
#  'Then, Brandon and Aaron were thinking about going to the house. Brandon wanted to give a bone to Aaron',
#  'Then, Aaron and Brandon were thinking about going to the house. Aaron wanted to give a bone to Brandon',
#  'Then, Alicia and Alexander had a lot of fun at the garden. Alexander gave a drink to Alicia',
#  'Then, Alexander and Alicia had a lot of fun at the garden. Alicia gave a drink to Alexander',
#  'Then, Megan and Daniel had a lot of fun at the station. Daniel gave a drink to Megan',
#  'Then, Daniel and Megan had a lot of fun at the station. Megan gave a drink to Daniel',
#  'After the lunch, Lisa and Stephen went to the store. Stephen gave a necklace to Lisa',
#  'After the lunch, Stephen and Lisa went to the store. Lisa gave a necklace to Stephen',
#  'After the lunch, Dustin and Rebecca went to the garden. Dustin gave a ring to Rebecca',
#  'After the lunch, Rebecca and Dustin went to the garden. Rebecca gave a ring to Dustin',
#  'Then, Erica and Elizabeth had a long argument, and afterwards Erica said to Elizabeth',
#  'Then, Elizabeth and Erica had a long argument, and afterwards Elizabeth said to Erica',
#  'While Sarah and Vanessa were working at the hospital, Vanessa gave a kiss to Sarah',
#  'While Vanessa and Sarah were working at the hospital, Sarah gave a kiss to Vanessa',
#  'While Benjamin and Aaron were working at the store, Benjamin gave a necklace to Aaron',
#  'While Aaron and Benjamin were working at the store, Aaron gave a necklace to Benjamin',
#  'When Michael and Charles got a bone at the school, Michael decided to give it to Charles',
#  'When Charles and Michael got a bone at the school, Charles decided to give it to Michael',
#  'The office Aaron and Katie went to had a drink. Aaron gave it to Katie',
#  'The office Katie and Aaron went to had a drink. Katie gave it to Aaron',
#  'Then, Kelly and Nicholas had a lot of fun at the restaurant. Kelly gave a bone to Nicholas',
#  'Then, Nicholas and Kelly had a lot of fun at the restaurant. Nicholas gave a bone to Kelly',
#  'When Brittany and Mary got a bone at the store, Brittany decided to give it to Mary',
#  'When Mary and Brittany got a bone at the store, Mary decided to give it to Brittany',
#  'Then, Steven and Justin had a lot of fun at the school. Justin gave a computer to Steven',
#  'Then, Justin and Steven had a lot of fun at the school. Steven gave a computer to Justin',
#  'When Rachel and Lindsay got a computer at the hospital, Rachel decided to give the computer to Lindsay',
#  'When Lindsay and Rachel got a computer at the hospital, Lindsay decided to give the computer to Rachel',
#  'Then, Lauren and Andrea had a long argument, and afterwards Lauren said to Andrea',
#  'Then, Andrea and Lauren had a long argument, and afterwards Andrea said to Lauren',
#  'Friends Daniel and Katie found a snack at the restaurant. Katie gave it to Daniel',
#  'Friends Katie and Daniel found a snack at the restaurant. Daniel gave it to Katie',
#  'After Joseph and Christine went to the school, Christine gave a computer to Joseph',
#  'After Christine and Joseph went to the school, Joseph gave a computer to Christine',
#  'While Emily and Dustin were working at the store, Dustin gave a necklace to Emily',
#  'While Dustin and Emily were working at the store, Emily gave a necklace to Dustin',
#  'After the lunch, Richard and Amanda went to the restaurant. Amanda gave a bone to Richard',
#  'After the lunch, Amanda and Richard went to the restaurant. Richard gave a bone to Amanda',
#  'Then, Emily and Daniel were working at the house. Emily decided to give a kiss to Daniel',
#  'Then, Daniel and Emily were working at the house. Daniel decided to give a kiss to Emily',
#  'After Charles and Katie went to the office, Katie gave a drink to Charles',
#  'After Katie and Charles went to the office, Charles gave a drink to Katie',
#  'Afterwards, Robert and Daniel went to the store. Robert gave a computer to Daniel',
#  'Afterwards, Daniel and Robert went to the store. Daniel gave a computer to Robert',
#  'Then, Michael and Christine had a long argument. Afterwards Christine said to Michael',
#  'Then, Christine and Michael had a long argument. Afterwards Michael said to Christine',
#  'Then, Laura and Patrick went to the house. Laura gave a computer to Patrick',
#  'Then, Patrick and Laura went to the house. Patrick gave a computer to Laura',
#  'Then, Jacob and Anthony had a long argument, and afterwards Anthony said to Jacob',
#  'Then, Anthony and Jacob had a long argument, and afterwards Jacob said to Anthony',
#  'Friends Nicholas and Patrick found a drink at the garden. Patrick gave it to Nicholas',
#  'Friends Patrick and Nicholas found a drink at the garden. Nicholas gave it to Patrick',
#  'After Daniel and Allison went to the station, Allison gave a computer to Daniel',
#  'After Allison and Daniel went to the station, Daniel gave a computer to Allison',
#  'The station Mark and Sarah went to had a bone. Mark gave it to Sarah',
#  'The station Sarah and Mark went to had a bone. Sarah gave it to Mark',
#  'Then, James and Katie had a long argument, and afterwards James said to Katie',
#  'Then, Katie and James had a long argument, and afterwards Katie said to James',
#  'After Justin and Samantha went to the store, Samantha gave a drink to Justin',
#  'After Samantha and Justin went to the store, Justin gave a drink to Samantha',
#  'Then, Richard and Sarah were thinking about going to the house. Sarah wanted to give a necklace to Richard',
#  'Then, Sarah and Richard were thinking about going to the house. Richard wanted to give a necklace to Sarah',
#  'After Kenneth and Vanessa went to the hospital, Vanessa gave a necklace to Kenneth',
#  'After Vanessa and Kenneth went to the hospital, Kenneth gave a necklace to Vanessa',
#  'Then, Stephanie and Melissa had a long argument, and afterwards Stephanie said to Melissa',
#  'Then, Melissa and Stephanie had a long argument, and afterwards Melissa said to Stephanie',
#  'Then, William and Daniel had a long argument, and afterwards William said to Daniel',
#  'Then, Daniel and William had a long argument, and afterwards Daniel said to William',
#  'Then, Elizabeth and Shannon were working at the store. Elizabeth decided to give a ring to Shannon',
#  'Then, Shannon and Elizabeth were working at the store. Shannon decided to give a ring to Elizabeth',
#  'When Jose and Paul got a bone at the school, Paul decided to give the bone to Jose',
#  'When Paul and Jose got a bone at the school, Jose decided to give the bone to Paul',
#  'Then, Sean and Erin had a long argument. Afterwards Erin said to Sean',
#  'Then, Erin and Sean had a long argument. Afterwards Sean said to Erin',
#  'After Thomas and Alicia went to the station, Alicia gave a computer to Thomas',
#  'After Alicia and Thomas went to the station, Thomas gave a computer to Alicia',
#  'Then, Paul and Stephen had a long argument. Afterwards Paul said to Stephen',
#  'Then, Stephen and Paul had a long argument. Afterwards Stephen said to Paul',
#  'When Andrea and Elizabeth got a computer at the store, Andrea decided to give the computer to Elizabeth',
#  'When Elizabeth and Andrea got a computer at the store, Elizabeth decided to give the computer to Andrea',
#  'The station Elizabeth and Mary went to had a bone. Mary gave it to Elizabeth',
#  'The station Mary and Elizabeth went to had a bone. Elizabeth gave it to Mary',
#  'After the lunch, Kimberly and Katherine went to the station. Katherine gave a ring to Kimberly',
#  'After the lunch, Katherine and Kimberly went to the station. Kimberly gave a ring to Katherine',
#  'Then, Charles and Richard were working at the school. Charles decided to give a drink to Richard',
#  'Then, Richard and Charles were working at the school. Richard decided to give a drink to Charles',
#  'Then, Erica and Megan had a lot of fun at the office. Erica gave a ring to Megan',
#  'Then, Megan and Erica had a lot of fun at the office. Megan gave a ring to Erica',
#  'While Lisa and Tyler were commuting to the restaurant, Lisa gave a necklace to Tyler',
#  'While Tyler and Lisa were commuting to the restaurant, Tyler gave a necklace to Lisa',
#  'When James and Brittany got a bone at the store, Brittany decided to give the bone to James',
#  'When Brittany and James got a bone at the store, James decided to give the bone to Brittany',
#  'Then, Alexander and Jeremy had a long argument, and afterwards Jeremy said to Alexander',
#  'Then, Jeremy and Alexander had a long argument, and afterwards Alexander said to Jeremy',
#  'Then, Jacob and Jamie had a long argument, and afterwards Jamie said to Jacob',
#  'Then, Jamie and Jacob had a long argument, and afterwards Jacob said to Jamie',
#  'While Cody and Erica were working at the garden, Erica gave a basketball to Cody',
#  'While Erica and Cody were working at the garden, Cody gave a basketball to Erica',
#  'After the lunch, Andrew and Erin went to the store. Andrew gave a necklace to Erin',
#  'After the lunch, Erin and Andrew went to the store. Erin gave a necklace to Andrew',
#  'When Brittany and Lindsey got a bone at the station, Brittany decided to give the bone to Lindsey',
#  'When Lindsey and Brittany got a bone at the station, Lindsey decided to give the bone to Brittany',
#  'Then, John and Christina were working at the house. Christina decided to give a necklace to John',
#  'Then, Christina and John were working at the house. John decided to give a necklace to Christina',
#  'Then, Rebecca and James were working at the garden. Rebecca decided to give a kiss to James',
#  'Then, James and Rebecca were working at the garden. James decided to give a kiss to Rebecca',
#  'While Michelle and Amanda were working at the restaurant, Amanda gave a ring to Michelle',
#  'While Amanda and Michelle were working at the restaurant, Michelle gave a ring to Amanda',
#  'Afterwards, Jessica and Melissa went to the school. Melissa gave a necklace to Jessica',
#  'Afterwards, Melissa and Jessica went to the school. Jessica gave a necklace to Melissa',
#  'Then, Thomas and Mary had a long argument, and afterwards Thomas said to Mary',
#  'Then, Mary and Thomas had a long argument, and afterwards Mary said to Thomas',
#  'After Benjamin and Adam went to the station, Adam gave a kiss to Benjamin',
#  'After Adam and Benjamin went to the station, Benjamin gave a kiss to Adam',
#  'Then, Sarah and Ashley had a long argument. Afterwards Ashley said to Sarah',
#  'Then, Ashley and Sarah had a long argument. Afterwards Sarah said to Ashley',
#  'After the lunch, Richard and Sarah went to the store. Sarah gave a basketball to Richard',
#  'After the lunch, Sarah and Richard went to the store. Richard gave a basketball to Sarah',
#  'When Cody and Elizabeth got a drink at the school, Elizabeth decided to give it to Cody',
#  'When Elizabeth and Cody got a drink at the school, Cody decided to give it to Elizabeth',
#  'Then, Melissa and Brittany had a long argument. Afterwards Melissa said to Brittany',
#  'Then, Brittany and Melissa had a long argument. Afterwards Brittany said to Melissa',
#  'While Anthony and Steven were commuting to the restaurant, Steven gave a basketball to Anthony',
#  'While Steven and Anthony were commuting to the restaurant, Anthony gave a basketball to Steven',
#  'When Jesse and Kevin got a basketball at the station, Jesse decided to give it to Kevin',
#  'When Kevin and Jesse got a basketball at the station, Kevin decided to give it to Jesse',
#  'While William and Stephen were commuting to the garden, William gave a ring to Stephen',
#  'While Stephen and William were commuting to the garden, Stephen gave a ring to William',
#  'After Jessica and Steven went to the school, Jessica gave a basketball to Steven',
#  'After Steven and Jessica went to the school, Steven gave a basketball to Jessica',
#  'After the lunch, Melissa and Jessica went to the station. Jessica gave a kiss to Melissa',
#  'After the lunch, Jessica and Melissa went to the station. Melissa gave a kiss to Jessica',
#  'While Kyle and Michael were working at the garden, Michael gave a necklace to Kyle',
#  'While Michael and Kyle were working at the garden, Kyle gave a necklace to Michael',
#  'Then, Kyle and Michelle had a lot of fun at the store. Michelle gave a necklace to Kyle',
#  'Then, Michelle and Kyle had a lot of fun at the store. Kyle gave a necklace to Michelle',
#  'Then, Lauren and Richard had a long argument, and afterwards Lauren said to Richard',
#  'Then, Richard and Lauren had a long argument, and afterwards Richard said to Lauren',
#  'While Patrick and Lindsay were working at the hospital, Patrick gave a computer to Lindsay',
#  'While Lindsay and Patrick were working at the hospital, Lindsay gave a computer to Patrick',
#  'Friends Crystal and Lindsay found a ring at the restaurant. Crystal gave it to Lindsay',
#  'Friends Lindsay and Crystal found a ring at the restaurant. Lindsay gave it to Crystal',
#  'While Samantha and Samuel were working at the house, Samantha gave a necklace to Samuel',
#  'While Samuel and Samantha were working at the house, Samuel gave a necklace to Samantha',
#  'After Richard and Brandon went to the station, Richard gave a kiss to Brandon',
#  'After Brandon and Richard went to the station, Brandon gave a kiss to Richard',
#  'When Kristen and Erica got a computer at the school, Kristen decided to give the computer to Erica',
#  'When Erica and Kristen got a computer at the school, Erica decided to give the computer to Kristen',
#  'Then, Joshua and William went to the office. William gave a snack to Joshua',
#  'Then, William and Joshua went to the office. Joshua gave a snack to William',
#  'After the lunch, Katherine and Kimberly went to the office. Kimberly gave a bone to Katherine',
#  'After the lunch, Kimberly and Katherine went to the office. Katherine gave a bone to Kimberly',
#  'Then, Christopher and Kelly had a lot of fun at the restaurant. Christopher gave a drink to Kelly',
#  'Then, Kelly and Christopher had a lot of fun at the restaurant. Kelly gave a drink to Christopher',
#  'When Brittany and Sean got a drink at the school, Brittany decided to give it to Sean',
#  'When Sean and Brittany got a drink at the school, Sean decided to give it to Brittany',
#  'Then, Matthew and Stephanie had a long argument, and afterwards Matthew said to Stephanie',
#  'Then, Stephanie and Matthew had a long argument, and afterwards Stephanie said to Matthew',
#  'When Christine and Nicholas got a snack at the restaurant, Christine decided to give it to Nicholas',
#  'When Nicholas and Christine got a snack at the restaurant, Nicholas decided to give it to Christine',
#  'After the lunch, Nathan and Jeremy went to the hospital. Nathan gave a necklace to Jeremy',
#  'After the lunch, Jeremy and Nathan went to the hospital. Jeremy gave a necklace to Nathan',
#  'Friends Kimberly and Courtney found a bone at the station. Courtney gave it to Kimberly',
#  'Friends Courtney and Kimberly found a bone at the station. Kimberly gave it to Courtney',
#  'Then, Gregory and Alicia had a long argument. Afterwards Alicia said to Gregory',
#  'Then, Alicia and Gregory had a long argument. Afterwards Gregory said to Alicia',
#  'Friends Jeremy and Jesse found a kiss at the office. Jesse gave it to Jeremy',
#  'Friends Jesse and Jeremy found a kiss at the office. Jeremy gave it to Jesse',
#  'While Angela and Erica were working at the restaurant, Angela gave a ring to Erica',
#  'While Erica and Angela were working at the restaurant, Erica gave a ring to Angela',
#  'Then, Richard and Daniel had a long argument, and afterwards Daniel said to Richard',
#  'Then, Daniel and Richard had a long argument, and afterwards Richard said to Daniel',
#  'Then, Rebecca and Laura went to the hospital. Rebecca gave a necklace to Laura',
#  'Then, Laura and Rebecca went to the hospital. Laura gave a necklace to Rebecca',
#  'While Kevin and Stephen were commuting to the station, Kevin gave a kiss to Stephen',
#  'While Stephen and Kevin were commuting to the station, Stephen gave a kiss to Kevin',
#  'Then, Mark and Samantha had a long argument. Afterwards Mark said to Samantha',
#  'Then, Samantha and Mark had a long argument. Afterwards Samantha said to Mark',
#  'Friends Shannon and Timothy found a snack at the house. Shannon gave it to Timothy',
#  'Friends Timothy and Shannon found a snack at the house. Timothy gave it to Shannon',
#  'While Travis and Stephen were working at the office, Travis gave a basketball to Stephen',
#  'While Stephen and Travis were working at the office, Stephen gave a basketball to Travis',
#  'Then, Jeremy and Timothy had a long argument. Afterwards Jeremy said to Timothy',
#  'Then, Timothy and Jeremy had a long argument. Afterwards Timothy said to Jeremy',
#  'Then, Kelly and Thomas had a long argument, and afterwards Kelly said to Thomas',
#  'Then, Thomas and Kelly had a long argument, and afterwards Thomas said to Kelly',
#  'When William and Emily got a necklace at the school, Emily decided to give the necklace to William',
#  'When Emily and William got a necklace at the school, William decided to give the necklace to Emily',
#  'Then, Ryan and Jeffrey were thinking about going to the station. Ryan wanted to give a basketball to Jeffrey',
#  'Then, Jeffrey and Ryan were thinking about going to the station. Jeffrey wanted to give a basketball to Ryan',
#  'Then, Christina and Courtney had a lot of fun at the garden. Courtney gave a computer to Christina',
#  'Then, Courtney and Christina had a lot of fun at the garden. Christina gave a computer to Courtney',
#  'Then, Anthony and Robert were working at the office. Anthony decided to give a kiss to Robert',
#  'Then, Robert and Anthony were working at the office. Robert decided to give a kiss to Anthony',
#  'The office Sarah and Jamie went to had a basketball. Jamie gave it to Sarah',
#  'The office Jamie and Sarah went to had a basketball. Sarah gave it to Jamie',
#  'Then, Melissa and Amanda had a long argument, and afterwards Amanda said to Melissa',
#  'Then, Amanda and Melissa had a long argument, and afterwards Melissa said to Amanda',
#  'The school Timothy and Benjamin went to had a snack. Timothy gave it to Benjamin',
#  'The school Benjamin and Timothy went to had a snack. Benjamin gave it to Timothy',
#  'After David and Mark went to the store, Mark gave a kiss to David',
#  'After Mark and David went to the store, David gave a kiss to Mark',
#  'Friends Thomas and Rachel found a snack at the office. Rachel gave it to Thomas',
#  'Friends Rachel and Thomas found a snack at the office. Thomas gave it to Rachel',
#  'Friends Alexander and Bryan found a basketball at the station. Bryan gave it to Alexander',
#  'Friends Bryan and Alexander found a basketball at the station. Alexander gave it to Bryan',
#  'Then, Tyler and Allison had a lot of fun at the restaurant. Tyler gave a drink to Allison',
#  'Then, Allison and Tyler had a lot of fun at the restaurant. Allison gave a drink to Tyler',
#  'The restaurant Nathan and Jose went to had a bone. Jose gave it to Nathan',
#  'The restaurant Jose and Nathan went to had a bone. Nathan gave it to Jose',
#  'Then, Joseph and Katie had a long argument, and afterwards Joseph said to Katie',
#  'Then, Katie and Joseph had a long argument, and afterwards Katie said to Joseph',
#  'Then, Jamie and Jose were thinking about going to the store. Jose wanted to give a necklace to Jamie',
#  'Then, Jose and Jamie were thinking about going to the store. Jamie wanted to give a necklace to Jose',
#  'While Angela and Samuel were commuting to the school, Angela gave a drink to Samuel',
#  'While Samuel and Angela were commuting to the school, Samuel gave a drink to Angela',
#  'Then, Matthew and Ryan had a long argument, and afterwards Matthew said to Ryan',
#  'Then, Ryan and Matthew had a long argument, and afterwards Ryan said to Matthew',
#  'Then, David and Joseph had a long argument. Afterwards David said to Joseph',
#  'Then, Joseph and David had a long argument. Afterwards Joseph said to David',
#  'Then, Adam and Jessica had a lot of fun at the garden. Adam gave a bone to Jessica',
#  'Then, Jessica and Adam had a lot of fun at the garden. Jessica gave a bone to Adam',
#  'Then, Samantha and Patrick had a lot of fun at the store. Samantha gave a computer to Patrick',
#  'Then, Patrick and Samantha had a lot of fun at the store. Patrick gave a computer to Samantha',
#  'Afterwards, Gregory and John went to the house. John gave a snack to Gregory',
#  'Afterwards, John and Gregory went to the house. Gregory gave a snack to John',
#  'The garden Emily and Courtney went to had a drink. Emily gave it to Courtney',
#  'The garden Courtney and Emily went to had a drink. Courtney gave it to Emily',
#  'The restaurant Kevin and Matthew went to had a computer. Kevin gave it to Matthew',
#  'The restaurant Matthew and Kevin went to had a computer. Matthew gave it to Kevin',
#  'When Rebecca and Amy got a computer at the station, Amy decided to give it to Rebecca',
#  'When Amy and Rebecca got a computer at the station, Rebecca decided to give it to Amy',
#  'After Jacob and Mary went to the station, Jacob gave a necklace to Mary',
#  'After Mary and Jacob went to the station, Mary gave a necklace to Jacob',
#  'The station Amber and Jessica went to had a necklace. Amber gave it to Jessica',
#  'The station Jessica and Amber went to had a necklace. Jessica gave it to Amber',
#  'Friends Robert and Richard found a necklace at the school. Robert gave it to Richard',
#  'Friends Richard and Robert found a necklace at the school. Richard gave it to Robert',
#  'Afterwards, Adam and Allison went to the hospital. Adam gave a snack to Allison',
#  'Afterwards, Allison and Adam went to the hospital. Allison gave a snack to Adam',
#  'Friends Lindsey and Benjamin found a necklace at the restaurant. Lindsey gave it to Benjamin',
#  'Friends Benjamin and Lindsey found a necklace at the restaurant. Benjamin gave it to Lindsey',
#  'Afterwards, Lindsay and Aaron went to the school. Aaron gave a necklace to Lindsay',
#  'Afterwards, Aaron and Lindsay went to the school. Lindsay gave a necklace to Aaron',
#  'Then, Jennifer and Amanda were working at the restaurant. Amanda decided to give a bone to Jennifer',
#  'Then, Amanda and Jennifer were working at the restaurant. Jennifer decided to give a bone to Amanda',
#  'Then, Samuel and Jeremy went to the station. Jeremy gave a snack to Samuel',
#  'Then, Jeremy and Samuel went to the station. Samuel gave a snack to Jeremy',
#  'Then, Daniel and Emily had a lot of fun at the garden. Daniel gave a drink to Emily',
#  'Then, Emily and Daniel had a lot of fun at the garden. Emily gave a drink to Daniel',
#  'While Paul and Joseph were commuting to the restaurant, Paul gave a ring to Joseph',
#  'While Joseph and Paul were commuting to the restaurant, Joseph gave a ring to Paul',
#  'While Steven and Nathan were commuting to the store, Nathan gave a drink to Steven',
#  'While Nathan and Steven were commuting to the store, Steven gave a drink to Nathan',
#  'Afterwards, Charles and Christine went to the garden. Charles gave a ring to Christine',
#  'Afterwards, Christine and Charles went to the garden. Christine gave a ring to Charles',
#  'Afterwards, Jacob and Jessica went to the restaurant. Jessica gave a snack to Jacob',
#  'Afterwards, Jessica and Jacob went to the restaurant. Jacob gave a snack to Jessica',
#  'Then, Sean and Erin had a long argument, and afterwards Sean said to Erin',
#  'Then, Erin and Sean had a long argument, and afterwards Erin said to Sean',
#  'Then, Michelle and Crystal had a long argument. Afterwards Michelle said to Crystal',
#  'Then, Crystal and Michelle had a long argument. Afterwards Crystal said to Michelle',
#  'When Jamie and Kenneth got a bone at the station, Kenneth decided to give it to Jamie',
#  'When Kenneth and Jamie got a bone at the station, Jamie decided to give it to Kenneth',
#  'Afterwards, Erin and Samuel went to the station. Samuel gave a kiss to Erin',
#  'Afterwards, Samuel and Erin went to the station. Erin gave a kiss to Samuel',
#  'The restaurant Jamie and Mary went to had a computer. Mary gave it to Jamie',
#  'The restaurant Mary and Jamie went to had a computer. Jamie gave it to Mary',
#  'Then, Jeffrey and Bryan went to the station. Bryan gave a bone to Jeffrey',
#  'Then, Bryan and Jeffrey went to the station. Jeffrey gave a bone to Bryan',
#  'Friends Jesse and Brandon found a kiss at the store. Jesse gave it to Brandon',
#  'Friends Brandon and Jesse found a kiss at the store. Brandon gave it to Jesse',
#  'Then, Stephen and Brittany had a lot of fun at the station. Stephen gave a necklace to Brittany',
#  'Then, Brittany and Stephen had a lot of fun at the station. Brittany gave a necklace to Stephen',
#  'Then, Anthony and Brandon had a lot of fun at the station. Brandon gave a snack to Anthony',
#  'Then, Brandon and Anthony had a lot of fun at the station. Anthony gave a snack to Brandon',
#  'When Courtney and Jeffrey got a ring at the garden, Courtney decided to give the ring to Jeffrey',
#  'When Jeffrey and Courtney got a ring at the garden, Jeffrey decided to give the ring to Courtney',
#  'Then, Kevin and Kenneth were working at the hospital. Kevin decided to give a bone to Kenneth',
#  'Then, Kenneth and Kevin were working at the hospital. Kenneth decided to give a bone to Kevin',
#  'Then, Jose and Sarah had a long argument, and afterwards Jose said to Sarah',
#  'Then, Sarah and Jose had a long argument, and afterwards Sarah said to Jose',
#  'The house Daniel and Jeffrey went to had a drink. Daniel gave it to Jeffrey',
#  'The house Jeffrey and Daniel went to had a drink. Jeffrey gave it to Daniel',
#  'After the lunch, Jesse and Amy went to the office. Jesse gave a ring to Amy',
#  'After the lunch, Amy and Jesse went to the office. Amy gave a ring to Jesse',
#  'After Shannon and Cody went to the garden, Shannon gave a snack to Cody',
#  'After Cody and Shannon went to the garden, Cody gave a snack to Shannon',
#  'Then, Kimberly and Jesse had a lot of fun at the house. Kimberly gave a computer to Jesse',
#  'Then, Jesse and Kimberly had a lot of fun at the house. Jesse gave a computer to Kimberly',
#  'Then, Jamie and Katherine had a lot of fun at the hospital. Jamie gave a kiss to Katherine',
#  'Then, Katherine and Jamie had a lot of fun at the hospital. Katherine gave a kiss to Jamie',
#  'While Jason and Jeffrey were working at the garden, Jeffrey gave a computer to Jason',
#  'While Jeffrey and Jason were working at the garden, Jason gave a computer to Jeffrey',
#  'When Shannon and Paul got a snack at the station, Paul decided to give it to Shannon',
#  'When Paul and Shannon got a snack at the station, Shannon decided to give it to Paul',
#  'Then, Matthew and Amy were working at the house. Matthew decided to give a drink to Amy',
#  'Then, Amy and Matthew were working at the house. Amy decided to give a drink to Matthew',
#  'While Daniel and Stephanie were commuting to the school, Daniel gave a ring to Stephanie',
#  'While Stephanie and Daniel were commuting to the school, Stephanie gave a ring to Daniel',
#  'Then, Rebecca and Rachel had a lot of fun at the store. Rachel gave a necklace to Rebecca',
#  'Then, Rachel and Rebecca had a lot of fun at the store. Rebecca gave a necklace to Rachel',
#  'Then, Christine and Jennifer were working at the station. Jennifer decided to give a computer to Christine',
#  'Then, Jennifer and Christine were working at the station. Christine decided to give a computer to Jennifer',
#  'Afterwards, Benjamin and Stephanie went to the restaurant. Stephanie gave a kiss to Benjamin',
#  'Afterwards, Stephanie and Benjamin went to the restaurant. Benjamin gave a kiss to Stephanie',
#  'Afterwards, Sara and Steven went to the office. Sara gave a necklace to Steven',
#  'Afterwards, Steven and Sara went to the office. Steven gave a necklace to Sara',
#  'After Andrew and Brian went to the house, Brian gave a basketball to Andrew',
#  'After Brian and Andrew went to the house, Andrew gave a basketball to Brian',
#  'Then, Mark and Stephen had a long argument. Afterwards Mark said to Stephen',
#  'Then, Stephen and Mark had a long argument. Afterwards Stephen said to Mark',
#  'While Mary and Timothy were commuting to the store, Timothy gave a bone to Mary',
#  'While Timothy and Mary were commuting to the store, Mary gave a bone to Timothy',
#  'When John and Robert got a bone at the office, John decided to give the bone to Robert',
#  'When Robert and John got a bone at the office, Robert decided to give the bone to John',
#  'Then, Lindsay and Nathan were thinking about going to the hospital. Lindsay wanted to give a ring to Nathan',
#  'Then, Nathan and Lindsay were thinking about going to the hospital. Nathan wanted to give a ring to Lindsay',
#  'Then, Amanda and Mark were thinking about going to the hospital. Mark wanted to give a ring to Amanda',
#  'Then, Mark and Amanda were thinking about going to the hospital. Amanda wanted to give a ring to Mark',
#  'Then, Michael and Tyler went to the station. Tyler gave a basketball to Michael',
#  'Then, Tyler and Michael went to the station. Michael gave a basketball to Tyler',
#  'After the lunch, Nicholas and Scott went to the restaurant. Nicholas gave a kiss to Scott',
#  'After the lunch, Scott and Nicholas went to the restaurant. Scott gave a kiss to Nicholas',
#  'Then, Kevin and Allison had a long argument, and afterwards Kevin said to Allison',
#  'Then, Allison and Kevin had a long argument, and afterwards Allison said to Kevin',
#  'Then, Brandon and Jeffrey were thinking about going to the restaurant. Brandon wanted to give a basketball to Jeffrey',
#  'Then, Jeffrey and Brandon were thinking about going to the restaurant. Jeffrey wanted to give a basketball to Brandon',
#  'Then, Timothy and Samantha went to the garden. Timothy gave a necklace to Samantha',
#  'Then, Samantha and Timothy went to the garden. Samantha gave a necklace to Timothy',
#  'Then, Heather and Courtney had a long argument. Afterwards Courtney said to Heather',
#  'Then, Courtney and Heather had a long argument. Afterwards Heather said to Courtney',
#  'Then, Nicholas and Vanessa went to the school. Vanessa gave a snack to Nicholas',
#  'Then, Vanessa and Nicholas went to the school. Nicholas gave a snack to Vanessa',
#  'Then, Angela and Kevin were thinking about going to the store. Angela wanted to give a ring to Kevin',
#  'Then, Kevin and Angela were thinking about going to the store. Kevin wanted to give a ring to Angela',
#  'After James and Paul went to the house, Paul gave a bone to James',
#  'After Paul and James went to the house, James gave a bone to Paul',
#  'While Thomas and John were working at the hospital, Thomas gave a kiss to John',
#  'While John and Thomas were working at the hospital, John gave a kiss to Thomas',
#  'Then, Joseph and James were thinking about going to the hospital. James wanted to give a snack to Joseph',
#  'Then, James and Joseph were thinking about going to the hospital. Joseph wanted to give a snack to James',
#  'After Lindsey and Jeffrey went to the school, Lindsey gave a ring to Jeffrey',
#  'After Jeffrey and Lindsey went to the school, Jeffrey gave a ring to Lindsey',
#  'Afterwards, Bradley and Ryan went to the store. Bradley gave a snack to Ryan',
#  'Afterwards, Ryan and Bradley went to the store. Ryan gave a snack to Bradley',
#  'Friends Heather and Amber found a basketball at the garden. Amber gave it to Heather',
#  'Friends Amber and Heather found a basketball at the garden. Heather gave it to Amber',
#  'Then, Bradley and Christina were working at the store. Christina decided to give a basketball to Bradley',
#  'Then, Christina and Bradley were working at the store. Bradley decided to give a basketball to Christina',
#  'Then, Emily and Jason had a long argument, and afterwards Jason said to Emily',
#  'Then, Jason and Emily had a long argument, and afterwards Emily said to Jason',
#  'Friends Megan and Daniel found a basketball at the restaurant. Daniel gave it to Megan',
#  'Friends Daniel and Megan found a basketball at the restaurant. Megan gave it to Daniel',
#  'Then, Travis and Jose went to the school. Travis gave a drink to Jose',
#  'Then, Jose and Travis went to the school. Jose gave a drink to Travis',
#  'Afterwards, Steven and Michelle went to the garden. Michelle gave a basketball to Steven',
#  'Afterwards, Michelle and Steven went to the garden. Steven gave a basketball to Michelle',
#  'While Tyler and Jacob were working at the school, Tyler gave a ring to Jacob',
#  'While Jacob and Tyler were working at the school, Jacob gave a ring to Tyler',
#  'Then, Stephen and Jose had a long argument. Afterwards Stephen said to Jose',
#  'Then, Jose and Stephen had a long argument. Afterwards Jose said to Stephen',
# ...
#  'Then, Richard and Shannon had a long argument. Afterwards Richard said to Shannon',
#  'While Nicole and Jacob were commuting to the school, Nicole gave a ring to Jacob',
#  'While Jacob and Nicole were commuting to the school, Jacob gave a ring to Nicole',
#  'Then, Jacob and Eric had a long argument. Afterwards Jacob said to Eric',
#  'Then, Eric and Jacob had a long argument. Afterwards Eric said to Jacob',
#  'Then, Kevin and Thomas went to the station. Kevin gave a computer to Thomas',
#  'Then, Thomas and Kevin went to the station. Thomas gave a computer to Kevin',
#  'While Joshua and Paul were commuting to the hospital, Joshua gave a computer to Paul',
#  'While Paul and Joshua were commuting to the hospital, Paul gave a computer to Joshua',
#  'When Ryan and Shannon got a necklace at the restaurant, Ryan decided to give the necklace to Shannon',
#  'When Shannon and Ryan got a necklace at the restaurant, Shannon decided to give the necklace to Ryan',
#  'The office Lindsay and Nicholas went to had a ring. Lindsay gave it to Nicholas',
#  'The office Nicholas and Lindsay went to had a ring. Nicholas gave it to Lindsay',
#  'Friends Dustin and Anthony found a basketball at the station. Dustin gave it to Anthony',
#  'Friends Anthony and Dustin found a basketball at the station. Anthony gave it to Dustin',
#  'Afterwards, Rachel and Kyle went to the store. Rachel gave a ring to Kyle',
#  'Afterwards, Kyle and Rachel went to the store. Kyle gave a ring to Rachel',
#  'Then, Stephen and Nicholas had a long argument, and afterwards Nicholas said to Stephen',
#  'Then, Nicholas and Stephen had a long argument, and afterwards Stephen said to Nicholas',
#  'The restaurant Jacob and Brandon went to had a drink. Brandon gave it to Jacob',
#  'The restaurant Brandon and Jacob went to had a drink. Jacob gave it to Brandon',
#  'Then, Mark and Christina had a long argument. Afterwards Mark said to Christina',
#  'Then, Christina and Mark had a long argument. Afterwards Christina said to Mark',
#  'Then, John and Joseph were working at the house. John decided to give a necklace to Joseph',
#  'Then, Joseph and John were working at the house. Joseph decided to give a necklace to John',
#  'Then, Christopher and Bryan had a long argument, and afterwards Christopher said to Bryan',
#  'Then, Bryan and Christopher had a long argument, and afterwards Bryan said to Christopher',
#  'When Michelle and Nicole got a drink at the store, Michelle decided to give the drink to Nicole',
#  'When Nicole and Michelle got a drink at the store, Nicole decided to give the drink to Michelle',
#  'The store Timothy and David went to had a kiss. Timothy gave it to David',
#  'The store David and Timothy went to had a kiss. David gave it to Timothy',
#  'Then, Steven and Thomas had a lot of fun at the restaurant. Thomas gave a basketball to Steven',
#  'Then, Thomas and Steven had a lot of fun at the restaurant. Steven gave a basketball to Thomas',
#  'Then, Erica and Lindsey had a lot of fun at the school. Lindsey gave a ring to Erica',
#  'Then, Lindsey and Erica had a lot of fun at the school. Erica gave a ring to Lindsey',
#  'While Vanessa and Joshua were working at the station, Joshua gave a snack to Vanessa',
#  'While Joshua and Vanessa were working at the station, Vanessa gave a snack to Joshua',
#  'Then, Anthony and Daniel had a long argument, and afterwards Anthony said to Daniel',
#  'Then, Daniel and Anthony had a long argument, and afterwards Daniel said to Anthony',
#  'Then, Michael and Stephen were thinking about going to the office. Michael wanted to give a basketball to Stephen',
#  'Then, Stephen and Michael were thinking about going to the office. Stephen wanted to give a basketball to Michael',
#  'When Kelly and Jeremy got a ring at the hospital, Jeremy decided to give the ring to Kelly',
#  'When Jeremy and Kelly got a ring at the hospital, Kelly decided to give the ring to Jeremy',
#  'After Christopher and Brian went to the office, Brian gave a necklace to Christopher',
#  'After Brian and Christopher went to the office, Christopher gave a necklace to Brian',
#  'After the lunch, Aaron and Allison went to the school. Allison gave a bone to Aaron',
#  'After the lunch, Allison and Aaron went to the school. Aaron gave a bone to Allison',
#  'Then, James and Jeffrey were working at the hospital. James decided to give a basketball to Jeffrey',
#  'Then, Jeffrey and James were working at the hospital. Jeffrey decided to give a basketball to James',
#  'When Bradley and William got a drink at the store, Bradley decided to give the drink to William',
#  'When William and Bradley got a drink at the store, William decided to give the drink to Bradley',
#  'Then, Steven and Nathan went to the station. Nathan gave a bone to Steven',
#  'Then, Nathan and Steven went to the station. Steven gave a bone to Nathan',
#  'Then, Jeremy and James had a lot of fun at the garden. James gave a basketball to Jeremy',
#  'Then, James and Jeremy had a lot of fun at the garden. Jeremy gave a basketball to James',
#  'While Kelly and Sara were working at the school, Sara gave a necklace to Kelly',
#  'While Sara and Kelly were working at the school, Kelly gave a necklace to Sara',
#  'Friends Dustin and Stephen found a snack at the store. Stephen gave it to Dustin',
#  'Friends Stephen and Dustin found a snack at the store. Dustin gave it to Stephen',
#  'When Christina and Dustin got a bone at the store, Dustin decided to give the bone to Christina',
#  'When Dustin and Christina got a bone at the store, Christina decided to give the bone to Dustin',
#  'While Brittany and Christine were commuting to the house, Brittany gave a drink to Christine',
#  'While Christine and Brittany were commuting to the house, Christine gave a drink to Brittany',
#  'When Andrea and Samuel got a computer at the restaurant, Andrea decided to give the computer to Samuel',
#  'When Samuel and Andrea got a computer at the restaurant, Samuel decided to give the computer to Andrea',
#  'The hospital Megan and Ryan went to had a basketball. Ryan gave it to Megan',
#  'The hospital Ryan and Megan went to had a basketball. Megan gave it to Ryan',
#  'After Michael and Mary went to the garden, Mary gave a snack to Michael',
#  'After Mary and Michael went to the garden, Michael gave a snack to Mary',
#  'Then, Joseph and Megan were thinking about going to the store. Megan wanted to give a kiss to Joseph',
#  'Then, Megan and Joseph were thinking about going to the store. Joseph wanted to give a kiss to Megan',
#  'Then, Aaron and Emily were thinking about going to the restaurant. Aaron wanted to give a basketball to Emily',
#  'Then, Emily and Aaron were thinking about going to the restaurant. Emily wanted to give a basketball to Aaron',
#  'Then, Ashley and Nicholas had a long argument, and afterwards Nicholas said to Ashley',
#  'Then, Nicholas and Ashley had a long argument, and afterwards Ashley said to Nicholas',
#  'The station Sean and Lauren went to had a drink. Sean gave it to Lauren',
#  'The station Lauren and Sean went to had a drink. Lauren gave it to Sean',
#  'Then, Sara and Katherine went to the house. Katherine gave a kiss to Sara',
#  'Then, Katherine and Sara went to the house. Sara gave a kiss to Katherine',
#  'While Patrick and Danielle were working at the hospital, Patrick gave a ring to Danielle',
#  'While Danielle and Patrick were working at the hospital, Danielle gave a ring to Patrick',
#  'The house Stephanie and Cody went to had a drink. Cody gave it to Stephanie',
#  'The house Cody and Stephanie went to had a drink. Stephanie gave it to Cody',
#  'Then, Danielle and Tyler were thinking about going to the garden. Tyler wanted to give a necklace to Danielle',
#  'Then, Tyler and Danielle were thinking about going to the garden. Danielle wanted to give a necklace to Tyler',
#  'Friends Rebecca and Samuel found a computer at the restaurant. Samuel gave it to Rebecca',
#  'Friends Samuel and Rebecca found a computer at the restaurant. Rebecca gave it to Samuel',
#  'Then, Kristen and Tiffany had a long argument, and afterwards Tiffany said to Kristen',
#  'Then, Tiffany and Kristen had a long argument, and afterwards Kristen said to Tiffany',
#  'After the lunch, Allison and Timothy went to the restaurant. Timothy gave a kiss to Allison',
#  'After the lunch, Timothy and Allison went to the restaurant. Allison gave a kiss to Timothy',
#  'Then, Samantha and Jason had a long argument, and afterwards Jason said to Samantha',
#  'Then, Jason and Samantha had a long argument, and afterwards Samantha said to Jason',
#  'After the lunch, Cody and Tiffany went to the office. Tiffany gave a necklace to Cody',
#  'After the lunch, Tiffany and Cody went to the office. Cody gave a necklace to Tiffany',
#  'Then, Nicholas and Timothy had a lot of fun at the restaurant. Nicholas gave a computer to Timothy',
#  'Then, Timothy and Nicholas had a lot of fun at the restaurant. Timothy gave a computer to Nicholas',
#  'After Rachel and Kyle went to the office, Rachel gave a necklace to Kyle',
#  'After Kyle and Rachel went to the office, Kyle gave a necklace to Rachel',
#  'The store Jesse and Alexander went to had a kiss. Alexander gave it to Jesse',
#  'The store Alexander and Jesse went to had a kiss. Jesse gave it to Alexander',
#  'Then, Vanessa and Dustin were working at the office. Dustin decided to give a snack to Vanessa',
#  'Then, Dustin and Vanessa were working at the office. Vanessa decided to give a snack to Dustin',
#  'While Jeremy and Erica were commuting to the hospital, Jeremy gave a necklace to Erica',
#  'While Erica and Jeremy were commuting to the hospital, Erica gave a necklace to Jeremy',
#  'Then, Michelle and Allison were thinking about going to the restaurant. Allison wanted to give a necklace to Michelle',
#  'Then, Allison and Michelle were thinking about going to the restaurant. Michelle wanted to give a necklace to Allison',
#  'After Christina and Erin went to the garden, Erin gave a necklace to Christina',
#  'After Erin and Christina went to the garden, Christina gave a necklace to Erin',
#  'Then, Matthew and William were working at the restaurant. Matthew decided to give a necklace to William',
#  'Then, William and Matthew were working at the restaurant. William decided to give a necklace to Matthew',
#  'After Vanessa and Lisa went to the store, Vanessa gave a drink to Lisa',
#  'After Lisa and Vanessa went to the store, Lisa gave a drink to Vanessa',
#  'After Jesse and Jeremy went to the house, Jeremy gave a necklace to Jesse',
#  'After Jeremy and Jesse went to the house, Jesse gave a necklace to Jeremy',
#  'Then, Shannon and Michelle had a long argument, and afterwards Michelle said to Shannon',
#  'Then, Michelle and Shannon had a long argument, and afterwards Shannon said to Michelle',
#  'Afterwards, Nicholas and Mary went to the hospital. Nicholas gave a snack to Mary',
#  'Afterwards, Mary and Nicholas went to the hospital. Mary gave a snack to Nicholas',
#  'After Kyle and Samantha went to the hospital, Kyle gave a computer to Samantha',
#  'After Samantha and Kyle went to the hospital, Samantha gave a computer to Kyle',
#  'The station Kevin and Kristen went to had a snack. Kristen gave it to Kevin',
#  'The station Kristen and Kevin went to had a snack. Kevin gave it to Kristen',
#  'Then, Crystal and Nathan had a lot of fun at the restaurant. Crystal gave a basketball to Nathan',
#  'Then, Nathan and Crystal had a lot of fun at the restaurant. Nathan gave a basketball to Crystal',
#  'When Matthew and Timothy got a kiss at the office, Timothy decided to give the kiss to Matthew',
#  'When Timothy and Matthew got a kiss at the office, Matthew decided to give the kiss to Timothy',
#  'Afterwards, Mary and James went to the store. Mary gave a bone to James',
#  'Afterwards, James and Mary went to the store. James gave a bone to Mary',
#  'Then, Lisa and Brian were thinking about going to the restaurant. Brian wanted to give a kiss to Lisa',
#  'Then, Brian and Lisa were thinking about going to the restaurant. Lisa wanted to give a kiss to Brian',
#  'After the lunch, Emily and Rebecca went to the house. Rebecca gave a basketball to Emily',
#  'After the lunch, Rebecca and Emily went to the house. Emily gave a basketball to Rebecca',
#  'Friends Sara and Samuel found a snack at the hospital. Samuel gave it to Sara',
#  'Friends Samuel and Sara found a snack at the hospital. Sara gave it to Samuel',
#  'The office Nicholas and Andrew went to had a kiss. Nicholas gave it to Andrew',
#  'The office Andrew and Nicholas went to had a kiss. Andrew gave it to Nicholas',
#  'Then, Justin and James went to the school. Justin gave a basketball to James',
#  'Then, James and Justin went to the school. James gave a basketball to Justin',
#  'The garden Katie and Michael went to had a necklace. Michael gave it to Katie',
#  'The garden Michael and Katie went to had a necklace. Katie gave it to Michael',
#  'Then, Stephanie and Angela had a long argument. Afterwards Stephanie said to Angela',
#  'Then, Angela and Stephanie had a long argument. Afterwards Angela said to Stephanie',
#  'Then, Angela and Dustin went to the station. Angela gave a snack to Dustin',
#  'Then, Dustin and Angela went to the station. Dustin gave a snack to Angela',
#  'While Erica and Nicholas were commuting to the school, Erica gave a snack to Nicholas',
#  'While Nicholas and Erica were commuting to the school, Nicholas gave a snack to Erica',
#  'Then, Michelle and Benjamin had a long argument. Afterwards Benjamin said to Michelle',
#  'Then, Benjamin and Michelle had a long argument. Afterwards Michelle said to Benjamin',
#  'Friends Elizabeth and Christopher found a basketball at the hospital. Christopher gave it to Elizabeth',
#  'Friends Christopher and Elizabeth found a basketball at the hospital. Elizabeth gave it to Christopher',
#  'Then, Aaron and Robert went to the hospital. Aaron gave a kiss to Robert',
#  'Then, Robert and Aaron went to the hospital. Robert gave a kiss to Aaron',
#  'When Kyle and Anthony got a basketball at the store, Kyle decided to give it to Anthony',
#  'When Anthony and Kyle got a basketball at the store, Anthony decided to give it to Kyle',
#  'Then, Christine and Lisa were working at the house. Lisa decided to give a bone to Christine',
#  'Then, Lisa and Christine were working at the house. Christine decided to give a bone to Lisa',
#  'When Erica and Kenneth got a ring at the store, Kenneth decided to give it to Erica',
#  'When Kenneth and Erica got a ring at the store, Erica decided to give it to Kenneth',
#  'Then, Kenneth and Katherine went to the store. Kenneth gave a drink to Katherine',
#  'Then, Katherine and Kenneth went to the store. Katherine gave a drink to Kenneth',
#  'Then, Paul and Cody went to the school. Cody gave a snack to Paul',
#  'Then, Cody and Paul went to the school. Paul gave a snack to Cody',
#  'Then, Allison and Kelly were working at the house. Allison decided to give a kiss to Kelly',
#  'Then, Kelly and Allison were working at the house. Kelly decided to give a kiss to Allison',
#  'When Samantha and Scott got a snack at the station, Samantha decided to give the snack to Scott',
#  'When Scott and Samantha got a snack at the station, Scott decided to give the snack to Samantha',
#  'When Gregory and Jacob got a drink at the store, Jacob decided to give it to Gregory',
#  'When Jacob and Gregory got a drink at the store, Gregory decided to give it to Jacob',
#  'Then, Jose and Scott had a lot of fun at the hospital. Jose gave a bone to Scott',
#  'Then, Scott and Jose had a lot of fun at the hospital. Scott gave a bone to Jose',
#  'While Jonathan and James were working at the house, Jonathan gave a computer to James',
#  'While James and Jonathan were working at the house, James gave a computer to Jonathan',
#  'Friends Stephen and David found a necklace at the office. David gave it to Stephen',
#  'Friends David and Stephen found a necklace at the office. Stephen gave it to David',
#  'When Joseph and Nicholas got a ring at the office, Nicholas decided to give the ring to Joseph',
#  'When Nicholas and Joseph got a ring at the office, Joseph decided to give the ring to Nicholas',
#  ...]

# %%
# save sentences in train_test_split
import pickle

prompts_train = ioi_prompts[:8000]
prompts_test = ioi_prompts[8000:]
with open("data/ioi_prompts_train.pkl", "wb") as f:
    pickle.dump(prompts_train, f)
with open("data/ioi_prompts_test.pkl", "wb") as f:
    pickle.dump(prompts_test, f)
