# %%
import re
import random as rd

# %%
# IOI Dataset

NAMES = [
    "Michael",
    "Christopher",
    "Jessica",
    "Matthew",
    "Ashley",
    "Jennifer",
    "Joshua",
    "Amanda",
    "Daniel",
    "David",
    "James",
    "Robert",
    "John",
    "Joseph",
    "Andrew",
    "Ryan",
    "Brandon",
    "Jason",
    "Justin",
    "Sarah",
    "William",
    "Jonathan",
    "Stephanie",
    "Brian",
    "Nicole",
    "Nicholas",
    "Anthony",
    "Heather",
    "Eric",
    "Elizabeth",
    "Adam",
    "Megan",
    "Melissa",
    "Kevin",
    "Steven",
    "Thomas",
    "Timothy",
    "Christina",
    "Kyle",
    "Rachel",
    "Laura",
    "Lauren",
    "Amber",
    "Brittany",
    "Danielle",
    "Richard",
    "Kimberly",
    "Jeffrey",
    "Amy",
    "Crystal",
    "Michelle",
    "Tiffany",
    "Jeremy",
    "Benjamin",
    "Mark",
    "Emily",
    "Aaron",
    "Charles",
    "Rebecca",
    "Jacob",
    "Stephen",
    "Patrick",
    "Sean",
    "Erin",
    "Jamie",
    "Kelly",
    "Samantha",
    "Nathan",
    "Sara",
    "Dustin",
    "Paul",
    "Angela",
    "Tyler",
    "Scott",
    "Katherine",
    "Andrea",
    "Gregory",
    "Erica",
    "Mary",
    "Travis",
    "Lisa",
    "Kenneth",
    "Bryan",
    "Lindsey",
    "Kristen",
    "Jose",
    "Alexander",
    "Jesse",
    "Katie",
    "Lindsay",
    "Shannon",
    "Vanessa",
    "Courtney",
    "Christine",
    "Alicia",
    "Cody",
    "Allison",
    "Bradley",
    "Samuel",
]

ABC_TEMPLATES = [
    "Then, [A], [B] and [C] went to the [PLACE]. [B] and [C] gave a [OBJECT] to [A]",
    "Afterwards [A], [B] and [C] went to the [PLACE]. [B] and [C] gave a [OBJECT] to [A]",
    "When [A], [B] and [C] arrived at the [PLACE], [B] and [C] gave a [OBJECT] to [A]",
    "Friends [A], [B] and [C] went to the [PLACE]. [B] and [C] gave a [OBJECT] to [A]",
]

BAC_TEMPLATES = [
    template.replace("[B]", "[A]", 1).replace("[A]", "[B]", 1)
    for template in ABC_TEMPLATES
]

BABA_TEMPLATES = [
    "Then, [B] and [A] went to the [PLACE]. [B] gave a [OBJECT] to [A]",
    "Then, [B] and [A] had a lot of fun at the [PLACE]. [B] gave a [OBJECT] to [A]",
    "Then, [B] and [A] were working at the [PLACE]. [B] decided to give a [OBJECT] to [A]",
    "Then, [B] and [A] were thinking about going to the [PLACE]. [B] wanted to give a [OBJECT] to [A]",
    "Then, [B] and [A] had a long argument, and afterwards [B] said to [A]",
    "After [B] and [A] went to the [PLACE], [B] gave a [OBJECT] to [A]",
    "When [B] and [A] got a [OBJECT] at the [PLACE], [B] decided to give it to [A]",
    "When [B] and [A] got a [OBJECT] at the [PLACE], [B] decided to give the [OBJECT] to [A]",
    "While [B] and [A] were working at the [PLACE], [B] gave a [OBJECT] to [A]",
    "While [B] and [A] were commuting to the [PLACE], [B] gave a [OBJECT] to [A]",
    "After the lunch, [B] and [A] went to the [PLACE]. [B] gave a [OBJECT] to [A]",
    "Afterwards, [B] and [A] went to the [PLACE]. [B] gave a [OBJECT] to [A]",
    "Then, [B] and [A] had a long argument. Afterwards [B] said to [A]",
    "The [PLACE] [B] and [A] went to had a [OBJECT]. [B] gave it to [A]",
    "Friends [B] and [A] found a [OBJECT] at the [PLACE]. [B] gave it to [A]",
]

BABA_LONG_TEMPLATES = [
    "Then in the morning, [B] and [A] went to the [PLACE]. [B] gave a [OBJECT] to [A]",
    "Then in the morning, [B] and [A] had a lot of fun at the [PLACE]. [B] gave a [OBJECT] to [A]",
    "Then in the morning, [B] and [A] were working at the [PLACE]. [B] decided to give a [OBJECT] to [A]",
    "Then in the morning, [B] and [A] were thinking about going to the [PLACE]. [B] wanted to give a [OBJECT] to [A]",
    "Then in the morning, [B] and [A] had a long argument, and afterwards [B] said to [A]",
    "After taking a long break [B] and [A] went to the [PLACE], [B] gave a [OBJECT] to [A]",
    "When soon afterwards [B] and [A] got a [OBJECT] at the [PLACE], [B] decided to give it to [A]",
    "When soon afterwards [B] and [A] got a [OBJECT] at the [PLACE], [B] decided to give the [OBJECT] to [A]",
    "While spending time together [B] and [A] were working at the [PLACE], [B] gave a [OBJECT] to [A]",
    "While spending time together [B] and [A] were commuting to the [PLACE], [B] gave a [OBJECT] to [A]",
    "After the lunch in the afternoon, [B] and [A] went to the [PLACE]. [B] gave a [OBJECT] to [A]",
    "Afterwards, while spending time together [B] and [A] went to the [PLACE]. [B] gave a [OBJECT] to [A]",
    "Then in the morning afterwards, [B] and [A] had a long argument. Afterwards [B] said to [A]",
    "The local big [PLACE] [B] and [A] went to had a [OBJECT]. [B] gave it to [A]",
    "Friends separated at birth [B] and [A] found a [OBJECT] at the [PLACE]. [B] gave it to [A]",
]

BABA_LATE_IOS = [
    "Then, [B] and [A] went to the [PLACE]. [B] gave a [OBJECT] to [A]",
    "Then, [B] and [A] had a lot of fun at the [PLACE]. [B] gave a [OBJECT] to [A]",
    "Then, [B] and [A] were working at the [PLACE]. [B] decided to give a [OBJECT] to [A]",
    "Then, [B] and [A] were thinking about going to the [PLACE]. [B] wanted to give a [OBJECT] to [A]",
    "Then, [B] and [A] had a long argument and after that [B] said to [A]",
    "After the lunch, [B] and [A] went to the [PLACE]. [B] gave a [OBJECT] to [A]",
    "Afterwards, [B] and [A] went to the [PLACE]. [B] gave a [OBJECT] to [A]",
    "Then, [B] and [A] had a long argument. Afterwards [B] said to [A]",
]

BABA_EARLY_IOS = [
    "Then [B] and [A] went to the [PLACE], and [B] gave a [OBJECT] to [A]",
    "Then [B] and [A] had a lot of fun at the [PLACE], and [B] gave a [OBJECT] to [A]",
    "Then [B] and [A] were working at the [PLACE], and [B] decided to give a [OBJECT] to [A]",
    "Then [B] and [A] were thinking about going to the [PLACE], and [B] wanted to give a [OBJECT] to [A]",
    "Then [B] and [A] had a long argument, and after that [B] said to [A]",
    "After the lunch [B] and [A] went to the [PLACE], and [B] gave a [OBJECT] to [A]",
    "Afterwards [B] and [A] went to the [PLACE], and [B] gave a [OBJECT] to [A]",
    "Then [B] and [A] had a long argument, and afterwards [B] said to [A]",
]

TEMPLATES_VARIED_MIDDLE = [
    "",
]

# no end of texts, GPT-2 small wasn't trained this way (ask Arthur)
# warnings.warn("Adding end of text prefixes!")
# for TEMPLATES in [BABA_TEMPLATES, BABA_EARLY_IOS, BABA_LATE_IOS]:
#     for i in range(len(TEMPLATES)):
#         TEMPLATES[i] = "<|endoftext|>" + TEMPLATES[i]

ABBA_TEMPLATES = BABA_TEMPLATES[:]
ABBA_LATE_IOS = BABA_LATE_IOS[:]
ABBA_EARLY_IOS = BABA_EARLY_IOS[:]

# %%
VERBS = [" tried", " said", " decided", " wanted", " gave"]
PLACES = [
    "store",
    "garden",
    "restaurant",
    "school",
    "hospital",
    "office",
    "house",
    "station",
]
OBJECTS = [
    "ring",
    "kiss",
    "bone",
    "basketball",
    "computer",
    "necklace",
    "drink",
    "snack",
]

ANIMALS = [
    "dog",
    "cat",
    "snake",
    "elephant",
    "beetle",
    "hippo",
    "giraffe",
    "tiger",
    "husky",
    "lion",
    "panther",
    "whale",
    "dolphin",
    "beaver",
    "rabbit",
    "fox",
    "lamb",
    "ferret",
]

# %%
for TEMPLATES in [ABBA_TEMPLATES, ABBA_LATE_IOS, ABBA_EARLY_IOS]:
    for i in range(len(TEMPLATES)):
        first_clause = True
        for j in range(1, len(TEMPLATES[i]) - 1):
            if TEMPLATES[i][j - 1 : j + 2] == "[B]" and first_clause:
                TEMPLATES[i] = TEMPLATES[i][:j] + "A" + TEMPLATES[i][j + 1 :]
            elif TEMPLATES[i][j - 1 : j + 2] == "[A]" and first_clause:
                first_clause = False
                TEMPLATES[i] = TEMPLATES[i][:j] + "B" + TEMPLATES[i][j + 1 :]


def multiple_replace(dict, text):
    # from: https://stackoverflow.com/questions/15175142/how-can-i-do-multiple-substitutions-using-regex
    # Create a regular expression from the dictionary keys
    regex = re.compile("(%s)" % "|".join(map(re.escape, dict.keys())))

    # For each match, look-up corresponding value in dictionary
    return regex.sub(lambda mo: dict[mo.string[mo.start() : mo.end()]], text)


def iter_sample_fast(iterable, samplesize):
    results = []
    # Fill in the first samplesize elements:
    try:
        for _ in range(samplesize):
            results.append(next(iterable))
    except StopIteration:
        raise ValueError("Sample larger than population.")
    rd.shuffle(results)  # Randomize their positions

    return results


NOUNS_DICT = NOUNS_DICT = {"[PLACE]": PLACES, "[OBJECT]": OBJECTS}


def gen_prompt_uniform(
    templates, names, nouns_dict, N, symmetric=False, prefixes=None, abc=False
):
    nb_gen = 0
    ioi_prompts = []
    while nb_gen < N:
        temp = rd.choice(templates)
        temp_id = templates.index(temp)
        name_1 = ""
        name_2 = ""
        name_3 = ""
        while len(set([name_1, name_2, name_3])) < 3:
            name_1 = rd.choice(names)
            name_2 = rd.choice(names)
            name_3 = rd.choice(names)

        nouns = {}
        ioi_prompt = {}
        for k in nouns_dict:
            nouns[k] = rd.choice(nouns_dict[k])
            ioi_prompt[k] = nouns[k]
        prompt = temp
        for k in nouns_dict:
            prompt = prompt.replace(k, nouns[k])

        if prefixes is not None:
            L = rd.randint(30, 40)
            pref = ".".join(rd.choice(prefixes).split(".")[:L])
            pref += "<|endoftext|>"
        else:
            pref = ""

        prompt1 = prompt.replace("[A]", name_1)
        prompt1 = prompt1.replace("[B]", name_2)
        if abc:
            prompt1 = prompt1.replace("[C]", name_3)
        prompt1 = pref + prompt1
        ioi_prompt["text"] = prompt1
        ioi_prompt["IO"] = name_1
        ioi_prompt["S"] = name_2
        ioi_prompt["TEMPLATE_IDX"] = temp_id
        ioi_prompts.append(ioi_prompt)
        if abc:
            ioi_prompts[-1]["C"] = name_3

        nb_gen += 1

        if symmetric and nb_gen < N:
            prompt2 = prompt.replace("[A]", name_2)
            prompt2 = prompt2.replace("[B]", name_1)
            prompt2 = pref + prompt2
            ioi_prompts.append(
                {"text": prompt2, "IO": name_2, "S": name_1, "TEMPLATE_IDX": temp_id}
            )
            nb_gen += 1
    return ioi_prompts

# %%
ioi_prompts_single_template = gen_prompt_uniform(
    [BABA_TEMPLATES[0]], NAMES, NOUNS_DICT, 10000, True, abc=False
)
# Make sentences with each template for train and test
ioi_prompts = gen_prompt_uniform(
    BABA_TEMPLATES + ABBA_TEMPLATES, NAMES, NOUNS_DICT, 10000, True, abc=False
)

BABA_TEMPLATES + ABBA_TEMPLATES
# Out:
# ['Then, [B] and [A] went to the [PLACE]. [B] gave a [OBJECT] to [A]',
#  'Then, [B] and [A] had a lot of fun at the [PLACE]. [B] gave a [OBJECT] to [A]',
#  'Then, [B] and [A] were working at the [PLACE]. [B] decided to give a [OBJECT] to [A]',
#  'Then, [B] and [A] were thinking about going to the [PLACE]. [B] wanted to give a [OBJECT] to [A]',
#  'Then, [B] and [A] had a long argument, and afterwards [B] said to [A]',
#  'After [B] and [A] went to the [PLACE], [B] gave a [OBJECT] to [A]',
#  'When [B] and [A] got a [OBJECT] at the [PLACE], [B] decided to give it to [A]',
#  'When [B] and [A] got a [OBJECT] at the [PLACE], [B] decided to give the [OBJECT] to [A]',
#  'While [B] and [A] were working at the [PLACE], [B] gave a [OBJECT] to [A]',
#  'While [B] and [A] were commuting to the [PLACE], [B] gave a [OBJECT] to [A]',
#  'After the lunch, [B] and [A] went to the [PLACE]. [B] gave a [OBJECT] to [A]',
#  'Afterwards, [B] and [A] went to the [PLACE]. [B] gave a [OBJECT] to [A]',
#  'Then, [B] and [A] had a long argument. Afterwards [B] said to [A]',
#  'The [PLACE] [B] and [A] went to had a [OBJECT]. [B] gave it to [A]',
#  'Friends [B] and [A] found a [OBJECT] at the [PLACE]. [B] gave it to [A]',
#  'Then, [A] and [B] went to the [PLACE]. [B] gave a [OBJECT] to [A]',
#  'Then, [A] and [B] had a lot of fun at the [PLACE]. [B] gave a [OBJECT] to [A]',
#  'Then, [A] and [B] were working at the [PLACE]. [B] decided to give a [OBJECT] to [A]',
#  'Then, [A] and [B] were thinking about going to the [PLACE]. [B] wanted to give a [OBJECT] to [A]',
#  'Then, [A] and [B] had a long argument, and afterwards [B] said to [A]',
#  'After [A] and [B] went to the [PLACE], [B] gave a [OBJECT] to [A]',
#  'When [A] and [B] got a [OBJECT] at the [PLACE], [B] decided to give it to [A]',
#  'When [A] and [B] got a [OBJECT] at the [PLACE], [B] decided to give the [OBJECT] to [A]',
#  'While [A] and [B] were working at the [PLACE], [B] gave a [OBJECT] to [A]',
#  'While [A] and [B] were commuting to the [PLACE], [B] gave a [OBJECT] to [A]',
#  'After the lunch, [A] and [B] went to the [PLACE]. [B] gave a [OBJECT] to [A]',
#  'Afterwards, [A] and [B] went to the [PLACE]. [B] gave a [OBJECT] to [A]',
#  'Then, [A] and [B] had a long argument. Afterwards [B] said to [A]',
#  'The [PLACE] [A] and [B] went to had a [OBJECT]. [B] gave it to [A]',
#  'Friends [A] and [B] found a [OBJECT] at the [PLACE]. [B] gave it to [A]']

# %%
# replace the first occurence of B in BABA and ABBA with C
non_ioi_templates = []
for template in ABBA_TEMPLATES + BABA_TEMPLATES:
    non_ioi_templates.append(template.replace("[B]", "[C]").replace("[C]", "[B]", 1))


ioi_prompts_abc = gen_prompt_uniform(
    non_ioi_templates, NAMES, NOUNS_DICT, 10000, False, abc=True
)

ioi_prompts_single_template_abc = gen_prompt_uniform(
    [non_ioi_templates[0]], NAMES, NOUNS_DICT, 10000, False, abc=True
)

# %%
len(ioi_prompts_single_template_abc)
# Out:
# 10000

# %%
# save sentences in train_test_split
import pickle

prompts_single_template_train = ioi_prompts_single_template[:8000]
prompts_single_template_test = ioi_prompts_single_template[8000:]
with open("data/ioi_prompts_single_template_train.pkl", "wb") as f:
    pickle.dump(prompts_single_template_train, f)
with open("data/ioi_prompts_single_template_test.pkl", "wb") as f:
    pickle.dump(prompts_single_template_test, f)

prompts_single_template_abc_train = ioi_prompts_single_template_abc[:8000]
prompts_single_template_abc_test = ioi_prompts_single_template_abc[8000:]
with open("data/ioi_prompts_single_template_abc_train.pkl", "wb") as f:
    pickle.dump(prompts_single_template_abc_train, f)
with open("data/ioi_prompts_single_template_abc_test.pkl", "wb") as f:
    pickle.dump(prompts_single_template_abc_test, f)

# %%
ioi_prompts_single_template_abc
# Out:
# [{'[PLACE]': 'school',
#   '[OBJECT]': 'basketball',
#   'text': 'Then, Joseph and Jonathan went to the school. Sean gave a basketball to Joseph',
#   'IO': 'Joseph',
#   'S': 'Jonathan',
#   'TEMPLATE_IDX': 0,
#   'C': 'Sean'},
#  {'[PLACE]': 'house',
#   '[OBJECT]': 'ring',
#   'text': 'Then, Gregory and Michelle went to the house. Justin gave a ring to Gregory',
#   'IO': 'Gregory',
#   'S': 'Michelle',
#   'TEMPLATE_IDX': 0,
#   'C': 'Justin'},
#  {'[PLACE]': 'garden',
#   '[OBJECT]': 'necklace',
#   'text': 'Then, William and Megan went to the garden. Tyler gave a necklace to William',
#   'IO': 'William',
#   'S': 'Megan',
#   'TEMPLATE_IDX': 0,
#   'C': 'Tyler'},
#  {'[PLACE]': 'store',
#   '[OBJECT]': 'kiss',
#   'text': 'Then, Samantha and Katherine went to the store. Andrew gave a kiss to Samantha',
#   'IO': 'Samantha',
#   'S': 'Katherine',
#   'TEMPLATE_IDX': 0,
#   'C': 'Andrew'},
#  {'[PLACE]': 'hospital',
#   '[OBJECT]': 'ring',
#   'text': 'Then, Danielle and Jeffrey went to the hospital. Michelle gave a ring to Danielle',
#   'IO': 'Danielle',
#   'S': 'Jeffrey',
#   'TEMPLATE_IDX': 0,
#   'C': 'Michelle'},
#  {'[PLACE]': 'office',
#   '[OBJECT]': 'bone',
#   'text': 'Then, Kimberly and Sara went to the office. Kyle gave a bone to Kimberly',
#   'IO': 'Kimberly',
#   'S': 'Sara',
#   'TEMPLATE_IDX': 0,
#   'C': 'Kyle'},
#  {'[PLACE]': 'restaurant',
#   '[OBJECT]': 'ring',
#   'text': 'Then, Ashley and Brian went to the restaurant. Robert gave a ring to Ashley',
#   'IO': 'Ashley',
#   'S': 'Brian',
#   'TEMPLATE_IDX': 0,
#   'C': 'Robert'},
#  {'[PLACE]': 'restaurant',
#   '[OBJECT]': 'computer',
#   'text': 'Then, Tiffany and Bryan went to the restaurant. Andrea gave a computer to Tiffany',
#   'IO': 'Tiffany',
#   'S': 'Bryan',
#   'TEMPLATE_IDX': 0,
#   'C': 'Andrea'},
#  {'[PLACE]': 'garden',
#   '[OBJECT]': 'kiss',
#   'text': 'Then, Michael and Steven went to the garden. Amy gave a kiss to Michael',
#   'IO': 'Michael',
#   'S': 'Steven',
#   'TEMPLATE_IDX': 0,
#   'C': 'Amy'},
#  {'[PLACE]': 'office',
#   '[OBJECT]': 'kiss',
#   'text': 'Then, Kyle and Crystal went to the office. Kenneth gave a kiss to Kyle',
#   'IO': 'Kyle',
#   'S': 'Crystal',
#   'TEMPLATE_IDX': 0,
#   'C': 'Kenneth'},
#  {'[PLACE]': 'restaurant',
#   '[OBJECT]': 'drink',
#   'text': 'Then, Matthew and Richard went to the restaurant. Jose gave a drink to Matthew',
#   'IO': 'Matthew',
#   'S': 'Richard',
#   'TEMPLATE_IDX': 0,
#   'C': 'Jose'},
#  {'[PLACE]': 'hospital',
#   '[OBJECT]': 'drink',
#   'text': 'Then, Stephanie and Matthew went to the hospital. Joshua gave a drink to Stephanie',
#   'IO': 'Stephanie',
#   'S': 'Matthew',
#   'TEMPLATE_IDX': 0,
#   'C': 'Joshua'},
#  {'[PLACE]': 'garden',
#   '[OBJECT]': 'bone',
#   'text': 'Then, Matthew and Katie went to the garden. Joseph gave a bone to Matthew',
#   'IO': 'Matthew',
#   'S': 'Katie',
#   'TEMPLATE_IDX': 0,
#   'C': 'Joseph'},
#  {'[PLACE]': 'school',
#   '[OBJECT]': 'kiss',
#   'text': 'Then, Thomas and Erica went to the school. Joshua gave a kiss to Thomas',
#   'IO': 'Thomas',
#   'S': 'Erica',
#   'TEMPLATE_IDX': 0,
#   'C': 'Joshua'},
#  {'[PLACE]': 'office',
#   '[OBJECT]': 'bone',
#   'text': 'Then, Brittany and Bradley went to the office. Robert gave a bone to Brittany',
#   'IO': 'Brittany',
#   'S': 'Bradley',
#   'TEMPLATE_IDX': 0,
#   'C': 'Robert'},
#  {'[PLACE]': 'restaurant',
#   '[OBJECT]': 'computer',
#   'text': 'Then, Dustin and Jacob went to the restaurant. Erica gave a computer to Dustin',
#   'IO': 'Dustin',
#   'S': 'Jacob',
#   'TEMPLATE_IDX': 0,
#   'C': 'Erica'},
#  {'[PLACE]': 'station',
#   '[OBJECT]': 'computer',
#   'text': 'Then, Richard and Kevin went to the station. Jesse gave a computer to Richard',
#   'IO': 'Richard',
#   'S': 'Kevin',
#   'TEMPLATE_IDX': 0,
#   'C': 'Jesse'},
#  {'[PLACE]': 'restaurant',
#   '[OBJECT]': 'snack',
#   'text': 'Then, Christine and Gregory went to the restaurant. Mary gave a snack to Christine',
#   'IO': 'Christine',
#   'S': 'Gregory',
#   'TEMPLATE_IDX': 0,
#   'C': 'Mary'},
#  {'[PLACE]': 'station',
#   '[OBJECT]': 'necklace',
#   'text': 'Then, Michelle and Nicholas went to the station. Lindsey gave a necklace to Michelle',
#   'IO': 'Michelle',
#   'S': 'Nicholas',
#   'TEMPLATE_IDX': 0,
#   'C': 'Lindsey'},
#  {'[PLACE]': 'school',
#   '[OBJECT]': 'ring',
#   'text': 'Then, Jeremy and Paul went to the school. Jason gave a ring to Jeremy',
#   'IO': 'Jeremy',
#   'S': 'Paul',
#   'TEMPLATE_IDX': 0,
#   'C': 'Jason'},
#  {'[PLACE]': 'station',
#   '[OBJECT]': 'computer',
#   'text': 'Then, Travis and Patrick went to the station. Justin gave a computer to Travis',
#   'IO': 'Travis',
#   'S': 'Patrick',
#   'TEMPLATE_IDX': 0,
#   'C': 'Justin'},
#  {'[PLACE]': 'office',
#   '[OBJECT]': 'bone',
#   'text': 'Then, Tiffany and Tyler went to the office. Rachel gave a bone to Tiffany',
#   'IO': 'Tiffany',
#   'S': 'Tyler',
#   'TEMPLATE_IDX': 0,
#   'C': 'Rachel'},
#  {'[PLACE]': 'house',
#   '[OBJECT]': 'kiss',
#   'text': 'Then, Richard and Patrick went to the house. James gave a kiss to Richard',
#   'IO': 'Richard',
#   'S': 'Patrick',
#   'TEMPLATE_IDX': 0,
#   'C': 'James'},
#  {'[PLACE]': 'restaurant',
#   '[OBJECT]': 'ring',
#   'text': 'Then, Megan and Jessica went to the restaurant. Robert gave a ring to Megan',
#   'IO': 'Megan',
#   'S': 'Jessica',
#   'TEMPLATE_IDX': 0,
#   'C': 'Robert'},
#  {'[PLACE]': 'house',
#   '[OBJECT]': 'basketball',
#   'text': 'Then, Mary and David went to the house. Elizabeth gave a basketball to Mary',
#   'IO': 'Mary',
#   'S': 'David',
#   'TEMPLATE_IDX': 0,
#   'C': 'Elizabeth'},
#  {'[PLACE]': 'station',
#   '[OBJECT]': 'bone',
#   'text': 'Then, Tiffany and Vanessa went to the station. Melissa gave a bone to Tiffany',
#   'IO': 'Tiffany',
#   'S': 'Vanessa',
#   'TEMPLATE_IDX': 0,
#   'C': 'Melissa'},
#  {'[PLACE]': 'restaurant',
#   '[OBJECT]': 'ring',
#   'text': 'Then, Kenneth and Stephanie went to the restaurant. James gave a ring to Kenneth',
#   'IO': 'Kenneth',
#   'S': 'Stephanie',
#   'TEMPLATE_IDX': 0,
#   'C': 'James'},
#  {'[PLACE]': 'station',
#   '[OBJECT]': 'ring',
#   'text': 'Then, Cody and Mary went to the station. Jesse gave a ring to Cody',
#   'IO': 'Cody',
#   'S': 'Mary',
#   'TEMPLATE_IDX': 0,
#   'C': 'Jesse'},
#  {'[PLACE]': 'school',
#   '[OBJECT]': 'bone',
#   'text': 'Then, Lindsey and Daniel went to the school. Katie gave a bone to Lindsey',
#   'IO': 'Lindsey',
#   'S': 'Daniel',
#   'TEMPLATE_IDX': 0,
#   'C': 'Katie'},
#  {'[PLACE]': 'office',
#   '[OBJECT]': 'basketball',
#   'text': 'Then, Richard and Patrick went to the office. Christopher gave a basketball to Richard',
#   'IO': 'Richard',
#   'S': 'Patrick',
#   'TEMPLATE_IDX': 0,
#   'C': 'Christopher'},
#  {'[PLACE]': 'store',
#   '[OBJECT]': 'kiss',
#   'text': 'Then, Stephen and Erica went to the store. Eric gave a kiss to Stephen',
#   'IO': 'Stephen',
#   'S': 'Erica',
#   'TEMPLATE_IDX': 0,
#   'C': 'Eric'},
#  {'[PLACE]': 'restaurant',
#   '[OBJECT]': 'kiss',
#   'text': 'Then, Nicole and Jason went to the restaurant. Travis gave a kiss to Nicole',
#   'IO': 'Nicole',
#   'S': 'Jason',
#   'TEMPLATE_IDX': 0,
#   'C': 'Travis'},
#  {'[PLACE]': 'office',
#   '[OBJECT]': 'computer',
#   'text': 'Then, Michelle and Lindsay went to the office. Justin gave a computer to Michelle',
#   'IO': 'Michelle',
#   'S': 'Lindsay',
#   'TEMPLATE_IDX': 0,
#   'C': 'Justin'},
#  {'[PLACE]': 'house',
#   '[OBJECT]': 'computer',
#   'text': 'Then, Lindsay and Jason went to the house. Nathan gave a computer to Lindsay',
#   'IO': 'Lindsay',
#   'S': 'Jason',
#   'TEMPLATE_IDX': 0,
#   'C': 'Nathan'},
#  {'[PLACE]': 'house',
#   '[OBJECT]': 'drink',
#   'text': 'Then, Mark and Gregory went to the house. Ryan gave a drink to Mark',
#   'IO': 'Mark',
#   'S': 'Gregory',
#   'TEMPLATE_IDX': 0,
#   'C': 'Ryan'},
#  {'[PLACE]': 'store',
#   '[OBJECT]': 'snack',
#   'text': 'Then, Justin and Matthew went to the store. Patrick gave a snack to Justin',
#   'IO': 'Justin',
#   'S': 'Matthew',
#   'TEMPLATE_IDX': 0,
#   'C': 'Patrick'},
#  {'[PLACE]': 'store',
#   '[OBJECT]': 'kiss',
#   'text': 'Then, Angela and Jason went to the store. Bryan gave a kiss to Angela',
#   'IO': 'Angela',
#   'S': 'Jason',
#   'TEMPLATE_IDX': 0,
#   'C': 'Bryan'},
#  {'[PLACE]': 'restaurant',
#   '[OBJECT]': 'drink',
#   'text': 'Then, Kimberly and Christina went to the restaurant. Bradley gave a drink to Kimberly',
#   'IO': 'Kimberly',
#   'S': 'Christina',
#   'TEMPLATE_IDX': 0,
#   'C': 'Bradley'},
#  {'[PLACE]': 'store',
#   '[OBJECT]': 'bone',
#   'text': 'Then, Ryan and Amber went to the store. Brandon gave a bone to Ryan',
#   'IO': 'Ryan',
#   'S': 'Amber',
#   'TEMPLATE_IDX': 0,
#   'C': 'Brandon'},
#  {'[PLACE]': 'restaurant',
#   '[OBJECT]': 'necklace',
#   'text': 'Then, Katherine and Brittany went to the restaurant. Charles gave a necklace to Katherine',
#   'IO': 'Katherine',
#   'S': 'Brittany',
#   'TEMPLATE_IDX': 0,
#   'C': 'Charles'},
#  {'[PLACE]': 'office',
#   '[OBJECT]': 'computer',
#   'text': 'Then, Patrick and Rachel went to the office. Eric gave a computer to Patrick',
#   'IO': 'Patrick',
#   'S': 'Rachel',
#   'TEMPLATE_IDX': 0,
#   'C': 'Eric'},
#  {'[PLACE]': 'station',
#   '[OBJECT]': 'necklace',
#   'text': 'Then, John and William went to the station. Richard gave a necklace to John',
#   'IO': 'John',
#   'S': 'William',
#   'TEMPLATE_IDX': 0,
#   'C': 'Richard'},
#  {'[PLACE]': 'hospital',
#   '[OBJECT]': 'necklace',
#   'text': 'Then, James and Stephanie went to the hospital. Bradley gave a necklace to James',
#   'IO': 'James',
#   'S': 'Stephanie',
#   'TEMPLATE_IDX': 0,
#   'C': 'Bradley'},
#  {'[PLACE]': 'hospital',
#   '[OBJECT]': 'ring',
#   'text': 'Then, Allison and Sara went to the hospital. Christina gave a ring to Allison',
#   'IO': 'Allison',
#   'S': 'Sara',
#   'TEMPLATE_IDX': 0,
#   'C': 'Christina'},
#  {'[PLACE]': 'school',
#   '[OBJECT]': 'basketball',
#   'text': 'Then, Charles and Matthew went to the school. Kenneth gave a basketball to Charles',
#   'IO': 'Charles',
#   'S': 'Matthew',
#   'TEMPLATE_IDX': 0,
#   'C': 'Kenneth'},
#  {'[PLACE]': 'restaurant',
#   '[OBJECT]': 'ring',
#   'text': 'Then, Amber and Travis went to the restaurant. John gave a ring to Amber',
#   'IO': 'Amber',
#   'S': 'Travis',
#   'TEMPLATE_IDX': 0,
#   'C': 'John'},
#  {'[PLACE]': 'office',
#   '[OBJECT]': 'snack',
#   'text': 'Then, Ryan and Lisa went to the office. Jeremy gave a snack to Ryan',
#   'IO': 'Ryan',
#   'S': 'Lisa',
#   'TEMPLATE_IDX': 0,
#   'C': 'Jeremy'},
#  {'[PLACE]': 'store',
#   '[OBJECT]': 'ring',
#   'text': 'Then, Sean and Nathan went to the store. Aaron gave a ring to Sean',
#   'IO': 'Sean',
#   'S': 'Nathan',
#   'TEMPLATE_IDX': 0,
#   'C': 'Aaron'},
#  {'[PLACE]': 'store',
#   '[OBJECT]': 'basketball',
#   'text': 'Then, Jessica and Crystal went to the store. Lindsey gave a basketball to Jessica',
#   'IO': 'Jessica',
#   'S': 'Crystal',
#   'TEMPLATE_IDX': 0,
#   'C': 'Lindsey'},
#  {'[PLACE]': 'office',
#   '[OBJECT]': 'ring',
#   'text': 'Then, Jamie and Steven went to the office. Sean gave a ring to Jamie',
#   'IO': 'Jamie',
#   'S': 'Steven',
#   'TEMPLATE_IDX': 0,
#   'C': 'Sean'},
#  {'[PLACE]': 'house',
#   '[OBJECT]': 'kiss',
#   'text': 'Then, Amy and Heather went to the house. Lindsey gave a kiss to Amy',
#   'IO': 'Amy',
#   'S': 'Heather',
#   'TEMPLATE_IDX': 0,
#   'C': 'Lindsey'},
#  {'[PLACE]': 'restaurant',
#   '[OBJECT]': 'ring',
#   'text': 'Then, Courtney and Paul went to the restaurant. Joshua gave a ring to Courtney',
#   'IO': 'Courtney',
#   'S': 'Paul',
#   'TEMPLATE_IDX': 0,
#   'C': 'Joshua'},
#  {'[PLACE]': 'station',
#   '[OBJECT]': 'computer',
#   'text': 'Then, Jacob and Sara went to the station. Jennifer gave a computer to Jacob',
#   'IO': 'Jacob',
#   'S': 'Sara',
#   'TEMPLATE_IDX': 0,
#   'C': 'Jennifer'},
#  {'[PLACE]': 'house',
#   '[OBJECT]': 'ring',
#   'text': 'Then, Robert and Tyler went to the house. Steven gave a ring to Robert',
#   'IO': 'Robert',
#   'S': 'Tyler',
#   'TEMPLATE_IDX': 0,
#   'C': 'Steven'},
#  {'[PLACE]': 'school',
#   '[OBJECT]': 'bone',
#   'text': 'Then, Mary and Sarah went to the school. Richard gave a bone to Mary',
#   'IO': 'Mary',
#   'S': 'Sarah',
#   'TEMPLATE_IDX': 0,
#   'C': 'Richard'},
#  {'[PLACE]': 'hospital',
#   '[OBJECT]': 'bone',
#   'text': 'Then, Christine and Andrew went to the hospital. Shannon gave a bone to Christine',
#   'IO': 'Christine',
#   'S': 'Andrew',
#   'TEMPLATE_IDX': 0,
#   'C': 'Shannon'},
#  {'[PLACE]': 'station',
#   '[OBJECT]': 'kiss',
#   'text': 'Then, Benjamin and Jennifer went to the station. Erica gave a kiss to Benjamin',
#   'IO': 'Benjamin',
#   'S': 'Jennifer',
#   'TEMPLATE_IDX': 0,
#   'C': 'Erica'},
#  {'[PLACE]': 'hospital',
#   '[OBJECT]': 'basketball',
#   'text': 'Then, John and Brian went to the hospital. Crystal gave a basketball to John',
#   'IO': 'John',
#   'S': 'Brian',
#   'TEMPLATE_IDX': 0,
#   'C': 'Crystal'},
#  {'[PLACE]': 'house',
#   '[OBJECT]': 'bone',
#   'text': 'Then, Jacob and Rebecca went to the house. Jeffrey gave a bone to Jacob',
#   'IO': 'Jacob',
#   'S': 'Rebecca',
#   'TEMPLATE_IDX': 0,
#   'C': 'Jeffrey'},
#  {'[PLACE]': 'school',
#   '[OBJECT]': 'basketball',
#   'text': 'Then, Michael and Joseph went to the school. Cody gave a basketball to Michael',
#   'IO': 'Michael',
#   'S': 'Joseph',
#   'TEMPLATE_IDX': 0,
#   'C': 'Cody'},
#  {'[PLACE]': 'store',
#   '[OBJECT]': 'computer',
#   'text': 'Then, Ashley and Jeremy went to the store. Sara gave a computer to Ashley',
#   'IO': 'Ashley',
#   'S': 'Jeremy',
#   'TEMPLATE_IDX': 0,
#   'C': 'Sara'},
#  {'[PLACE]': 'station',
#   '[OBJECT]': 'basketball',
#   'text': 'Then, Nicole and Amy went to the station. Brian gave a basketball to Nicole',
#   'IO': 'Nicole',
#   'S': 'Amy',
#   'TEMPLATE_IDX': 0,
#   'C': 'Brian'},
#  {'[PLACE]': 'garden',
#   '[OBJECT]': 'basketball',
#   'text': 'Then, Jacob and Dustin went to the garden. Sean gave a basketball to Jacob',
#   'IO': 'Jacob',
#   'S': 'Dustin',
#   'TEMPLATE_IDX': 0,
#   'C': 'Sean'},
#  {'[PLACE]': 'restaurant',
#   '[OBJECT]': 'snack',
#   'text': 'Then, Stephanie and Brian went to the restaurant. Crystal gave a snack to Stephanie',
#   'IO': 'Stephanie',
#   'S': 'Brian',
#   'TEMPLATE_IDX': 0,
#   'C': 'Crystal'},
#  {'[PLACE]': 'hospital',
#   '[OBJECT]': 'kiss',
#   'text': 'Then, Jennifer and David went to the hospital. Shannon gave a kiss to Jennifer',
#   'IO': 'Jennifer',
#   'S': 'David',
#   'TEMPLATE_IDX': 0,
#   'C': 'Shannon'},
#  {'[PLACE]': 'house',
#   '[OBJECT]': 'computer',
#   'text': 'Then, Jamie and Charles went to the house. Elizabeth gave a computer to Jamie',
#   'IO': 'Jamie',
#   'S': 'Charles',
#   'TEMPLATE_IDX': 0,
#   'C': 'Elizabeth'},
#  {'[PLACE]': 'school',
#   '[OBJECT]': 'kiss',
#   'text': 'Then, Kyle and Shannon went to the school. Sarah gave a kiss to Kyle',
#   'IO': 'Kyle',
#   'S': 'Shannon',
#   'TEMPLATE_IDX': 0,
#   'C': 'Sarah'},
#  {'[PLACE]': 'station',
#   '[OBJECT]': 'basketball',
#   'text': 'Then, Ryan and Melissa went to the station. David gave a basketball to Ryan',
#   'IO': 'Ryan',
#   'S': 'Melissa',
#   'TEMPLATE_IDX': 0,
#   'C': 'David'},
#  {'[PLACE]': 'hospital',
#   '[OBJECT]': 'ring',
#   'text': 'Then, Rachel and Travis went to the hospital. Sara gave a ring to Rachel',
#   'IO': 'Rachel',
#   'S': 'Travis',
#   'TEMPLATE_IDX': 0,
#   'C': 'Sara'},
#  {'[PLACE]': 'restaurant',
#   '[OBJECT]': 'bone',
#   'text': 'Then, Dustin and Travis went to the restaurant. Andrea gave a bone to Dustin',
#   'IO': 'Dustin',
#   'S': 'Travis',
#   'TEMPLATE_IDX': 0,
#   'C': 'Andrea'},
#  {'[PLACE]': 'school',
#   '[OBJECT]': 'drink',
#   'text': 'Then, Kristen and John went to the school. Christopher gave a drink to Kristen',
#   'IO': 'Kristen',
#   'S': 'John',
#   'TEMPLATE_IDX': 0,
#   'C': 'Christopher'},
#  {'[PLACE]': 'garden',
#   '[OBJECT]': 'basketball',
#   'text': 'Then, Michael and Scott went to the garden. Jessica gave a basketball to Michael',
#   'IO': 'Michael',
#   'S': 'Scott',
#   'TEMPLATE_IDX': 0,
#   'C': 'Jessica'},
#  {'[PLACE]': 'restaurant',
#   '[OBJECT]': 'ring',
#   'text': 'Then, Jose and Jonathan went to the restaurant. Robert gave a ring to Jose',
#   'IO': 'Jose',
#   'S': 'Jonathan',
#   'TEMPLATE_IDX': 0,
#   'C': 'Robert'},
#  {'[PLACE]': 'hospital',
#   '[OBJECT]': 'kiss',
#   'text': 'Then, Nicole and Kimberly went to the hospital. Adam gave a kiss to Nicole',
#   'IO': 'Nicole',
#   'S': 'Kimberly',
#   'TEMPLATE_IDX': 0,
#   'C': 'Adam'},
#  {'[PLACE]': 'station',
#   '[OBJECT]': 'bone',
#   'text': 'Then, Andrew and Aaron went to the station. Erica gave a bone to Andrew',
#   'IO': 'Andrew',
#   'S': 'Aaron',
#   'TEMPLATE_IDX': 0,
#   'C': 'Erica'},
#  {'[PLACE]': 'store',
#   '[OBJECT]': 'snack',
#   'text': 'Then, Jose and Jeremy went to the store. Paul gave a snack to Jose',
#   'IO': 'Jose',
#   'S': 'Jeremy',
#   'TEMPLATE_IDX': 0,
#   'C': 'Paul'},
#  {'[PLACE]': 'house',
#   '[OBJECT]': 'bone',
#   'text': 'Then, Charles and Alexander went to the house. Timothy gave a bone to Charles',
#   'IO': 'Charles',
#   'S': 'Alexander',
#   'TEMPLATE_IDX': 0,
#   'C': 'Timothy'},
#  {'[PLACE]': 'restaurant',
#   '[OBJECT]': 'drink',
#   'text': 'Then, Nicole and Angela went to the restaurant. Kyle gave a drink to Nicole',
#   'IO': 'Nicole',
#   'S': 'Angela',
#   'TEMPLATE_IDX': 0,
#   'C': 'Kyle'},
#  {'[PLACE]': 'hospital',
#   '[OBJECT]': 'basketball',
#   'text': 'Then, Robert and James went to the hospital. Tyler gave a basketball to Robert',
#   'IO': 'Robert',
#   'S': 'James',
#   'TEMPLATE_IDX': 0,
#   'C': 'Tyler'},
#  {'[PLACE]': 'hospital',
#   '[OBJECT]': 'computer',
#   'text': 'Then, Lisa and Rachel went to the hospital. Melissa gave a computer to Lisa',
#   'IO': 'Lisa',
#   'S': 'Rachel',
#   'TEMPLATE_IDX': 0,
#   'C': 'Melissa'},
#  {'[PLACE]': 'school',
#   '[OBJECT]': 'bone',
#   'text': 'Then, Lisa and Rebecca went to the school. Jennifer gave a bone to Lisa',
#   'IO': 'Lisa',
#   'S': 'Rebecca',
#   'TEMPLATE_IDX': 0,
#   'C': 'Jennifer'},
#  {'[PLACE]': 'garden',
#   '[OBJECT]': 'necklace',
#   'text': 'Then, Jennifer and Timothy went to the garden. Michelle gave a necklace to Jennifer',
#   'IO': 'Jennifer',
#   'S': 'Timothy',
#   'TEMPLATE_IDX': 0,
#   'C': 'Michelle'},
#  {'[PLACE]': 'office',
#   '[OBJECT]': 'drink',
#   'text': 'Then, Emily and Alexander went to the office. Stephanie gave a drink to Emily',
#   'IO': 'Emily',
#   'S': 'Alexander',
#   'TEMPLATE_IDX': 0,
#   'C': 'Stephanie'},
#  {'[PLACE]': 'store',
#   '[OBJECT]': 'drink',
#   'text': 'Then, Charles and Jonathan went to the store. Lindsay gave a drink to Charles',
#   'IO': 'Charles',
#   'S': 'Jonathan',
#   'TEMPLATE_IDX': 0,
#   'C': 'Lindsay'},
#  {'[PLACE]': 'garden',
#   '[OBJECT]': 'ring',
#   'text': 'Then, Eric and Alexander went to the garden. Benjamin gave a ring to Eric',
#   'IO': 'Eric',
#   'S': 'Alexander',
#   'TEMPLATE_IDX': 0,
#   'C': 'Benjamin'},
#  {'[PLACE]': 'house',
#   '[OBJECT]': 'bone',
#   'text': 'Then, Charles and Michael went to the house. Ryan gave a bone to Charles',
#   'IO': 'Charles',
#   'S': 'Michael',
#   'TEMPLATE_IDX': 0,
#   'C': 'Ryan'},
#  {'[PLACE]': 'garden',
#   '[OBJECT]': 'snack',
#   'text': 'Then, Angela and James went to the garden. Samuel gave a snack to Angela',
#   'IO': 'Angela',
#   'S': 'James',
#   'TEMPLATE_IDX': 0,
#   'C': 'Samuel'},
#  {'[PLACE]': 'store',
#   '[OBJECT]': 'basketball',
#   'text': 'Then, Elizabeth and Erica went to the store. Amber gave a basketball to Elizabeth',
#   'IO': 'Elizabeth',
#   'S': 'Erica',
#   'TEMPLATE_IDX': 0,
#   'C': 'Amber'},
#  {'[PLACE]': 'restaurant',
#   '[OBJECT]': 'snack',
#   'text': 'Then, Nicholas and Thomas went to the restaurant. Jason gave a snack to Nicholas',
#   'IO': 'Nicholas',
#   'S': 'Thomas',
#   'TEMPLATE_IDX': 0,
#   'C': 'Jason'},
#  {'[PLACE]': 'restaurant',
#   '[OBJECT]': 'drink',
#   'text': 'Then, Alicia and Paul went to the restaurant. Shannon gave a drink to Alicia',
#   'IO': 'Alicia',
#   'S': 'Paul',
#   'TEMPLATE_IDX': 0,
#   'C': 'Shannon'},
#  {'[PLACE]': 'hospital',
#   '[OBJECT]': 'computer',
#   'text': 'Then, Jamie and Jonathan went to the hospital. Brittany gave a computer to Jamie',
#   'IO': 'Jamie',
#   'S': 'Jonathan',
#   'TEMPLATE_IDX': 0,
#   'C': 'Brittany'},
#  {'[PLACE]': 'station',
#   '[OBJECT]': 'computer',
#   'text': 'Then, Daniel and Vanessa went to the station. William gave a computer to Daniel',
#   'IO': 'Daniel',
#   'S': 'Vanessa',
#   'TEMPLATE_IDX': 0,
#   'C': 'William'},
#  {'[PLACE]': 'house',
#   '[OBJECT]': 'computer',
#   'text': 'Then, Allison and Nathan went to the house. Jeffrey gave a computer to Allison',
#   'IO': 'Allison',
#   'S': 'Nathan',
#   'TEMPLATE_IDX': 0,
#   'C': 'Jeffrey'},
#  {'[PLACE]': 'restaurant',
#   '[OBJECT]': 'drink',
#   'text': 'Then, Alexander and Kenneth went to the restaurant. Thomas gave a drink to Alexander',
#   'IO': 'Alexander',
#   'S': 'Kenneth',
#   'TEMPLATE_IDX': 0,
#   'C': 'Thomas'},
#  {'[PLACE]': 'house',
#   '[OBJECT]': 'ring',
#   'text': 'Then, Michael and Cody went to the house. Jacob gave a ring to Michael',
#   'IO': 'Michael',
#   'S': 'Cody',
#   'TEMPLATE_IDX': 0,
#   'C': 'Jacob'},
#  {'[PLACE]': 'house',
#   '[OBJECT]': 'computer',
#   'text': 'Then, Alicia and Lindsay went to the house. Nathan gave a computer to Alicia',
#   'IO': 'Alicia',
#   'S': 'Lindsay',
#   'TEMPLATE_IDX': 0,
#   'C': 'Nathan'},
#  {'[PLACE]': 'office',
#   '[OBJECT]': 'basketball',
#   'text': 'Then, Dustin and Kenneth went to the office. Rachel gave a basketball to Dustin',
#   'IO': 'Dustin',
#   'S': 'Kenneth',
#   'TEMPLATE_IDX': 0,
#   'C': 'Rachel'},
#  {'[PLACE]': 'restaurant',
#   '[OBJECT]': 'basketball',
#   'text': 'Then, Amy and Aaron went to the restaurant. Lindsey gave a basketball to Amy',
#   'IO': 'Amy',
#   'S': 'Aaron',
#   'TEMPLATE_IDX': 0,
#   'C': 'Lindsey'},
#  {'[PLACE]': 'school',
#   '[OBJECT]': 'basketball',
#   'text': 'Then, Richard and Jonathan went to the school. Andrea gave a basketball to Richard',
#   'IO': 'Richard',
#   'S': 'Jonathan',
#   'TEMPLATE_IDX': 0,
#   'C': 'Andrea'},
#  {'[PLACE]': 'store',
#   '[OBJECT]': 'computer',
#   'text': 'Then, Alexander and Timothy went to the store. Erica gave a computer to Alexander',
#   'IO': 'Alexander',
#   'S': 'Timothy',
#   'TEMPLATE_IDX': 0,
#   'C': 'Erica'},
#  {'[PLACE]': 'station',
#   '[OBJECT]': 'drink',
#   'text': 'Then, Patrick and Matthew went to the station. Brittany gave a drink to Patrick',
#   'IO': 'Patrick',
#   'S': 'Matthew',
#   'TEMPLATE_IDX': 0,
#   'C': 'Brittany'},
#  {'[PLACE]': 'store',
#   '[OBJECT]': 'bone',
#   'text': 'Then, Paul and James went to the store. Rachel gave a bone to Paul',
#   'IO': 'Paul',
#   'S': 'James',
#   'TEMPLATE_IDX': 0,
#   'C': 'Rachel'},
#  {'[PLACE]': 'office',
#   '[OBJECT]': 'basketball',
#   'text': 'Then, Richard and Charles went to the office. Gregory gave a basketball to Richard',
#   'IO': 'Richard',
#   'S': 'Charles',
#   'TEMPLATE_IDX': 0,
#   'C': 'Gregory'},
#  {'[PLACE]': 'house',
#   '[OBJECT]': 'computer',
#   'text': 'Then, Dustin and Jonathan went to the house. Andrea gave a computer to Dustin',
#   'IO': 'Dustin',
#   'S': 'Jonathan',
#   'TEMPLATE_IDX': 0,
#   'C': 'Andrea'},
#  {'[PLACE]': 'office',
#   '[OBJECT]': 'snack',
#   'text': 'Then, Jennifer and Kevin went to the office. Ryan gave a snack to Jennifer',
#   'IO': 'Jennifer',
#   'S': 'Kevin',
#   'TEMPLATE_IDX': 0,
#   'C': 'Ryan'},
#  {'[PLACE]': 'hospital',
#   '[OBJECT]': 'drink',
#   'text': 'Then, Laura and Amy went to the hospital. Megan gave a drink to Laura',
#   'IO': 'Laura',
#   'S': 'Amy',
#   'TEMPLATE_IDX': 0,
#   'C': 'Megan'},
#  {'[PLACE]': 'office',
#   '[OBJECT]': 'basketball',
#   'text': 'Then, Amanda and Sarah went to the office. Andrew gave a basketball to Amanda',
#   'IO': 'Amanda',
#   'S': 'Sarah',
#   'TEMPLATE_IDX': 0,
#   'C': 'Andrew'},
#  {'[PLACE]': 'hospital',
#   '[OBJECT]': 'kiss',
#   'text': 'Then, Melissa and Alicia went to the hospital. Mary gave a kiss to Melissa',
#   'IO': 'Melissa',
#   'S': 'Alicia',
#   'TEMPLATE_IDX': 0,
#   'C': 'Mary'},
#  {'[PLACE]': 'station',
#   '[OBJECT]': 'basketball',
#   'text': 'Then, Paul and Matthew went to the station. Jacob gave a basketball to Paul',
#   'IO': 'Paul',
#   'S': 'Matthew',
#   'TEMPLATE_IDX': 0,
#   'C': 'Jacob'},
#  {'[PLACE]': 'station',
#   '[OBJECT]': 'basketball',
#   'text': 'Then, Elizabeth and Brandon went to the station. Steven gave a basketball to Elizabeth',
#   'IO': 'Elizabeth',
#   'S': 'Brandon',
#   'TEMPLATE_IDX': 0,
#   'C': 'Steven'},
#  {'[PLACE]': 'school',
#   '[OBJECT]': 'drink',
#   'text': 'Then, Lindsey and Jeffrey went to the school. Megan gave a drink to Lindsey',
#   'IO': 'Lindsey',
#   'S': 'Jeffrey',
#   'TEMPLATE_IDX': 0,
#   'C': 'Megan'},
#  {'[PLACE]': 'restaurant',
#   '[OBJECT]': 'snack',
#   'text': 'Then, Andrew and Rachel went to the restaurant. Courtney gave a snack to Andrew',
#   'IO': 'Andrew',
#   'S': 'Rachel',
#   'TEMPLATE_IDX': 0,
#   'C': 'Courtney'},
#  {'[PLACE]': 'restaurant',
#   '[OBJECT]': 'snack',
#   'text': 'Then, Robert and Eric went to the restaurant. Stephanie gave a snack to Robert',
#   'IO': 'Robert',
#   'S': 'Eric',
#   'TEMPLATE_IDX': 0,
#   'C': 'Stephanie'},
#  {'[PLACE]': 'office',
#   '[OBJECT]': 'ring',
#   'text': 'Then, Thomas and Tyler went to the office. Aaron gave a ring to Thomas',
#   'IO': 'Thomas',
#   'S': 'Tyler',
#   'TEMPLATE_IDX': 0,
#   'C': 'Aaron'},
#  {'[PLACE]': 'garden',
#   '[OBJECT]': 'snack',
#   'text': 'Then, Samuel and Danielle went to the garden. Bradley gave a snack to Samuel',
#   'IO': 'Samuel',
#   'S': 'Danielle',
#   'TEMPLATE_IDX': 0,
#   'C': 'Bradley'},
#  {'[PLACE]': 'school',
#   '[OBJECT]': 'basketball',
#   'text': 'Then, Andrea and Benjamin went to the school. Timothy gave a basketball to Andrea',
#   'IO': 'Andrea',
#   'S': 'Benjamin',
#   'TEMPLATE_IDX': 0,
#   'C': 'Timothy'},
#  {'[PLACE]': 'garden',
#   '[OBJECT]': 'necklace',
#   'text': 'Then, Laura and Katie went to the garden. Travis gave a necklace to Laura',
#   'IO': 'Laura',
#   'S': 'Katie',
#   'TEMPLATE_IDX': 0,
#   'C': 'Travis'},
#  {'[PLACE]': 'station',
#   '[OBJECT]': 'ring',
#   'text': 'Then, Alexander and Paul went to the station. Joshua gave a ring to Alexander',
#   'IO': 'Alexander',
#   'S': 'Paul',
#   'TEMPLATE_IDX': 0,
#   'C': 'Joshua'},
#  {'[PLACE]': 'house',
#   '[OBJECT]': 'basketball',
#   'text': 'Then, Megan and Eric went to the house. Samantha gave a basketball to Megan',
#   'IO': 'Megan',
#   'S': 'Eric',
#   'TEMPLATE_IDX': 0,
#   'C': 'Samantha'},
#  {'[PLACE]': 'station',
#   '[OBJECT]': 'snack',
#   'text': 'Then, Elizabeth and Jamie went to the station. Samuel gave a snack to Elizabeth',
#   'IO': 'Elizabeth',
#   'S': 'Jamie',
#   'TEMPLATE_IDX': 0,
#   'C': 'Samuel'},
#  {'[PLACE]': 'school',
#   '[OBJECT]': 'ring',
#   'text': 'Then, John and Nathan went to the school. Megan gave a ring to John',
#   'IO': 'John',
#   'S': 'Nathan',
#   'TEMPLATE_IDX': 0,
#   'C': 'Megan'},
#  {'[PLACE]': 'garden',
#   '[OBJECT]': 'snack',
#   'text': 'Then, Patrick and Mary went to the garden. Paul gave a snack to Patrick',
#   'IO': 'Patrick',
#   'S': 'Mary',
#   'TEMPLATE_IDX': 0,
#   'C': 'Paul'},
#  {'[PLACE]': 'house',
#   '[OBJECT]': 'drink',
#   'text': 'Then, Laura and James went to the house. Nicholas gave a drink to Laura',
#   'IO': 'Laura',
#   'S': 'James',
#   'TEMPLATE_IDX': 0,
#   'C': 'Nicholas'},
#  {'[PLACE]': 'garden',
#   '[OBJECT]': 'computer',
#   'text': 'Then, Dustin and Robert went to the garden. Nicholas gave a computer to Dustin',
#   'IO': 'Dustin',
#   'S': 'Robert',
#   'TEMPLATE_IDX': 0,
#   'C': 'Nicholas'},
#  {'[PLACE]': 'store',
#   '[OBJECT]': 'ring',
#   'text': 'Then, Crystal and Jeremy went to the store. Rebecca gave a ring to Crystal',
#   'IO': 'Crystal',
#   'S': 'Jeremy',
#   'TEMPLATE_IDX': 0,
#   'C': 'Rebecca'},
#  {'[PLACE]': 'hospital',
#   '[OBJECT]': 'snack',
#   'text': 'Then, Tiffany and Justin went to the hospital. Joshua gave a snack to Tiffany',
#   'IO': 'Tiffany',
#   'S': 'Justin',
#   'TEMPLATE_IDX': 0,
#   'C': 'Joshua'},
#  {'[PLACE]': 'station',
#   '[OBJECT]': 'computer',
#   'text': 'Then, Katherine and Jesse went to the station. Laura gave a computer to Katherine',
#   'IO': 'Katherine',
#   'S': 'Jesse',
#   'TEMPLATE_IDX': 0,
#   'C': 'Laura'},
#  {'[PLACE]': 'station',
#   '[OBJECT]': 'bone',
#   'text': 'Then, Nicholas and Andrea went to the station. Mark gave a bone to Nicholas',
#   'IO': 'Nicholas',
#   'S': 'Andrea',
#   'TEMPLATE_IDX': 0,
#   'C': 'Mark'},
#  {'[PLACE]': 'hospital',
#   '[OBJECT]': 'drink',
#   'text': 'Then, Christina and Samantha went to the hospital. Katherine gave a drink to Christina',
#   'IO': 'Christina',
#   'S': 'Samantha',
#   'TEMPLATE_IDX': 0,
#   'C': 'Katherine'},
#  {'[PLACE]': 'school',
#   '[OBJECT]': 'drink',
#   'text': 'Then, Ryan and Amy went to the school. Justin gave a drink to Ryan',
#   'IO': 'Ryan',
#   'S': 'Amy',
#   'TEMPLATE_IDX': 0,
#   'C': 'Justin'},
#  {'[PLACE]': 'office',
#   '[OBJECT]': 'bone',
#   'text': 'Then, Nicole and Joseph went to the office. Michelle gave a bone to Nicole',
#   'IO': 'Nicole',
#   'S': 'Joseph',
#   'TEMPLATE_IDX': 0,
#   'C': 'Michelle'},
#  {'[PLACE]': 'school',
#   '[OBJECT]': 'ring',
#   'text': 'Then, Megan and Sara went to the school. Kelly gave a ring to Megan',
#   'IO': 'Megan',
#   'S': 'Sara',
#   'TEMPLATE_IDX': 0,
#   'C': 'Kelly'},
#  {'[PLACE]': 'school',
#   '[OBJECT]': 'snack',
#   'text': 'Then, Daniel and Lisa went to the school. Samuel gave a snack to Daniel',
#   'IO': 'Daniel',
#   'S': 'Lisa',
#   'TEMPLATE_IDX': 0,
#   'C': 'Samuel'},
#  {'[PLACE]': 'hospital',
#   '[OBJECT]': 'snack',
#   'text': 'Then, Megan and Ryan went to the hospital. Anthony gave a snack to Megan',
#   'IO': 'Megan',
#   'S': 'Ryan',
#   'TEMPLATE_IDX': 0,
#   'C': 'Anthony'},
#  {'[PLACE]': 'school',
#   '[OBJECT]': 'drink',
#   'text': 'Then, Anthony and Christine went to the school. Crystal gave a drink to Anthony',
#   'IO': 'Anthony',
#   'S': 'Christine',
#   'TEMPLATE_IDX': 0,
#   'C': 'Crystal'},
#  {'[PLACE]': 'restaurant',
#   '[OBJECT]': 'bone',
#   'text': 'Then, Sara and Jason went to the restaurant. Charles gave a bone to Sara',
#   'IO': 'Sara',
#   'S': 'Jason',
#   'TEMPLATE_IDX': 0,
#   'C': 'Charles'},
#  {'[PLACE]': 'school',
#   '[OBJECT]': 'computer',
#   'text': 'Then, Rebecca and Nathan went to the school. Laura gave a computer to Rebecca',
#   'IO': 'Rebecca',
#   'S': 'Nathan',
#   'TEMPLATE_IDX': 0,
#   'C': 'Laura'},
#  {'[PLACE]': 'restaurant',
#   '[OBJECT]': 'bone',
#   'text': 'Then, Steven and Samuel went to the restaurant. Jeffrey gave a bone to Steven',
#   'IO': 'Steven',
#   'S': 'Samuel',
#   'TEMPLATE_IDX': 0,
#   'C': 'Jeffrey'},
#  {'[PLACE]': 'store',
#   '[OBJECT]': 'kiss',
#   'text': 'Then, Sara and Patrick went to the store. Thomas gave a kiss to Sara',
#   'IO': 'Sara',
#   'S': 'Patrick',
#   'TEMPLATE_IDX': 0,
#   'C': 'Thomas'},
#  {'[PLACE]': 'hospital',
#   '[OBJECT]': 'computer',
#   'text': 'Then, Emily and Kenneth went to the hospital. Courtney gave a computer to Emily',
#   'IO': 'Emily',
#   'S': 'Kenneth',
#   'TEMPLATE_IDX': 0,
#   'C': 'Courtney'},
#  {'[PLACE]': 'store',
#   '[OBJECT]': 'drink',
#   'text': 'Then, Steven and Jamie went to the store. Patrick gave a drink to Steven',
#   'IO': 'Steven',
#   'S': 'Jamie',
#   'TEMPLATE_IDX': 0,
#   'C': 'Patrick'},
#  {'[PLACE]': 'hospital',
#   '[OBJECT]': 'drink',
#   'text': 'Then, Samantha and Scott went to the hospital. Megan gave a drink to Samantha',
#   'IO': 'Samantha',
#   'S': 'Scott',
#   'TEMPLATE_IDX': 0,
#   'C': 'Megan'},
#  {'[PLACE]': 'restaurant',
#   '[OBJECT]': 'drink',
#   'text': 'Then, Michelle and Matthew went to the restaurant. Christine gave a drink to Michelle',
#   'IO': 'Michelle',
#   'S': 'Matthew',
#   'TEMPLATE_IDX': 0,
#   'C': 'Christine'},
#  {'[PLACE]': 'house',
#   '[OBJECT]': 'snack',
#   'text': 'Then, Jose and Gregory went to the house. Richard gave a snack to Jose',
#   'IO': 'Jose',
#   'S': 'Gregory',
#   'TEMPLATE_IDX': 0,
#   'C': 'Richard'},
#  {'[PLACE]': 'store',
#   '[OBJECT]': 'snack',
#   'text': 'Then, Charles and Erica went to the store. Jacob gave a snack to Charles',
#   'IO': 'Charles',
#   'S': 'Erica',
#   'TEMPLATE_IDX': 0,
#   'C': 'Jacob'},
#  {'[PLACE]': 'school',
#   '[OBJECT]': 'computer',
#   'text': 'Then, Cody and Timothy went to the school. Laura gave a computer to Cody',
#   'IO': 'Cody',
#   'S': 'Timothy',
#   'TEMPLATE_IDX': 0,
#   'C': 'Laura'},
#  {'[PLACE]': 'garden',
#   '[OBJECT]': 'necklace',
#   'text': 'Then, Mark and Stephanie went to the garden. Heather gave a necklace to Mark',
#   'IO': 'Mark',
#   'S': 'Stephanie',
#   'TEMPLATE_IDX': 0,
#   'C': 'Heather'},
#  {'[PLACE]': 'restaurant',
#   '[OBJECT]': 'snack',
#   'text': 'Then, Richard and Brittany went to the restaurant. Stephen gave a snack to Richard',
#   'IO': 'Richard',
#   'S': 'Brittany',
#   'TEMPLATE_IDX': 0,
#   'C': 'Stephen'},
#  {'[PLACE]': 'store',
#   '[OBJECT]': 'basketball',
#   'text': 'Then, Erin and Sarah went to the store. Katherine gave a basketball to Erin',
#   'IO': 'Erin',
#   'S': 'Sarah',
#   'TEMPLATE_IDX': 0,
#   'C': 'Katherine'},
#  {'[PLACE]': 'store',
#   '[OBJECT]': 'necklace',
#   'text': 'Then, Christina and Timothy went to the store. Scott gave a necklace to Christina',
#   'IO': 'Christina',
#   'S': 'Timothy',
#   'TEMPLATE_IDX': 0,
#   'C': 'Scott'},
#  {'[PLACE]': 'hospital',
#   '[OBJECT]': 'necklace',
#   'text': 'Then, Justin and Christopher went to the hospital. Melissa gave a necklace to Justin',
#   'IO': 'Justin',
#   'S': 'Christopher',
#   'TEMPLATE_IDX': 0,
#   'C': 'Melissa'},
#  {'[PLACE]': 'station',
#   '[OBJECT]': 'basketball',
#   'text': 'Then, Sarah and Lisa went to the station. Bryan gave a basketball to Sarah',
#   'IO': 'Sarah',
#   'S': 'Lisa',
#   'TEMPLATE_IDX': 0,
#   'C': 'Bryan'},
#  {'[PLACE]': 'store',
#   '[OBJECT]': 'necklace',
#   'text': 'Then, Jacob and Jeffrey went to the store. Nicholas gave a necklace to Jacob',
#   'IO': 'Jacob',
#   'S': 'Jeffrey',
#   'TEMPLATE_IDX': 0,
#   'C': 'Nicholas'},
#  {'[PLACE]': 'station',
#   '[OBJECT]': 'drink',
#   'text': 'Then, Courtney and Brian went to the station. Melissa gave a drink to Courtney',
#   'IO': 'Courtney',
#   'S': 'Brian',
#   'TEMPLATE_IDX': 0,
#   'C': 'Melissa'},
#  {'[PLACE]': 'restaurant',
#   '[OBJECT]': 'ring',
#   'text': 'Then, Melissa and Megan went to the restaurant. Sean gave a ring to Melissa',
#   'IO': 'Melissa',
#   'S': 'Megan',
#   'TEMPLATE_IDX': 0,
#   'C': 'Sean'},
#  {'[PLACE]': 'store',
#   '[OBJECT]': 'kiss',
#   'text': 'Then, Paul and Brandon went to the store. Stephanie gave a kiss to Paul',
#   'IO': 'Paul',
#   'S': 'Brandon',
#   'TEMPLATE_IDX': 0,
#   'C': 'Stephanie'},
#  {'[PLACE]': 'station',
#   '[OBJECT]': 'ring',
#   'text': 'Then, Kimberly and William went to the station. Christine gave a ring to Kimberly',
#   'IO': 'Kimberly',
#   'S': 'William',
#   'TEMPLATE_IDX': 0,
#   'C': 'Christine'},
#  {'[PLACE]': 'school',
#   '[OBJECT]': 'kiss',
#   'text': 'Then, Sarah and Alexander went to the school. Cody gave a kiss to Sarah',
#   'IO': 'Sarah',
#   'S': 'Alexander',
#   'TEMPLATE_IDX': 0,
#   'C': 'Cody'},
#  {'[PLACE]': 'restaurant',
#   '[OBJECT]': 'drink',
#   'text': 'Then, Bradley and Christopher went to the restaurant. Kenneth gave a drink to Bradley',
#   'IO': 'Bradley',
#   'S': 'Christopher',
#   'TEMPLATE_IDX': 0,
#   'C': 'Kenneth'},
#  {'[PLACE]': 'station',
#   '[OBJECT]': 'kiss',
#   'text': 'Then, Ryan and Rachel went to the station. Michael gave a kiss to Ryan',
#   'IO': 'Ryan',
#   'S': 'Rachel',
#   'TEMPLATE_IDX': 0,
#   'C': 'Michael'},
#  {'[PLACE]': 'restaurant',
#   '[OBJECT]': 'ring',
#   'text': 'Then, Jamie and Jessica went to the restaurant. Katherine gave a ring to Jamie',
#   'IO': 'Jamie',
#   'S': 'Jessica',
#   'TEMPLATE_IDX': 0,
#   'C': 'Katherine'},
#  {'[PLACE]': 'restaurant',
#   '[OBJECT]': 'kiss',
#   'text': 'Then, James and Joshua went to the restaurant. Richard gave a kiss to James',
#   'IO': 'James',
#   'S': 'Joshua',
#   'TEMPLATE_IDX': 0,
#   'C': 'Richard'},
#  {'[PLACE]': 'house',
#   '[OBJECT]': 'necklace',
#   'text': 'Then, Kyle and Bradley went to the house. Ashley gave a necklace to Kyle',
#   'IO': 'Kyle',
#   'S': 'Bradley',
#   'TEMPLATE_IDX': 0,
#   'C': 'Ashley'},
#  {'[PLACE]': 'garden',
#   '[OBJECT]': 'computer',
#   'text': 'Then, Jennifer and Adam went to the garden. Emily gave a computer to Jennifer',
#   'IO': 'Jennifer',
#   'S': 'Adam',
#   'TEMPLATE_IDX': 0,
#   'C': 'Emily'},
#  {'[PLACE]': 'restaurant',
#   '[OBJECT]': 'bone',
#   'text': 'Then, Timothy and Adam went to the restaurant. Bradley gave a bone to Timothy',
#   'IO': 'Timothy',
#   'S': 'Adam',
#   'TEMPLATE_IDX': 0,
#   'C': 'Bradley'},
#  {'[PLACE]': 'station',
#   '[OBJECT]': 'basketball',
#   'text': 'Then, Erica and Bradley went to the station. Lindsey gave a basketball to Erica',
#   'IO': 'Erica',
#   'S': 'Bradley',
#   'TEMPLATE_IDX': 0,
#   'C': 'Lindsey'},
#  {'[PLACE]': 'hospital',
#   '[OBJECT]': 'necklace',
#   'text': 'Then, Nathan and Gregory went to the hospital. Matthew gave a necklace to Nathan',
#   'IO': 'Nathan',
#   'S': 'Gregory',
#   'TEMPLATE_IDX': 0,
#   'C': 'Matthew'},
#  {'[PLACE]': 'restaurant',
#   '[OBJECT]': 'snack',
#   'text': 'Then, Crystal and Bryan went to the restaurant. David gave a snack to Crystal',
#   'IO': 'Crystal',
#   'S': 'Bryan',
#   'TEMPLATE_IDX': 0,
#   'C': 'David'},
#  {'[PLACE]': 'office',
#   '[OBJECT]': 'computer',
#   'text': 'Then, Ashley and Rebecca went to the office. Brittany gave a computer to Ashley',
#   'IO': 'Ashley',
#   'S': 'Rebecca',
#   'TEMPLATE_IDX': 0,
#   'C': 'Brittany'},
#  {'[PLACE]': 'hospital',
#   '[OBJECT]': 'basketball',
#   'text': 'Then, Kyle and Rachel went to the hospital. Ashley gave a basketball to Kyle',
#   'IO': 'Kyle',
#   'S': 'Rachel',
#   'TEMPLATE_IDX': 0,
#   'C': 'Ashley'},
#  {'[PLACE]': 'garden',
#   '[OBJECT]': 'necklace',
#   'text': 'Then, Jamie and Lindsay went to the garden. Ryan gave a necklace to Jamie',
#   'IO': 'Jamie',
#   'S': 'Lindsay',
#   'TEMPLATE_IDX': 0,
#   'C': 'Ryan'},
#  {'[PLACE]': 'house',
#   '[OBJECT]': 'ring',
#   'text': 'Then, Jose and Lauren went to the house. Kelly gave a ring to Jose',
#   'IO': 'Jose',
#   'S': 'Lauren',
#   'TEMPLATE_IDX': 0,
#   'C': 'Kelly'},
#  {'[PLACE]': 'restaurant',
#   '[OBJECT]': 'drink',
#   'text': 'Then, Amber and Vanessa went to the restaurant. Joseph gave a drink to Amber',
#   'IO': 'Amber',
#   'S': 'Vanessa',
#   'TEMPLATE_IDX': 0,
#   'C': 'Joseph'},
#  {'[PLACE]': 'school',
#   '[OBJECT]': 'drink',
#   'text': 'Then, Heather and Christine went to the school. Kristen gave a drink to Heather',
#   'IO': 'Heather',
#   'S': 'Christine',
#   'TEMPLATE_IDX': 0,
#   'C': 'Kristen'},
#  {'[PLACE]': 'office',
#   '[OBJECT]': 'kiss',
#   'text': 'Then, Scott and David went to the office. James gave a kiss to Scott',
#   'IO': 'Scott',
#   'S': 'David',
#   'TEMPLATE_IDX': 0,
#   'C': 'James'},
#  {'[PLACE]': 'station',
#   '[OBJECT]': 'basketball',
#   'text': 'Then, James and Jessica went to the station. Jeffrey gave a basketball to James',
#   'IO': 'James',
#   'S': 'Jessica',
#   'TEMPLATE_IDX': 0,
#   'C': 'Jeffrey'},
#  {'[PLACE]': 'store',
#   '[OBJECT]': 'necklace',
#   'text': 'Then, Nathan and Ryan went to the store. Christina gave a necklace to Nathan',
#   'IO': 'Nathan',
#   'S': 'Ryan',
#   'TEMPLATE_IDX': 0,
#   'C': 'Christina'},
#  {'[PLACE]': 'school',
#   '[OBJECT]': 'snack',
#   'text': 'Then, Anthony and Justin went to the school. Brandon gave a snack to Anthony',
#   'IO': 'Anthony',
#   'S': 'Justin',
#   'TEMPLATE_IDX': 0,
#   'C': 'Brandon'},
#  {'[PLACE]': 'station',
#   '[OBJECT]': 'necklace',
#   'text': 'Then, Rachel and Amanda went to the station. Samuel gave a necklace to Rachel',
#   'IO': 'Rachel',
#   'S': 'Amanda',
#   'TEMPLATE_IDX': 0,
#   'C': 'Samuel'},
#  {'[PLACE]': 'station',
#   '[OBJECT]': 'snack',
#   'text': 'Then, Eric and Katherine went to the station. John gave a snack to Eric',
#   'IO': 'Eric',
#   'S': 'Katherine',
#   'TEMPLATE_IDX': 0,
#   'C': 'John'},
#  {'[PLACE]': 'restaurant',
#   '[OBJECT]': 'basketball',
#   'text': 'Then, Andrea and Stephanie went to the restaurant. Nathan gave a basketball to Andrea',
#   'IO': 'Andrea',
#   'S': 'Stephanie',
#   'TEMPLATE_IDX': 0,
#   'C': 'Nathan'},
#  {'[PLACE]': 'office',
#   '[OBJECT]': 'kiss',
#   'text': 'Then, Jacob and Aaron went to the office. Jeffrey gave a kiss to Jacob',
#   'IO': 'Jacob',
#   'S': 'Aaron',
#   'TEMPLATE_IDX': 0,
#   'C': 'Jeffrey'},
#  {'[PLACE]': 'station',
#   '[OBJECT]': 'drink',
#   'text': 'Then, Samuel and Thomas went to the station. Kelly gave a drink to Samuel',
#   'IO': 'Samuel',
#   'S': 'Thomas',
#   'TEMPLATE_IDX': 0,
#   'C': 'Kelly'},
#  {'[PLACE]': 'station',
#   '[OBJECT]': 'drink',
#   'text': 'Then, Jennifer and Alexander went to the station. John gave a drink to Jennifer',
#   'IO': 'Jennifer',
#   'S': 'Alexander',
#   'TEMPLATE_IDX': 0,
#   'C': 'John'},
#  {'[PLACE]': 'hospital',
#   '[OBJECT]': 'snack',
#   'text': 'Then, Sarah and Christine went to the hospital. Erin gave a snack to Sarah',
#   'IO': 'Sarah',
#   'S': 'Christine',
#   'TEMPLATE_IDX': 0,
#   'C': 'Erin'},
#  {'[PLACE]': 'school',
#   '[OBJECT]': 'drink',
#   'text': 'Then, Lisa and Tiffany went to the school. Heather gave a drink to Lisa',
#   'IO': 'Lisa',
#   'S': 'Tiffany',
#   'TEMPLATE_IDX': 0,
#   'C': 'Heather'},
#  {'[PLACE]': 'house',
#   '[OBJECT]': 'kiss',
#   'text': 'Then, Lindsay and Vanessa went to the house. Bradley gave a kiss to Lindsay',
#   'IO': 'Lindsay',
#   'S': 'Vanessa',
#   'TEMPLATE_IDX': 0,
#   'C': 'Bradley'},
#  {'[PLACE]': 'school',
#   '[OBJECT]': 'necklace',
#   'text': 'Then, Nicholas and Jamie went to the school. Christine gave a necklace to Nicholas',
#   'IO': 'Nicholas',
#   'S': 'Jamie',
#   'TEMPLATE_IDX': 0,
#   'C': 'Christine'},
#  {'[PLACE]': 'school',
#   '[OBJECT]': 'ring',
#   'text': 'Then, Amy and Allison went to the school. Justin gave a ring to Amy',
#   'IO': 'Amy',
#   'S': 'Allison',
#   'TEMPLATE_IDX': 0,
#   'C': 'Justin'},
#  {'[PLACE]': 'station',
#   '[OBJECT]': 'drink',
#   'text': 'Then, Joshua and Michelle went to the station. Allison gave a drink to Joshua',
#   'IO': 'Joshua',
#   'S': 'Michelle',
#   'TEMPLATE_IDX': 0,
#   'C': 'Allison'},
#  {'[PLACE]': 'school',
#   '[OBJECT]': 'basketball',
#   'text': 'Then, Eric and Lindsey went to the school. Bryan gave a basketball to Eric',
#   'IO': 'Eric',
#   'S': 'Lindsey',
#   'TEMPLATE_IDX': 0,
#   'C': 'Bryan'},
#  {'[PLACE]': 'station',
#   '[OBJECT]': 'ring',
#   'text': 'Then, Kelly and Katie went to the station. Lindsay gave a ring to Kelly',
#   'IO': 'Kelly',
#   'S': 'Katie',
#   'TEMPLATE_IDX': 0,
#   'C': 'Lindsay'},
#  {'[PLACE]': 'station',
#   '[OBJECT]': 'kiss',
#   'text': 'Then, Ryan and Patrick went to the station. Justin gave a kiss to Ryan',
#   'IO': 'Ryan',
#   'S': 'Patrick',
#   'TEMPLATE_IDX': 0,
#   'C': 'Justin'},
#  {'[PLACE]': 'store',
#   '[OBJECT]': 'bone',
#   'text': 'Then, Nicole and Jamie went to the store. Jeffrey gave a bone to Nicole',
#   'IO': 'Nicole',
#   'S': 'Jamie',
#   'TEMPLATE_IDX': 0,
#   'C': 'Jeffrey'},
#  {'[PLACE]': 'office',
#   '[OBJECT]': 'kiss',
#   'text': 'Then, Paul and Lisa went to the office. Lindsay gave a kiss to Paul',
#   'IO': 'Paul',
#   'S': 'Lisa',
#   'TEMPLATE_IDX': 0,
#   'C': 'Lindsay'},
#  {'[PLACE]': 'office',
#   '[OBJECT]': 'basketball',
#   'text': 'Then, Kevin and Jose went to the office. Samuel gave a basketball to Kevin',
#   'IO': 'Kevin',
#   'S': 'Jose',
#   'TEMPLATE_IDX': 0,
#   'C': 'Samuel'},
#  {'[PLACE]': 'garden',
#   '[OBJECT]': 'ring',
#   'text': 'Then, Christopher and Paul went to the garden. Melissa gave a ring to Christopher',
#   'IO': 'Christopher',
#   'S': 'Paul',
#   'TEMPLATE_IDX': 0,
#   'C': 'Melissa'},
#  {'[PLACE]': 'station',
#   '[OBJECT]': 'bone',
#   'text': 'Then, William and Shannon went to the station. Rebecca gave a bone to William',
#   'IO': 'William',
#   'S': 'Shannon',
#   'TEMPLATE_IDX': 0,
#   'C': 'Rebecca'},
#  {'[PLACE]': 'station',
#   '[OBJECT]': 'ring',
#   'text': 'Then, Mary and Sara went to the station. Lauren gave a ring to Mary',
#   'IO': 'Mary',
#   'S': 'Sara',
#   'TEMPLATE_IDX': 0,
#   'C': 'Lauren'},
#  {'[PLACE]': 'office',
#   '[OBJECT]': 'drink',
#   'text': 'Then, Paul and Heather went to the office. Michelle gave a drink to Paul',
#   'IO': 'Paul',
#   'S': 'Heather',
#   'TEMPLATE_IDX': 0,
#   'C': 'Michelle'},
#  {'[PLACE]': 'school',
#   '[OBJECT]': 'kiss',
#   'text': 'Then, Andrew and Allison went to the school. Bryan gave a kiss to Andrew',
#   'IO': 'Andrew',
#   'S': 'Allison',
#   'TEMPLATE_IDX': 0,
#   'C': 'Bryan'},
#  {'[PLACE]': 'station',
#   '[OBJECT]': 'snack',
#   'text': 'Then, Dustin and Jeffrey went to the station. Paul gave a snack to Dustin',
#   'IO': 'Dustin',
#   'S': 'Jeffrey',
#   'TEMPLATE_IDX': 0,
#   'C': 'Paul'},
#  {'[PLACE]': 'restaurant',
#   '[OBJECT]': 'computer',
#   'text': 'Then, Kimberly and Angela went to the restaurant. Timothy gave a computer to Kimberly',
#   'IO': 'Kimberly',
#   'S': 'Angela',
#   'TEMPLATE_IDX': 0,
#   'C': 'Timothy'},
#  {'[PLACE]': 'hospital',
#   '[OBJECT]': 'kiss',
#   'text': 'Then, Robert and Jeffrey went to the hospital. Jessica gave a kiss to Robert',
#   'IO': 'Robert',
#   'S': 'Jeffrey',
#   'TEMPLATE_IDX': 0,
#   'C': 'Jessica'},
#  {'[PLACE]': 'restaurant',
#   '[OBJECT]': 'ring',
#   'text': 'Then, Rachel and Jeremy went to the restaurant. Michael gave a ring to Rachel',
#   'IO': 'Rachel',
#   'S': 'Jeremy',
#   'TEMPLATE_IDX': 0,
#   'C': 'Michael'},
#  {'[PLACE]': 'station',
#   '[OBJECT]': 'kiss',
#   'text': 'Then, Cody and Thomas went to the station. Nathan gave a kiss to Cody',
#   'IO': 'Cody',
#   'S': 'Thomas',
#   'TEMPLATE_IDX': 0,
#   'C': 'Nathan'},
#  {'[PLACE]': 'garden',
#   '[OBJECT]': 'basketball',
#   'text': 'Then, Samantha and Joseph went to the garden. Andrea gave a basketball to Samantha',
#   'IO': 'Samantha',
#   'S': 'Joseph',
#   'TEMPLATE_IDX': 0,
#   'C': 'Andrea'},
#  {'[PLACE]': 'garden',
#   '[OBJECT]': 'basketball',
#   'text': 'Then, Aaron and Sean went to the garden. Shannon gave a basketball to Aaron',
#   'IO': 'Aaron',
#   'S': 'Sean',
#   'TEMPLATE_IDX': 0,
#   'C': 'Shannon'},
#  {'[PLACE]': 'station',
#   '[OBJECT]': 'drink',
#   'text': 'Then, Robert and Travis went to the station. Rebecca gave a drink to Robert',
#   'IO': 'Robert',
#   'S': 'Travis',
#   'TEMPLATE_IDX': 0,
#   'C': 'Rebecca'},
#  {'[PLACE]': 'hospital',
#   '[OBJECT]': 'basketball',
#   'text': 'Then, Mark and Anthony went to the hospital. Amy gave a basketball to Mark',
#   'IO': 'Mark',
#   'S': 'Anthony',
#   'TEMPLATE_IDX': 0,
#   'C': 'Amy'},
#  {'[PLACE]': 'house',
#   '[OBJECT]': 'bone',
#   'text': 'Then, Sean and Kenneth went to the house. Adam gave a bone to Sean',
#   'IO': 'Sean',
#   'S': 'Kenneth',
#   'TEMPLATE_IDX': 0,
#   'C': 'Adam'},
#  {'[PLACE]': 'restaurant',
#   '[OBJECT]': 'basketball',
#   'text': 'Then, James and Alicia went to the restaurant. Kristen gave a basketball to James',
#   'IO': 'James',
#   'S': 'Alicia',
#   'TEMPLATE_IDX': 0,
#   'C': 'Kristen'},
#  {'[PLACE]': 'station',
#   '[OBJECT]': 'computer',
#   'text': 'Then, Scott and Erica went to the station. Mary gave a computer to Scott',
#   'IO': 'Scott',
#   'S': 'Erica',
#   'TEMPLATE_IDX': 0,
#   'C': 'Mary'},
#  {'[PLACE]': 'house',
#   '[OBJECT]': 'drink',
#   'text': 'Then, Lindsay and David went to the house. Jacob gave a drink to Lindsay',
#   'IO': 'Lindsay',
#   'S': 'David',
#   'TEMPLATE_IDX': 0,
#   'C': 'Jacob'},
#  {'[PLACE]': 'house',
#   '[OBJECT]': 'bone',
#   'text': 'Then, Jose and Jesse went to the house. Kimberly gave a bone to Jose',
#   'IO': 'Jose',
#   'S': 'Jesse',
#   'TEMPLATE_IDX': 0,
#   'C': 'Kimberly'},
#  {'[PLACE]': 'office',
#   '[OBJECT]': 'necklace',
#   'text': 'Then, Danielle and Lindsay went to the office. Brian gave a necklace to Danielle',
#   'IO': 'Danielle',
#   'S': 'Lindsay',
#   'TEMPLATE_IDX': 0,
#   'C': 'Brian'},
#  {'[PLACE]': 'station',
#   '[OBJECT]': 'kiss',
#   'text': 'Then, Jamie and Heather went to the station. Lindsey gave a kiss to Jamie',
#   'IO': 'Jamie',
#   'S': 'Heather',
#   'TEMPLATE_IDX': 0,
#   'C': 'Lindsey'},
#  {'[PLACE]': 'station',
#   '[OBJECT]': 'kiss',
#   'text': 'Then, Brittany and Jose went to the station. Christine gave a kiss to Brittany',
#   'IO': 'Brittany',
#   'S': 'Jose',
#   'TEMPLATE_IDX': 0,
#   'C': 'Christine'},
#  {'[PLACE]': 'school',
#   '[OBJECT]': 'snack',
#   'text': 'Then, Courtney and Timothy went to the school. Laura gave a snack to Courtney',
#   'IO': 'Courtney',
#   'S': 'Timothy',
#   'TEMPLATE_IDX': 0,
#   'C': 'Laura'},
#  {'[PLACE]': 'hospital',
#   '[OBJECT]': 'kiss',
#   'text': 'Then, Travis and Andrea went to the hospital. Tyler gave a kiss to Travis',
#   'IO': 'Travis',
#   'S': 'Andrea',
#   'TEMPLATE_IDX': 0,
#   'C': 'Tyler'},
#  {'[PLACE]': 'office',
#   '[OBJECT]': 'computer',
#   'text': 'Then, Andrew and Jeffrey went to the office. Nicholas gave a computer to Andrew',
#   'IO': 'Andrew',
#   'S': 'Jeffrey',
#   'TEMPLATE_IDX': 0,
#   'C': 'Nicholas'},
#  {'[PLACE]': 'store',
#   '[OBJECT]': 'necklace',
#   'text': 'Then, Angela and Kristen went to the store. Aaron gave a necklace to Angela',
#   'IO': 'Angela',
#   'S': 'Kristen',
#   'TEMPLATE_IDX': 0,
#   'C': 'Aaron'},
#  {'[PLACE]': 'store',
#   '[OBJECT]': 'computer',
#   'text': 'Then, Alicia and Jamie went to the store. Amanda gave a computer to Alicia',
#   'IO': 'Alicia',
#   'S': 'Jamie',
#   'TEMPLATE_IDX': 0,
#   'C': 'Amanda'},
#  {'[PLACE]': 'garden',
#   '[OBJECT]': 'necklace',
#   'text': 'Then, Kyle and Joshua went to the garden. Lindsey gave a necklace to Kyle',
#   'IO': 'Kyle',
#   'S': 'Joshua',
#   'TEMPLATE_IDX': 0,
#   'C': 'Lindsey'},
#  {'[PLACE]': 'garden',
#   '[OBJECT]': 'ring',
#   'text': 'Then, Sara and Kristen went to the garden. Christopher gave a ring to Sara',
#   'IO': 'Sara',
#   'S': 'Kristen',
#   'TEMPLATE_IDX': 0,
#   'C': 'Christopher'},
#  {'[PLACE]': 'station',
#   '[OBJECT]': 'snack',
#   'text': 'Then, Andrea and Christina went to the station. William gave a snack to Andrea',
#   'IO': 'Andrea',
#   'S': 'Christina',
#   'TEMPLATE_IDX': 0,
#   'C': 'William'},
#  {'[PLACE]': 'garden',
#   '[OBJECT]': 'drink',
#   'text': 'Then, Thomas and Nicole went to the garden. Erin gave a drink to Thomas',
#   'IO': 'Thomas',
# ...
#   'S': 'James',
#   'TEMPLATE_IDX': 0,
#   'C': 'Shannon'},
#  {'[PLACE]': 'garden',
#   '[OBJECT]': 'necklace',
#   'text': 'Then, Aaron and Benjamin went to the garden. David gave a necklace to Aaron',
#   'IO': 'Aaron',
#   'S': 'Benjamin',
#   'TEMPLATE_IDX': 0,
#   'C': 'David'},
#  {'[PLACE]': 'restaurant',
#   '[OBJECT]': 'necklace',
#   'text': 'Then, Sean and Jose went to the restaurant. Daniel gave a necklace to Sean',
#   'IO': 'Sean',
#   'S': 'Jose',
#   'TEMPLATE_IDX': 0,
#   'C': 'Daniel'},
#  {'[PLACE]': 'house',
#   '[OBJECT]': 'basketball',
#   'text': 'Then, Charles and Christina went to the house. Alicia gave a basketball to Charles',
#   'IO': 'Charles',
#   'S': 'Christina',
#   'TEMPLATE_IDX': 0,
#   'C': 'Alicia'},
#  {'[PLACE]': 'office',
#   '[OBJECT]': 'bone',
#   'text': 'Then, Scott and Sarah went to the office. Vanessa gave a bone to Scott',
#   'IO': 'Scott',
#   'S': 'Sarah',
#   'TEMPLATE_IDX': 0,
#   'C': 'Vanessa'},
#  {'[PLACE]': 'house',
#   '[OBJECT]': 'snack',
#   'text': 'Then, Robert and Nathan went to the house. Jacob gave a snack to Robert',
#   'IO': 'Robert',
#   'S': 'Nathan',
#   'TEMPLATE_IDX': 0,
#   'C': 'Jacob'},
#  {'[PLACE]': 'school',
#   '[OBJECT]': 'kiss',
#   'text': 'Then, Christine and Andrew went to the school. Alexander gave a kiss to Christine',
#   'IO': 'Christine',
#   'S': 'Andrew',
#   'TEMPLATE_IDX': 0,
#   'C': 'Alexander'},
#  {'[PLACE]': 'house',
#   '[OBJECT]': 'drink',
#   'text': 'Then, Samuel and Sarah went to the house. Bryan gave a drink to Samuel',
#   'IO': 'Samuel',
#   'S': 'Sarah',
#   'TEMPLATE_IDX': 0,
#   'C': 'Bryan'},
#  {'[PLACE]': 'office',
#   '[OBJECT]': 'kiss',
#   'text': 'Then, Shannon and Nicole went to the office. Bryan gave a kiss to Shannon',
#   'IO': 'Shannon',
#   'S': 'Nicole',
#   'TEMPLATE_IDX': 0,
#   'C': 'Bryan'},
#  {'[PLACE]': 'station',
#   '[OBJECT]': 'computer',
#   'text': 'Then, Alicia and Jessica went to the station. Vanessa gave a computer to Alicia',
#   'IO': 'Alicia',
#   'S': 'Jessica',
#   'TEMPLATE_IDX': 0,
#   'C': 'Vanessa'},
#  {'[PLACE]': 'hospital',
#   '[OBJECT]': 'kiss',
#   'text': 'Then, Benjamin and Kelly went to the hospital. Mary gave a kiss to Benjamin',
#   'IO': 'Benjamin',
#   'S': 'Kelly',
#   'TEMPLATE_IDX': 0,
#   'C': 'Mary'},
#  {'[PLACE]': 'school',
#   '[OBJECT]': 'ring',
#   'text': 'Then, Dustin and Jennifer went to the school. David gave a ring to Dustin',
#   'IO': 'Dustin',
#   'S': 'Jennifer',
#   'TEMPLATE_IDX': 0,
#   'C': 'David'},
#  {'[PLACE]': 'house',
#   '[OBJECT]': 'necklace',
#   'text': 'Then, David and Amanda went to the house. Cody gave a necklace to David',
#   'IO': 'David',
#   'S': 'Amanda',
#   'TEMPLATE_IDX': 0,
#   'C': 'Cody'},
#  {'[PLACE]': 'school',
#   '[OBJECT]': 'snack',
#   'text': 'Then, Jonathan and Rebecca went to the school. Anthony gave a snack to Jonathan',
#   'IO': 'Jonathan',
#   'S': 'Rebecca',
#   'TEMPLATE_IDX': 0,
#   'C': 'Anthony'},
#  {'[PLACE]': 'garden',
#   '[OBJECT]': 'necklace',
#   'text': 'Then, Stephen and Rebecca went to the garden. Kyle gave a necklace to Stephen',
#   'IO': 'Stephen',
#   'S': 'Rebecca',
#   'TEMPLATE_IDX': 0,
#   'C': 'Kyle'},
#  {'[PLACE]': 'hospital',
#   '[OBJECT]': 'drink',
#   'text': 'Then, Jacob and Emily went to the hospital. Danielle gave a drink to Jacob',
#   'IO': 'Jacob',
#   'S': 'Emily',
#   'TEMPLATE_IDX': 0,
#   'C': 'Danielle'},
#  {'[PLACE]': 'hospital',
#   '[OBJECT]': 'kiss',
#   'text': 'Then, Christine and Rebecca went to the hospital. Anthony gave a kiss to Christine',
#   'IO': 'Christine',
#   'S': 'Rebecca',
#   'TEMPLATE_IDX': 0,
#   'C': 'Anthony'},
#  {'[PLACE]': 'store',
#   '[OBJECT]': 'snack',
#   'text': 'Then, Jacob and Amber went to the store. Justin gave a snack to Jacob',
#   'IO': 'Jacob',
#   'S': 'Amber',
#   'TEMPLATE_IDX': 0,
#   'C': 'Justin'},
#  {'[PLACE]': 'house',
#   '[OBJECT]': 'necklace',
#   'text': 'Then, Allison and Danielle went to the house. Michael gave a necklace to Allison',
#   'IO': 'Allison',
#   'S': 'Danielle',
#   'TEMPLATE_IDX': 0,
#   'C': 'Michael'},
#  {'[PLACE]': 'store',
#   '[OBJECT]': 'basketball',
#   'text': 'Then, Tiffany and Timothy went to the store. Melissa gave a basketball to Tiffany',
#   'IO': 'Tiffany',
#   'S': 'Timothy',
#   'TEMPLATE_IDX': 0,
#   'C': 'Melissa'},
#  {'[PLACE]': 'restaurant',
#   '[OBJECT]': 'computer',
#   'text': 'Then, Scott and Matthew went to the restaurant. Kelly gave a computer to Scott',
#   'IO': 'Scott',
#   'S': 'Matthew',
#   'TEMPLATE_IDX': 0,
#   'C': 'Kelly'},
#  {'[PLACE]': 'hospital',
#   '[OBJECT]': 'bone',
#   'text': 'Then, Shannon and Travis went to the hospital. Nathan gave a bone to Shannon',
#   'IO': 'Shannon',
#   'S': 'Travis',
#   'TEMPLATE_IDX': 0,
#   'C': 'Nathan'},
#  {'[PLACE]': 'hospital',
#   '[OBJECT]': 'snack',
#   'text': 'Then, Joseph and Tiffany went to the hospital. Robert gave a snack to Joseph',
#   'IO': 'Joseph',
#   'S': 'Tiffany',
#   'TEMPLATE_IDX': 0,
#   'C': 'Robert'},
#  {'[PLACE]': 'hospital',
#   '[OBJECT]': 'bone',
#   'text': 'Then, Daniel and Lauren went to the hospital. Travis gave a bone to Daniel',
#   'IO': 'Daniel',
#   'S': 'Lauren',
#   'TEMPLATE_IDX': 0,
#   'C': 'Travis'},
#  {'[PLACE]': 'hospital',
#   '[OBJECT]': 'ring',
#   'text': 'Then, Alexander and Brandon went to the hospital. Andrew gave a ring to Alexander',
#   'IO': 'Alexander',
#   'S': 'Brandon',
#   'TEMPLATE_IDX': 0,
#   'C': 'Andrew'},
#  {'[PLACE]': 'restaurant',
#   '[OBJECT]': 'basketball',
#   'text': 'Then, Angela and Sean went to the restaurant. Brittany gave a basketball to Angela',
#   'IO': 'Angela',
#   'S': 'Sean',
#   'TEMPLATE_IDX': 0,
#   'C': 'Brittany'},
#  {'[PLACE]': 'store',
#   '[OBJECT]': 'basketball',
#   'text': 'Then, Justin and Richard went to the store. Kristen gave a basketball to Justin',
#   'IO': 'Justin',
#   'S': 'Richard',
#   'TEMPLATE_IDX': 0,
#   'C': 'Kristen'},
#  {'[PLACE]': 'hospital',
#   '[OBJECT]': 'basketball',
#   'text': 'Then, Shannon and Sara went to the hospital. Jonathan gave a basketball to Shannon',
#   'IO': 'Shannon',
#   'S': 'Sara',
#   'TEMPLATE_IDX': 0,
#   'C': 'Jonathan'},
#  {'[PLACE]': 'office',
#   '[OBJECT]': 'kiss',
#   'text': 'Then, Cody and Kyle went to the office. Erica gave a kiss to Cody',
#   'IO': 'Cody',
#   'S': 'Kyle',
#   'TEMPLATE_IDX': 0,
#   'C': 'Erica'},
#  {'[PLACE]': 'station',
#   '[OBJECT]': 'computer',
#   'text': 'Then, Travis and Andrew went to the station. Megan gave a computer to Travis',
#   'IO': 'Travis',
#   'S': 'Andrew',
#   'TEMPLATE_IDX': 0,
#   'C': 'Megan'},
#  {'[PLACE]': 'hospital',
#   '[OBJECT]': 'bone',
#   'text': 'Then, Emily and Megan went to the hospital. Eric gave a bone to Emily',
#   'IO': 'Emily',
#   'S': 'Megan',
#   'TEMPLATE_IDX': 0,
#   'C': 'Eric'},
#  {'[PLACE]': 'house',
#   '[OBJECT]': 'kiss',
#   'text': 'Then, Thomas and Sara went to the house. Charles gave a kiss to Thomas',
#   'IO': 'Thomas',
#   'S': 'Sara',
#   'TEMPLATE_IDX': 0,
#   'C': 'Charles'},
#  {'[PLACE]': 'hospital',
#   '[OBJECT]': 'bone',
#   'text': 'Then, Elizabeth and Michael went to the hospital. Allison gave a bone to Elizabeth',
#   'IO': 'Elizabeth',
#   'S': 'Michael',
#   'TEMPLATE_IDX': 0,
#   'C': 'Allison'},
#  {'[PLACE]': 'school',
#   '[OBJECT]': 'bone',
#   'text': 'Then, Tiffany and Stephanie went to the school. Mark gave a bone to Tiffany',
#   'IO': 'Tiffany',
#   'S': 'Stephanie',
#   'TEMPLATE_IDX': 0,
#   'C': 'Mark'},
#  {'[PLACE]': 'garden',
#   '[OBJECT]': 'drink',
#   'text': 'Then, Charles and Angela went to the garden. Erica gave a drink to Charles',
#   'IO': 'Charles',
#   'S': 'Angela',
#   'TEMPLATE_IDX': 0,
#   'C': 'Erica'},
#  {'[PLACE]': 'hospital',
#   '[OBJECT]': 'necklace',
#   'text': 'Then, Nicholas and John went to the hospital. Travis gave a necklace to Nicholas',
#   'IO': 'Nicholas',
#   'S': 'John',
#   'TEMPLATE_IDX': 0,
#   'C': 'Travis'},
#  {'[PLACE]': 'store',
#   '[OBJECT]': 'necklace',
#   'text': 'Then, Shannon and Patrick went to the store. Jamie gave a necklace to Shannon',
#   'IO': 'Shannon',
#   'S': 'Patrick',
#   'TEMPLATE_IDX': 0,
#   'C': 'Jamie'},
#  {'[PLACE]': 'office',
#   '[OBJECT]': 'snack',
#   'text': 'Then, John and Mary went to the office. Jessica gave a snack to John',
#   'IO': 'John',
#   'S': 'Mary',
#   'TEMPLATE_IDX': 0,
#   'C': 'Jessica'},
#  {'[PLACE]': 'garden',
#   '[OBJECT]': 'necklace',
#   'text': 'Then, Alexander and Kimberly went to the garden. Ashley gave a necklace to Alexander',
#   'IO': 'Alexander',
#   'S': 'Kimberly',
#   'TEMPLATE_IDX': 0,
#   'C': 'Ashley'},
#  {'[PLACE]': 'school',
#   '[OBJECT]': 'kiss',
#   'text': 'Then, Crystal and Travis went to the school. Christina gave a kiss to Crystal',
#   'IO': 'Crystal',
#   'S': 'Travis',
#   'TEMPLATE_IDX': 0,
#   'C': 'Christina'},
#  {'[PLACE]': 'restaurant',
#   '[OBJECT]': 'bone',
#   'text': 'Then, James and Jonathan went to the restaurant. Richard gave a bone to James',
#   'IO': 'James',
#   'S': 'Jonathan',
#   'TEMPLATE_IDX': 0,
#   'C': 'Richard'},
#  {'[PLACE]': 'hospital',
#   '[OBJECT]': 'drink',
#   'text': 'Then, Sean and Jason went to the hospital. Matthew gave a drink to Sean',
#   'IO': 'Sean',
#   'S': 'Jason',
#   'TEMPLATE_IDX': 0,
#   'C': 'Matthew'},
#  {'[PLACE]': 'school',
#   '[OBJECT]': 'snack',
#   'text': 'Then, Angela and Ashley went to the school. Nicole gave a snack to Angela',
#   'IO': 'Angela',
#   'S': 'Ashley',
#   'TEMPLATE_IDX': 0,
#   'C': 'Nicole'},
#  {'[PLACE]': 'restaurant',
#   '[OBJECT]': 'snack',
#   'text': 'Then, Lauren and Bryan went to the restaurant. Patrick gave a snack to Lauren',
#   'IO': 'Lauren',
#   'S': 'Bryan',
#   'TEMPLATE_IDX': 0,
#   'C': 'Patrick'},
#  {'[PLACE]': 'station',
#   '[OBJECT]': 'snack',
#   'text': 'Then, John and Brittany went to the station. Charles gave a snack to John',
#   'IO': 'John',
#   'S': 'Brittany',
#   'TEMPLATE_IDX': 0,
#   'C': 'Charles'},
#  {'[PLACE]': 'office',
#   '[OBJECT]': 'computer',
#   'text': 'Then, Rachel and Sean went to the office. Brian gave a computer to Rachel',
#   'IO': 'Rachel',
#   'S': 'Sean',
#   'TEMPLATE_IDX': 0,
#   'C': 'Brian'},
#  {'[PLACE]': 'house',
#   '[OBJECT]': 'ring',
#   'text': 'Then, Jeffrey and Crystal went to the house. Bradley gave a ring to Jeffrey',
#   'IO': 'Jeffrey',
#   'S': 'Crystal',
#   'TEMPLATE_IDX': 0,
#   'C': 'Bradley'},
#  {'[PLACE]': 'hospital',
#   '[OBJECT]': 'bone',
#   'text': 'Then, Mark and Lindsay went to the hospital. Lisa gave a bone to Mark',
#   'IO': 'Mark',
#   'S': 'Lindsay',
#   'TEMPLATE_IDX': 0,
#   'C': 'Lisa'},
#  {'[PLACE]': 'station',
#   '[OBJECT]': 'basketball',
#   'text': 'Then, Katie and Amy went to the station. Amber gave a basketball to Katie',
#   'IO': 'Katie',
#   'S': 'Amy',
#   'TEMPLATE_IDX': 0,
#   'C': 'Amber'},
#  {'[PLACE]': 'restaurant',
#   '[OBJECT]': 'ring',
#   'text': 'Then, Robert and Jeffrey went to the restaurant. Adam gave a ring to Robert',
#   'IO': 'Robert',
#   'S': 'Jeffrey',
#   'TEMPLATE_IDX': 0,
#   'C': 'Adam'},
#  {'[PLACE]': 'garden',
#   '[OBJECT]': 'bone',
#   'text': 'Then, Emily and Richard went to the garden. Gregory gave a bone to Emily',
#   'IO': 'Emily',
#   'S': 'Richard',
#   'TEMPLATE_IDX': 0,
#   'C': 'Gregory'},
#  {'[PLACE]': 'station',
#   '[OBJECT]': 'bone',
#   'text': 'Then, Samuel and Justin went to the station. Amber gave a bone to Samuel',
#   'IO': 'Samuel',
#   'S': 'Justin',
#   'TEMPLATE_IDX': 0,
#   'C': 'Amber'},
#  {'[PLACE]': 'school',
#   '[OBJECT]': 'kiss',
#   'text': 'Then, Joseph and Alexander went to the school. Jeffrey gave a kiss to Joseph',
#   'IO': 'Joseph',
#   'S': 'Alexander',
#   'TEMPLATE_IDX': 0,
#   'C': 'Jeffrey'},
#  {'[PLACE]': 'station',
#   '[OBJECT]': 'necklace',
#   'text': 'Then, Samantha and Thomas went to the station. Bradley gave a necklace to Samantha',
#   'IO': 'Samantha',
#   'S': 'Thomas',
#   'TEMPLATE_IDX': 0,
#   'C': 'Bradley'},
#  {'[PLACE]': 'hospital',
#   '[OBJECT]': 'kiss',
#   'text': 'Then, Samuel and Tyler went to the hospital. Kimberly gave a kiss to Samuel',
#   'IO': 'Samuel',
#   'S': 'Tyler',
#   'TEMPLATE_IDX': 0,
#   'C': 'Kimberly'},
#  {'[PLACE]': 'hospital',
#   '[OBJECT]': 'kiss',
#   'text': 'Then, Amber and Andrew went to the hospital. Jennifer gave a kiss to Amber',
#   'IO': 'Amber',
#   'S': 'Andrew',
#   'TEMPLATE_IDX': 0,
#   'C': 'Jennifer'},
#  {'[PLACE]': 'store',
#   '[OBJECT]': 'bone',
#   'text': 'Then, Vanessa and Jeremy went to the store. William gave a bone to Vanessa',
#   'IO': 'Vanessa',
#   'S': 'Jeremy',
#   'TEMPLATE_IDX': 0,
#   'C': 'William'},
#  {'[PLACE]': 'station',
#   '[OBJECT]': 'computer',
#   'text': 'Then, Timothy and Anthony went to the station. Elizabeth gave a computer to Timothy',
#   'IO': 'Timothy',
#   'S': 'Anthony',
#   'TEMPLATE_IDX': 0,
#   'C': 'Elizabeth'},
#  {'[PLACE]': 'station',
#   '[OBJECT]': 'computer',
#   'text': 'Then, Thomas and Steven went to the station. Kimberly gave a computer to Thomas',
#   'IO': 'Thomas',
#   'S': 'Steven',
#   'TEMPLATE_IDX': 0,
#   'C': 'Kimberly'},
#  {'[PLACE]': 'garden',
#   '[OBJECT]': 'computer',
#   'text': 'Then, Nicholas and Charles went to the garden. Christopher gave a computer to Nicholas',
#   'IO': 'Nicholas',
#   'S': 'Charles',
#   'TEMPLATE_IDX': 0,
#   'C': 'Christopher'},
#  {'[PLACE]': 'restaurant',
#   '[OBJECT]': 'kiss',
#   'text': 'Then, Kyle and Shannon went to the restaurant. Ryan gave a kiss to Kyle',
#   'IO': 'Kyle',
#   'S': 'Shannon',
#   'TEMPLATE_IDX': 0,
#   'C': 'Ryan'},
#  {'[PLACE]': 'restaurant',
#   '[OBJECT]': 'ring',
#   'text': 'Then, Brian and Samuel went to the restaurant. Lindsay gave a ring to Brian',
#   'IO': 'Brian',
#   'S': 'Samuel',
#   'TEMPLATE_IDX': 0,
#   'C': 'Lindsay'},
#  {'[PLACE]': 'garden',
#   '[OBJECT]': 'kiss',
#   'text': 'Then, Andrew and Sara went to the garden. Alicia gave a kiss to Andrew',
#   'IO': 'Andrew',
#   'S': 'Sara',
#   'TEMPLATE_IDX': 0,
#   'C': 'Alicia'},
#  {'[PLACE]': 'station',
#   '[OBJECT]': 'necklace',
#   'text': 'Then, Paul and Crystal went to the station. Jason gave a necklace to Paul',
#   'IO': 'Paul',
#   'S': 'Crystal',
#   'TEMPLATE_IDX': 0,
#   'C': 'Jason'},
#  {'[PLACE]': 'station',
#   '[OBJECT]': 'drink',
#   'text': 'Then, Sarah and Shannon went to the station. Sean gave a drink to Sarah',
#   'IO': 'Sarah',
#   'S': 'Shannon',
#   'TEMPLATE_IDX': 0,
#   'C': 'Sean'},
#  {'[PLACE]': 'garden',
#   '[OBJECT]': 'drink',
#   'text': 'Then, Matthew and Gregory went to the garden. Jesse gave a drink to Matthew',
#   'IO': 'Matthew',
#   'S': 'Gregory',
#   'TEMPLATE_IDX': 0,
#   'C': 'Jesse'},
#  {'[PLACE]': 'office',
#   '[OBJECT]': 'drink',
#   'text': 'Then, Courtney and Tyler went to the office. William gave a drink to Courtney',
#   'IO': 'Courtney',
#   'S': 'Tyler',
#   'TEMPLATE_IDX': 0,
#   'C': 'William'},
#  {'[PLACE]': 'restaurant',
#   '[OBJECT]': 'kiss',
#   'text': 'Then, Joseph and Sean went to the restaurant. Michael gave a kiss to Joseph',
#   'IO': 'Joseph',
#   'S': 'Sean',
#   'TEMPLATE_IDX': 0,
#   'C': 'Michael'},
#  {'[PLACE]': 'restaurant',
#   '[OBJECT]': 'snack',
#   'text': 'Then, Brandon and Michael went to the restaurant. Michelle gave a snack to Brandon',
#   'IO': 'Brandon',
#   'S': 'Michael',
#   'TEMPLATE_IDX': 0,
#   'C': 'Michelle'},
#  {'[PLACE]': 'hospital',
#   '[OBJECT]': 'kiss',
#   'text': 'Then, Christine and Danielle went to the hospital. Kristen gave a kiss to Christine',
#   'IO': 'Christine',
#   'S': 'Danielle',
#   'TEMPLATE_IDX': 0,
#   'C': 'Kristen'},
#  {'[PLACE]': 'garden',
#   '[OBJECT]': 'drink',
#   'text': 'Then, Justin and Mark went to the garden. Courtney gave a drink to Justin',
#   'IO': 'Justin',
#   'S': 'Mark',
#   'TEMPLATE_IDX': 0,
#   'C': 'Courtney'},
#  {'[PLACE]': 'station',
#   '[OBJECT]': 'basketball',
#   'text': 'Then, Tyler and Jeffrey went to the station. Michelle gave a basketball to Tyler',
#   'IO': 'Tyler',
#   'S': 'Jeffrey',
#   'TEMPLATE_IDX': 0,
#   'C': 'Michelle'},
#  {'[PLACE]': 'garden',
#   '[OBJECT]': 'basketball',
#   'text': 'Then, Katherine and Jason went to the garden. Lindsey gave a basketball to Katherine',
#   'IO': 'Katherine',
#   'S': 'Jason',
#   'TEMPLATE_IDX': 0,
#   'C': 'Lindsey'},
#  {'[PLACE]': 'restaurant',
#   '[OBJECT]': 'ring',
#   'text': 'Then, Thomas and Lindsey went to the restaurant. Steven gave a ring to Thomas',
#   'IO': 'Thomas',
#   'S': 'Lindsey',
#   'TEMPLATE_IDX': 0,
#   'C': 'Steven'},
#  {'[PLACE]': 'office',
#   '[OBJECT]': 'kiss',
#   'text': 'Then, Nicholas and Matthew went to the office. Laura gave a kiss to Nicholas',
#   'IO': 'Nicholas',
#   'S': 'Matthew',
#   'TEMPLATE_IDX': 0,
#   'C': 'Laura'},
#  {'[PLACE]': 'station',
#   '[OBJECT]': 'basketball',
#   'text': 'Then, Jose and Rachel went to the station. Adam gave a basketball to Jose',
#   'IO': 'Jose',
#   'S': 'Rachel',
#   'TEMPLATE_IDX': 0,
#   'C': 'Adam'},
#  ...]
